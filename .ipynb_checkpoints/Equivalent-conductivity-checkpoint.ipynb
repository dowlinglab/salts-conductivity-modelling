# %%
# importing packages
import numpy as np
from matplotlib import pyplot as plt
import math
import scipy.stats as stats
import pandas as pd

# %% [markdown]
# ## Equivalent Conductivity Model

# %% [markdown]
# ![image.png](attachment:53890d7b-cadb-4bc7-ac45-a60d74b38fae.png)

# %% [markdown]
# ## Relationship Between Equivalent Conductivity and Specific Conductivity

# %% [markdown]
# Specific conductivity = equivalent conductivity*concentration/1000
#
# Where the concentration is in equivalent per litre and equivalent conductivity in centimeter squared per Ohm per equivalent

# %% [markdown]
# ## NaCl

# %%
# loading NaCl equivalent conductivity data
equiv_data = pd.read_csv("./Data/NaCl_equiv.csv")
molar_conc_equiv = equiv_data["Conc"] # mM
equiv_cond = equiv_data["Equiv_cond"] # cm^2.Siemen.equiv^(-1)

# number of data points
ndata = len(equiv_cond)

# %% [markdown]
# ## Validating Equivalent Conductivity

# %%
# constants
temp = 298.16 # K
epsilon = 78.3
eta = 8.903*10**(-3) # poise
lambda_0 = 126.45 # cm^2.Siemen.equiv^(-1)
a = 4*10**(-8) # cm
B = 0.3291*10**8 # cm^(-1).mole^(-1/2).l^(1/2)

# for 1:1 electrolytes
q = 0.5
z_1 = 1
z_2 = -1

# B1 and B2
B_1 = 2.801*10**6*np.abs(z_1*z_2)*q/((epsilon*temp)**(3/2)*(1 + math.sqrt(q)))
B_2 = 41.25*(np.abs(z_1) + np.abs(z_2))/(eta*(epsilon*temp)**(1/2))
# B_1 = 0.2300 # mole^(-1/2).l^(1/2)
# B_2 = 60.65 # cm^2.Siemen.equiv^(-1).(l/mole)^(1/2)

# concentration in M
conc = [molar_conc_equiv[i]*10**(-3) for i in range(ndata)]

# equivalent conductivity from equation (7.36) in reference
def cond_calc_ref(conc):
    """
    Calculates equivalent conductivity using equation (7.36) in reference

    Arguments:
        conc: salt concentration in M
    
    Returns:
        equiv_cond_ref: equivalent conductivity values in cm^2.S/equiv
    """
    # species concentration
    cation_conc = conc
    Cl_conc = [np.abs(z_1)*conc[i] for i in range(len(conc))]

    # ionic strength
    I = np.zeros(len(conc))
    for i in range(len(conc)):
        conc_all = [cation_conc[i], Cl_conc[i]]
        z = [z_1, z_2]
        I[i] = 1/2*(sum(conc_all[j]*z[j]**2 for j in range(len(conc_all))))

    # equivalent conductivity
    equiv_cond_ref = []
    for i in range(len(conc)):
        equiv_cond_ref.append(lambda_0 - ((B_1*lambda_0 + B_2)*math.sqrt(I[i])/(1 + a*B*math.sqrt(I[i]))))
    
    return(equiv_cond_ref)

# making smoother plots
conc_smooth = np.linspace(0, np.max(conc), 100)
equiv_cond_smooth = cond_calc_ref(conc_smooth)

# %%
# making plot comparison of data values and calculated
plt.plot(conc_smooth, equiv_cond_smooth, "r-", label="Python code")
plt.plot(conc, equiv_cond, "b.", markersize=10, label="Theory calculation")
plt.xlabel("NaCl concentration (M)")
plt.ylabel("Equivalent conductivity (cm^2.S/equiv)")
plt.ylim((90, 130))
plt.legend()
plt.show()

# %%
# loading NaCl specific conductivity data
specific_data = pd.read_csv("./Data/NaCl.csv")
molar_conc_specific_Na = specific_data["NaCl conc"]
specific_cond_exp_Na = specific_data["NaCl cond"]
specific_cond_calibrated_Na = specific_data["NaCl cond cal"]

# number of data points
ndata2 = len(specific_cond_exp_Na)

# %% [markdown]
# ## Converting Equivalent Conductivity to Specific Conductivity

# %%
# concentration in M
conc2 = [molar_conc_specific_Na[i]*10**(-3) for i in range(ndata2)]

# function the predicts specific conductivity
def specific_cond_model(conc):
    """
    Calculates specific conductivity from equivalent conductivity

    Arguments:
        conc: salt concentration in M
    
    Returns:
        specific_cond_calc: specific conductivity values in micro Siemen per cm
    """
    
    # equivalent conductivity
    equiv_cond = cond_calc_ref(conc)
    
    # species concentration
    cation_conc = conc
    Cl_conc = [np.abs(z_1)*conc[i] for i in range(len(conc))]
    
    # converting the concentrations in mM to equivalent per litre
    equiv_conc = [cation_conc[i]*np.abs(z_1) for i in range(len(conc))]
    
    # specific conductivity in Siemen per cm
    specific_cond = []
    for i in range(len(conc)):
        specific_cond.append((equiv_conc[i]/1000)*equiv_cond[i])
    
    # specific conductivity in micro Siemen per cm
    specific_cond_calc = [specific_cond[i]*10**6 for i in range(len(conc))]

    return specific_cond_calc

# specific conductivity in micro Siemen per cm
specific_cond_calc_Na = specific_cond_model(conc2)

# %%
# making plot comparison of data and calculated values
fig = plt.figure(figsize=(4,4))
plt.plot(molar_conc_specific_Na, specific_cond_calc_Na, "r-", label="Theory")
plt.plot(molar_conc_specific_Na, specific_cond_exp_Na, "b.", markersize=10, label="Data")
plt.plot(molar_conc_specific_Na, specific_cond_calibrated_Na, "s", markersize=5, label="Calibrated Data")
plt.xlabel("NaCl concentration (mM)", fontsize=16,fontweight='bold')
plt.ylabel("Conductivity ($\mathbf{\mu}$S/cm)", fontsize=16,fontweight='bold')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.tick_params(direction="in",top=True, right=True)
plt.title("Theory Predictions", fontsize=16,fontweight='bold')
plt.legend()
plt.show()

# %%
# residuals
residuals = [specific_cond_calc_Na[i] - specific_cond_exp_Na[i] for i in range(ndata2)]

# making plot of residuals of calculated specific conductivity
plt.plot(molar_conc_specific_Na, residuals, "b.")
plt.xlabel("NaCl concentration (mM)")
plt.ylabel("Residuals (uS/cm)")
plt.show()

# %% [markdown]
# ## Evaluating Error

# %%
# residual fraction
residuals_percent = [(residuals[i]/specific_cond_exp_Na[i])*100 for i in range(ndata2)]

# visualizing in plot
fig = plt.figure(figsize=(4,4))
plt.plot(molar_conc_specific_Na, residuals_percent, "b.")
plt.xlabel("NaCl concentration (mM)", fontsize=16,fontweight='bold')
plt.ylabel("Residuals/Experiments (%)", fontsize=16,fontweight='bold')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.tick_params(direction="in",top=True, right=True)
plt.title("Instrument Error", fontsize=16,fontweight='bold')
plt.show()

# %%
# residual fraction
residuals_percent = [(residuals[i]/specific_cond_exp_Na[i])*100 for i in range(ndata2)]

# residuals percent average
residuals_percent.pop(0)
residual_percent_avg = np.average(residuals_percent)
print(residual_percent_avg)

# visualizing in plot
molar_conc_specific_Na.pop(0)
fig = plt.figure(figsize=(4,4))
plt.plot(molar_conc_specific_Na, residuals_percent, "b.")
plt.xlabel("NaCl concentration (mM)", fontsize=16,fontweight='bold')
plt.ylabel("Residuals/Experiments (%)", fontsize=16,fontweight='bold')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.tick_params(direction="in",top=True, right=True)
plt.title("Instrument Error", fontsize=16,fontweight='bold')
plt.show()
# Out:
# 14.54455955086329

# %% [markdown]
# ## Same Analysis for Potassium Chloride

# %%
# loading NaCl equivalent conductivity data
equiv_data = pd.read_csv("./Data/KCl_Equiv.csv")
molar_conc_equiv = equiv_data["KCl Conc"] # mM
equiv_cond = equiv_data["Equiv Cond"] # cm^2.Siemen.equiv^(-1)

# number of data points
ndata = len(equiv_cond)

# %%
# constants
temp = 298.16 # K
epsilon = 78.3
eta = 8.903*10**(-3) # poise
lambda_0 = 149.85 # cm^2.Siemen.equiv^(-1)
a = 4*10**(-8) # cm
B = 0.3291*10**8 # cm^(-1).mole^(-1/2).l^(1/2)

# for 1:1 electrolytes
q = 0.5
z_1 = 1
z_2 = -1

# B1 and B2
B_1 = 2.801*10**6*np.abs(z_1*z_2)*q/((epsilon*temp)**(3/2)*(1 + math.sqrt(q)))
B_2 = 41.25*(np.abs(z_1) + np.abs(z_2))/(eta*(epsilon*temp)**(1/2))

# concentration in M
conc = [molar_conc_equiv[i]*10**(-3) for i in range(ndata)]

# making smoother plots
conc_smooth = np.linspace(0, np.max(conc), 100)
equiv_cond_smooth = cond_calc_ref(conc_smooth)

# prediction accuracy
prediction_acc = [equiv_cond_smooth[i]/equiv_cond[i] for i in range(ndata)]
prediction_acc_avg = np.mean(prediction_acc)
# print(prediction_acc_avg)
# print(prediction_acc)

# %%
# making plot comparison of data values and calculated
plt.plot(conc_smooth, equiv_cond_smooth, "r-", label="Python code")
plt.plot(conc, equiv_cond, "b.", markersize=10, label="Theory calculation")
plt.xlabel("KCl concentration (M)", fontsize=12,fontweight='bold')
plt.ylabel("Equivalent conductivity (cm$\mathbf{^2}$.S/equiv)", fontsize=12,fontweight='bold')
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.tick_params(direction="in",top=True, right=True)
plt.title("Python code predictions", fontsize=16,fontweight='bold')
plt.ylim((120, 160))
plt.legend()
plt.show()

# %%
# loading KCl specific conductivity data
specific_data_probe1 = pd.read_csv("./Data/KCl_Probe1.csv")
specific_data_probe2 = pd.read_csv("./Data/KCl_Probe2.csv")
specific_data_probe3 = pd.read_csv("./Data/KCl_Probe3.csv")
molar_conc_specific = specific_data_probe1["KCl Conc"]
specific_cond_exp1 = specific_data_probe1["Cond"]
specific_cond_calibrated_exp1 = specific_data_probe1["Cond_cal"]
specific_cond_exp2 = specific_data_probe2["Cond"]
specific_cond_exp3 = specific_data_probe3["Cond"]

# number of data points
ndata2 = len(specific_cond_exp1)

# %%
# concentration in M
conc2 = [molar_conc_specific[i]*10**(-3) for i in range(ndata2)]

# specific conductivity in micro Siemen per cm
specific_cond_calc = specific_cond_model(conc2)

# %% [markdown]
# ## Probe 1

# %%
# making plot comparison of probe 1 data and calculated values
fig = plt.figure(figsize=(4,4))
plt.plot(molar_conc_specific, specific_cond_calc, "r-", label="Theory")
plt.plot(molar_conc_specific, specific_cond_exp1, "b.", markersize=10, label="Data")
plt.plot(molar_conc_specific, specific_cond_calibrated_exp1, "s", markersize=5, label="Calibrated Data")
plt.xlabel("KCl concentration (mM)", fontsize=16,fontweight='bold')
plt.ylabel("Conductivity (uS/cm)", fontsize=16,fontweight='bold')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.tick_params(direction="in",top=True, right=True)
plt.title("Theory Predictions", fontsize=16,fontweight='bold')
plt.legend()
plt.show()

# %%
# residuals
residuals = [specific_cond_calc[i] - specific_cond_exp1[i] for i in range(ndata2)]

# making plot of residuals of calculated specific conductivity
plt.plot(molar_conc_specific, residuals, "b.")
plt.xlabel("KCl concentration (mM)")
plt.ylabel("Residuals (uS/cm)")
plt.show()

# %%
# residual fraction
residuals_percent = [(residuals[i]/specific_cond_exp1[i])*100 for i in range(ndata2)]

# visualizing in plot
fig = plt.figure(figsize=(4,4))
plt.plot(molar_conc_specific, residuals_percent, "b.")
plt.xlabel("KCl concentration (mM)", fontsize=16,fontweight='bold')
plt.ylabel("Residuals/Experiments (%)", fontsize=16,fontweight='bold')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.tick_params(direction="in",top=True, right=True)
plt.title("Instrument Error", fontsize=16,fontweight='bold')
plt.show()

# %% [markdown]
# ## Probe 2

# %%
# making plot comparison of probe 2 data and calculated values
fig = plt.figure(figsize=(4,4))
plt.plot(molar_conc_specific, specific_cond_calc, "r-", label="Theory")
plt.plot(molar_conc_specific, specific_cond_exp2, "b.", markersize=10, label="Data")
plt.xlabel("KCl concentration (mM)", fontsize=16,fontweight='bold')
plt.ylabel("Conductivity (uS/cm)", fontsize=16,fontweight='bold')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.tick_params(direction="in",top=True, right=True)
plt.title("Theory Predictions", fontsize=16,fontweight='bold')
plt.legend()
plt.show()

# %%
# residuals
residuals = [specific_cond_calc[i] - specific_cond_exp2[i] for i in range(ndata2)]

# making plot of residuals of calculated specific conductivity
plt.plot(molar_conc_specific, residuals, "b.")
plt.xlabel("KCl concentration (mM)")
plt.ylabel("Residuals (uS/cm)")
plt.show()

# %%
# residual fraction
residuals_percent = [(residuals[i]/specific_cond_exp2[i])*100 for i in range(ndata2)]

# visualizing in plot
fig = plt.figure(figsize=(4,4))
plt.plot(molar_conc_specific, residuals_percent, "b.")
plt.xlabel("KCl concentration (mM)", fontsize=16,fontweight='bold')
plt.ylabel("Residuals/Experiments (%)", fontsize=16,fontweight='bold')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.tick_params(direction="in",top=True, right=True)
plt.title("Instrument Error", fontsize=16,fontweight='bold')
plt.show()

# %% [markdown]
# ## Probe 3

# %%
# making plot comparison of probe 3 data and calculated values
fig = plt.figure(figsize=(4,4))
plt.plot(molar_conc_specific, specific_cond_calc, "r-", label="Theory")
plt.plot(molar_conc_specific, specific_cond_exp3, "b.", markersize=10, label="Data")
plt.xlabel("KCl concentration (mM)", fontsize=16,fontweight='bold')
plt.ylabel("Conductivity (uS/cm)", fontsize=16,fontweight='bold')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.tick_params(direction="in",top=True, right=True)
plt.title("Theory Predictions", fontsize=16,fontweight='bold')
plt.legend()
plt.show()

# %%
# residuals
residuals = [specific_cond_calc[i] - specific_cond_exp3[i] for i in range(ndata2)]

# making plot of residuals of calculated specific conductivity
plt.plot(molar_conc_specific, residuals, "b.")
plt.xlabel("KCl concentration (mM)")
plt.ylabel("Residuals (uS/cm)")
plt.show()

# %%
# residual fraction
residuals_percent = [(residuals[i]/specific_cond_exp3[i])*100 for i in range(ndata2)]

# visualizing in plot
fig = plt.figure(figsize=(4,4))
plt.plot(molar_conc_specific, residuals_percent, "b.")
plt.xlabel("KCl concentration (mM)", fontsize=16,fontweight='bold')
plt.ylabel("Residuals/Experiments (%)", fontsize=16,fontweight='bold')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.tick_params(direction="in",top=True, right=True)
plt.title("Instrument Error", fontsize=16,fontweight='bold')
plt.show()

# %%
# residuals percent average
residuals_percent.pop(0)
residual_percent_avg = np.average(residuals_percent)
print(residual_percent_avg)

# visualizing in plot
molar_conc_specific.pop(0)
fig = plt.figure(figsize=(4,4))
plt.plot(molar_conc_specific, residuals_percent, "b.")
plt.xlabel("KCl concentration (mM)", fontsize=16,fontweight='bold')
plt.ylabel("Residuals/Experiments (%)", fontsize=16,fontweight='bold')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.tick_params(direction="in",top=True, right=True)
plt.title("Instrument Error", fontsize=16,fontweight='bold')
plt.show()
# Out:
# 11.938478672844088

# %% [markdown]
# ## CaCl2

# %%
# loading LaCl3 equivalent conductivity data
equiv_data = pd.read_csv("./Data/CaCl2_equiv.csv")
molar_conc_equiv = equiv_data["CaCl2_conc"] # mM
equiv_cond = equiv_data["CaCl2_equiv_cond"] # cm^2.Siemen.equiv^(-1)

# number of data points
ndata = len(equiv_cond)

# %%
# constants
temp = 298.16 # K
epsilon = 78.3
eta = 8.903*10**(-3) # poise
lambda_0 = 135.85 # cm^2.Siemen.equiv^(-1)
a = 4.31*10**(-8) # cm
lambda_0_cation = 59.5 # cm^2.Siemen.equiv^(-1)
lambda_0_Cl = 76.35 # cm^2.Siemen.equiv^(-1)
z_1 = 2
z_2 = -1

# calculating B and q
B = 50.29*(10**8)*(epsilon*temp)**(-0.5) # cm^(-1).mole^(-1/2).l^(1/2)
q = np.abs(z_1*z_2)*(lambda_0_cation + lambda_0_Cl)/((np.abs(z_1) + np.abs(z_2))*(np.abs(z_2)*lambda_0_cation + np.abs(z_1)*lambda_0_Cl))

# B1 and B2
B_1 = 2.801*(10**6)*np.abs(z_1*z_2)*q/((epsilon*temp)**(3/2)*(1 + math.sqrt(q)))
B_2 = 41.25*(np.abs(z_1) + np.abs(z_2))/(eta*(epsilon*temp)**(1/2))

# concentration in M
conc = [molar_conc_equiv[i]*10**(-3) for i in range(ndata)]

# making smoother plots
conc_smooth = np.linspace(0, np.max(conc), 100)
equiv_cond_smooth = cond_calc_ref(conc_smooth)

# %%
# making plot comparison of data values and calculated
plt.plot(conc_smooth, equiv_cond_smooth, "r-", label="Python code")
plt.plot(conc, equiv_cond, "b.", markersize=10, label="Theory calculation")
plt.xlabel("CaCl2 concentration (M)")
plt.ylabel("Equivalent conductivity (cm^2.S/equiv)")
plt.ylim((70, 150))
plt.legend()
plt.show()

# %% [markdown]
# ## LaCl3

# %%
# loading LaCl3 equivalent conductivity data
equiv_data = pd.read_csv("./Data/LaCl3_equiv.csv")
molar_conc_equiv = equiv_data["Conc"] # mM
equiv_cond = equiv_data["Equiv_cond"] # cm^2.Siemen.equiv^(-1)

# number of data points
ndata = len(equiv_cond)

# %%
# constants
temp = 298.16 # K
epsilon = 78.3
eta = 8.903*10**(-3) # poise
lambda_0 = 145.9 # cm^2.Siemen.equiv^(-1)
a = 4.9*10**(-8) # cm
lambda_0_cation = 69.55 # cm^2.Siemen.equiv^(-1)
lambda_0_Cl = 76.35 # cm^2.Siemen.equiv^(-1)
z_1 = 3
z_2 = -1

# calculating B and q
B = 50.29*(10**8)*(epsilon*temp)**(-0.5) # cm^(-1).mole^(-1/2).l^(1/2)
q = np.abs(z_1*z_2)*(lambda_0_cation + lambda_0_Cl)/((np.abs(z_1) + np.abs(z_2))*(np.abs(z_2)*lambda_0_cation + np.abs(z_1)*lambda_0_Cl))

# B1 and B2
B_1 = 2.801*(10**6)*np.abs(z_1*z_2)*q/((epsilon*temp)**(3/2)*(1 + math.sqrt(q)))
B_2 = 41.25*(np.abs(z_1) + np.abs(z_2))/(eta*(epsilon*temp)**(1/2))

# concentration in M
conc = [molar_conc_equiv[i]*10**(-3) for i in range(ndata)]

# making smoother plots
conc_smooth = np.linspace(0, np.max(conc), 100)
equiv_cond_smooth = cond_calc_ref(conc_smooth)

# %%
# making plot comparison of data values and calculated
plt.plot(conc_smooth, equiv_cond_smooth, "r-", label="Python code")
plt.plot(conc, equiv_cond, "b.", markersize=10, label="Theory calculation")
plt.xlabel("LaCl3 concentration (M)")
plt.ylabel("Equivalent conductivity (cm^2.S/equiv)")
plt.ylim((70, 150))
plt.legend()
plt.show()

# %%
# loading LaCl3 specific conductivity data
specific_data = pd.read_csv("./Data/LaCl3.csv")
molar_conc_specific_La = specific_data["LaCl3 conc"]
specific_cond_exp_La = specific_data["LaCl3 cond"]
specific_cond_calibrated_La = specific_data["LaCl3 cond cal"]

# number of data points
ndata2 = len(specific_cond_exp_La)

# %%
# loading LaCl3 equivalent conductivity data
equiv_data = pd.read_csv("./Data/LaCl3_equiv2.csv")
molar_conc_equiv = equiv_data["Conc"] # mM
equiv_cond = equiv_data["Equiv_cond"] # cm^2.Siemen.equiv^(-1)

# number of data points
ndata = len(equiv_cond)

# %%
# concentration in M
conc = [molar_conc_equiv[i]*10**(-3) for i in range(ndata)]

# species concentration
La_conc = conc
Cl_conc = [3*conc[i] for i in range(ndata)]

# converting the concentrations in mM to equivalent per litre
equiv_conc = [La_conc[i]*np.abs(z_1) for i in range(ndata)]

# specific conductivity in Siemen per cm
specific_cond_La = []
for i in range(ndata):
    specific_cond_La.append((equiv_conc[i]/1000)*equiv_cond[i])

# specific conductivity in micro Siemen per cm
specific_cond_calc_La = [specific_cond_La[i]*10**6 for i in range(ndata)]

# %%
# loading NaCl specific conductivity data
specific_data = pd.read_csv("./Data/NaCl.csv")
molar_conc_Na = specific_data["NaCl conc"]

# %%
# making plot comparison of data and calculated values
fig = plt.figure(figsize=(4,4))
plt.plot(molar_conc_specific_La, specific_cond_calibrated_La, "s", markersize=5, label="LaC$\mathrm{l_3}$")
plt.plot(molar_conc_equiv, specific_cond_calc_La, color="red", label="Theory")
plt.plot(molar_conc_Na, specific_cond_calibrated_Na, "o", color="black", markersize=5, label="NaCl")
plt.plot(molar_conc_Na, specific_cond_calc_Na, color="blue", label="Theory")
plt.xlabel("Salt Concentration (mM)", fontsize=16,fontweight='bold')
plt.ylabel("Conductivity ($\mathbf{\mu}$S/cm)", fontsize=16,fontweight='bold')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.tick_params(direction="in",top=True, right=True)
plt.title("Theory Predictions", fontsize=16,fontweight='bold')
plt.legend()
plt.savefig("NaCl_LaCl3_plot.jpg")
plt.show()

# %% [markdown]
# ## NaCl and CaCl2

# %%
# loading specific conductivity data
specific_data = pd.read_csv("./Data/NaCl2_CaCl2_cal.csv")
molar_conc_specific_Na = specific_data["NaCl"]
molar_conc_specific_Ca = specific_data["CaCl2"]
specific_cond_calibrated = specific_data["Bulk_cond_cal"]

# number of data points
ndata = len(specific_cond_calibrated)

# %% [markdown]
# ### NaCl

# %%
# constants
temp = 298.16 # K
epsilon = 78.3
eta = 8.903*10**(-3) # poise
lambda_0 = 126.45 # cm^2.Siemen.equiv^(-1)
a = 4*10**(-8) # cm
B = 0.3291*10**8 # cm^(-1).mole^(-1/2).l^(1/2)

# for 1:1 electrolytes
q = 0.5
z_1 = 1
z_2 = -1

# B1 and B2
B_1 = 2.801*10**6*np.abs(z_1*z_2)*q/((epsilon*temp)**(3/2)*(1 + math.sqrt(q)))
B_2 = 41.25*(np.abs(z_1) + np.abs(z_2))/(eta*(epsilon*temp)**(1/2))

# %%
# concentration in M
conc = [molar_conc_specific_Na[i]*10**(-3) for i in range(ndata)]

# specific conductivity in micro Siemen per cm
specific_cond_calc_Na = specific_cond_model(conc)

# %% [markdown]
# ### CaCl2

# %%
# constants
temp = 298.16 # K
epsilon = 78.3
eta = 8.903*10**(-3) # poise
lambda_0 = 135.85 # cm^2.Siemen.equiv^(-1)
a = 4.31*10**(-8) # cm
lambda_0_cation = 59.5 # cm^2.Siemen.equiv^(-1)
lambda_0_Cl = 76.35 # cm^2.Siemen.equiv^(-1)
z_1 = 2
z_2 = -1

# calculating B and q
B = 50.29*(10**8)*(epsilon*temp)**(-0.5) # cm^(-1).mole^(-1/2).l^(1/2)
q = np.abs(z_1*z_2)*(lambda_0_cation + lambda_0_Cl)/((np.abs(z_1) + np.abs(z_2))*(np.abs(z_2)*lambda_0_cation + np.abs(z_1)*lambda_0_Cl))

# B1 and B2
B_1 = 2.801*(10**6)*np.abs(z_1*z_2)*q/((epsilon*temp)**(3/2)*(1 + math.sqrt(q)))
B_2 = 41.25*(np.abs(z_1) + np.abs(z_2))/(eta*(epsilon*temp)**(1/2))

# %%
# concentration in M
conc = [molar_conc_specific_Ca[i]*10**(-3) for i in range(ndata)]

# specific conductivity in micro Siemen per cm
specific_cond_calc_Ca = specific_cond_model(conc)

# %% [markdown]
# ### NaCl2 + CaCl2

# %%
# bulk conductivity
specific_cond_calc = [specific_cond_calc_Na[i] + specific_cond_calc_Ca[i] for i in range(ndata)]

# making plot comparison of calculated and experimental conductivity of NaCl and CaCl2
fig = plt.figure()
ax = fig.add_subplot(projection='3d')

# plotting
ax.plot3D(molar_conc_specific_Na, molar_conc_specific_Ca, specific_cond_calc, label="Calculations")
ax.plot3D(molar_conc_specific_Na, molar_conc_specific_Ca, specific_cond_calibrated, "b.", markersize=10, label="Data")
ax.set_title('3D conductivity plot')
ax.set_zlabel("Conductivity (uS/cm)")
ax.set_xlabel("NaCl conc. (mM)")
ax.set_ylabel("CaCl2 conc. (mM)")
ax.legend()
plt.show()

# %%
# residuals for NaCl and CaCl2
e = [specific_cond_calc[i] - specific_cond_calibrated[i] for i in range(ndata)]

# making plots of residuals
fig = plt.figure()
ax = fig.add_subplot(projection ='3d')

# plotting
ax.plot3D(molar_conc_specific_Na, molar_conc_specific_Ca, e, "b.")
ax.set_title("Residuals plot")
ax.set_zlabel("Residuals (uS/cm)")
ax.set_xlabel("NaCl conc. (mM)")
ax.set_ylabel("CaCl2 conc. (mM)")
plt.show()

# %% [markdown]
# ## NaCl and LaCl3

# %%
# loading specific conductivity data
specific_data = pd.read_csv("./Data/NaCl_LaCl3_interaction.csv")
molar_conc_specific_Na = specific_data["NaCl conc"]
molar_conc_specific_La = specific_data["LaCl3 conc"]
specific_cond_calibrated = specific_data["Cal bulk cond"]

# number of data points
ndata = len(specific_cond_calibrated)

# %% [markdown]
# ### NaCl

# %%
# constants
temp = 298.16 # K
epsilon = 78.3
eta = 8.903*10**(-3) # poise
lambda_0 = 126.45 # cm^2.Siemen.equiv^(-1)
a = 4*10**(-8) # cm
B = 0.3291*10**8 # cm^(-1).mole^(-1/2).l^(1/2)

# for 1:1 electrolytes
q = 0.5
z_1 = 1
z_2 = -1

# B1 and B2
B_1 = 2.801*10**6*np.abs(z_1*z_2)*q/((epsilon*temp)**(3/2)*(1 + math.sqrt(q)))
B_2 = 41.25*(np.abs(z_1) + np.abs(z_2))/(eta*(epsilon*temp)**(1/2))

# %%
# concentration in M
conc = [molar_conc_specific_Na[i]*10**(-3) for i in range(ndata)]

# specific conductivity in micro Siemen per cm
specific_cond_calc_Na = specific_cond_model(conc)

# %% [markdown]
# ### LaCl3

# %%
# constants
temp = 298.16 # K
epsilon = 78.3
eta = 8.903*10**(-3) # poise
lambda_0 = 145.9 # cm^2.Siemen.equiv^(-1)
a = 4.9*10**(-8) # cm
lambda_0_cation = 69.55 # cm^2.Siemen.equiv^(-1)
lambda_0_Cl = 76.35 # cm^2.Siemen.equiv^(-1)
z_1 = 3
z_2 = -1

# calculating B and q
B = 50.29*(10**8)*(epsilon*temp)**(-0.5) # cm^(-1).mole^(-1/2).l^(1/2)
q = np.abs(z_1*z_2)*(lambda_0_cation + lambda_0_Cl)/((np.abs(z_1) + np.abs(z_2))*(np.abs(z_2)*lambda_0_cation + np.abs(z_1)*lambda_0_Cl))

# B1 and B2
B_1 = 2.801*(10**6)*np.abs(z_1*z_2)*q/((epsilon*temp)**(3/2)*(1 + math.sqrt(q)))
B_2 = 41.25*(np.abs(z_1) + np.abs(z_2))/(eta*(epsilon*temp)**(1/2))

# %%
# concentration in M
conc = [molar_conc_specific_La[i]*10**(-3) for i in range(ndata)]

# specific conductivity in micro Siemen per cm
specific_cond_calc_La = specific_cond_model(conc)

# %%
# bulk conductivity
specific_cond_calc = [specific_cond_calc_Na[i] + specific_cond_calc_La[i] for i in range(ndata)]

# making plot comparison of calculated and experimental conductivity of NaCl and CaCl2
fig = plt.figure()
ax = fig.add_subplot(projection='3d')

# plotting
ax.plot3D(molar_conc_specific_Na, molar_conc_specific_La, specific_cond_calc, label="Calculations")
ax.plot3D(molar_conc_specific_Na, molar_conc_specific_La, specific_cond_calibrated, "b.", markersize=10, label="Data")
ax.set_title('3D conductivity plot')
ax.set_zlabel("Conductivity (uS/cm)")
ax.set_xlabel("NaCl conc. (mM)")
ax.set_ylabel("LaCl3 conc. (mM)")
ax.legend()
plt.show()

# %%
# residuals for NaCl and CaCl2
e = [specific_cond_calc[i] - specific_cond_calibrated[i] for i in range(ndata)]

# making plots of residuals
fig = plt.figure()
ax = fig.add_subplot(projection ='3d')

# plotting
ax.plot3D(molar_conc_specific_Na, molar_conc_specific_La, e, "b.")
ax.set_title("Residuals plot")
ax.set_zlabel("Residuals (uS/cm)")
ax.set_xlabel("NaCl conc. (mM)")
ax.set_ylabel("LaCl3 conc. (mM)")
plt.show()
