# %%
# importing packages
import numpy as np
from matplotlib import pyplot as plt
import math
import scipy.stats as stats
import pandas as pd

# %% [markdown]
# ## Equivalent Conductivity Model

# %% [markdown]
# ![image.png](attachment:c2ebb2e8-3614-46bb-bf3b-ce727358a5ed.png)
#
# Robinson, R. A., & Stokes, R. H. (2002). Electrolyte solutions. Courier Corporation.

# %% [markdown]
# ## Specific Conductivity

# %% [markdown]
# ### NaCl

# %%
# loading NaCl equivalent conductivity data
equiv_data = pd.read_csv("./Data/NaCl_equiv.csv")
molar_conc_equiv = equiv_data["Conc"] # mM
equiv_cond = equiv_data["Equiv_cond"] # cm^2.Siemen.equiv^(-1)

# number of data points
ndata = len(equiv_cond)

# %% [markdown]
# ### Validating NaCl Equivalent Conductivity

# %%
# constants
temp_NaCl = 298.16 # K
epsilon = 78.3
eta = 8.903*10**(-3) # poise
lambda_0_NaCl = 126.45 # cm^2.Siemen.equiv^(-1)
lambda_0_Na = 50.10 # cm^2.Siemen.equiv^(-1)
lambda_0_Cl = 76.35 # cm^2.Siemen.equiv^(-1)
a_NaCl = 4*10**(-8) # cm
z_Na = 1
z_Cl = -1

# concentration in M
conc = [molar_conc_equiv[i]*10**(-3) for i in range(ndata)]

# equivalent conductivity from equation (4)
def cond_calc_ref(conc, temp, epsilon, eta, lambda_0, a, z_1, z_2, lambda_0_cation, lambda_0_anion):
    """
    Calculates equivalent conductivity using equation (7.36) in reference

    Arguments:
        conc: salt concentration in M
        temp: temperature of salt solution in K
        epsilon: dielectric constant
        eta: viscosity of salt solution in poise
        lambda_0: limiting equivalent conductivity of salt in cm^2.Siemen.equiv^(-1)
        a: distance within which no other ions can penetrate in cm
        z_1: valency of cation
        z_2: valency of anion
        lambda_0_cation: limiting equivalent conductivity of cation in cm^2.Siemen.equiv^(-1)
        lambda_0_anion: limiting equivalent conductivity of anion in cm^2.Siemen.equiv^(-1)
    
    Returns:
        equiv_cond_ref: equivalent conductivity values in cm^2.S/equiv
    """
    # calculating B and q
    B = 50.29*(10**8)*(epsilon*temp)**(-0.5)
    q = np.abs(z_1*z_2)*(lambda_0_cation + lambda_0_anion)/((np.abs(z_1) + np.abs(z_2))*(np.abs(z_2)*lambda_0_cation + np.abs(z_1)*lambda_0_anion))
    
    # B1 and B2
    B_1 = 2.801*10**6*np.abs(z_1*z_2)*q/((epsilon*temp)**(3/2)*(1 + math.sqrt(q)))
    B_2 = 41.25*(np.abs(z_1) + np.abs(z_2))/(eta*(epsilon*temp)**(1/2))
    
    # species concentration
    cation_conc = conc
    Cl_conc = [np.abs(z_1)*conc[i] for i in range(len(conc))]

    # ionic strength
    I = np.zeros(len(conc))
    for i in range(len(conc)):
        conc_all = [cation_conc[i], Cl_conc[i]]
        z = [z_1, z_2]
        I[i] = 1/2*(sum(conc_all[j]*z[j]**2 for j in range(len(conc_all))))

    # equivalent conductivity
    equiv_cond_ref = []
    for i in range(len(conc)):
        equiv_cond_ref.append(lambda_0 - ((B_1*lambda_0 + B_2)*math.sqrt(I[i])/(1 + a*B*math.sqrt(I[i]))))
    
    return(equiv_cond_ref)

# making smoother plots
conc_smooth = np.linspace(0, np.max(conc), 100)
equiv_cond_smooth = cond_calc_ref(conc_smooth, temp_NaCl, epsilon, eta, lambda_0_NaCl, a_NaCl, z_Na, z_Cl, lambda_0_Na, lambda_0_Cl)

# %%
# making plot comparison of data values and calculated
plt.plot(conc_smooth, equiv_cond_smooth, "r-", label="Python code")
plt.plot(conc, equiv_cond, "b.", markersize=10, label="Theory calculation")
plt.xlabel("NaCl concentration (M)")
plt.ylabel("Equivalent conductivity (cm^2.S/equiv)")
plt.ylim((90, 130))
plt.legend()
plt.show()

# %% [markdown]
# ### Load Specific Conductivity Data

# %%
# loading NaCl specific conductivity data
specific_data = pd.read_csv("./Data/NaCl.csv")
molar_conc_specific_Na = specific_data["NaCl conc"]
specific_cond_exp_Na = specific_data["NaCl cond"]
specific_cond_calibrated_Na = specific_data["NaCl cond cal"]

# number of data points
ndata2 = len(specific_cond_exp_Na)

# %%
# loading CaCl2 specific conductivity data
specific_data = pd.read_csv("./Data/CaCl2.csv")
molar_conc_specific_Ca_fig = specific_data["CaCl2_conc"]
specific_cond_calibrated_Ca_fig = specific_data["CaCl2_cond_cal"]

# number of data points
ndata_Ca_fig = len(specific_cond_calibrated_Ca_fig)

# %%
# loading LaCl3 specific conductivity data
specific_data = pd.read_csv("./Data/LaCl3_2.csv")
molar_conc_specific_La_fig = specific_data["LaCl3 conc"]
specific_cond_calibrated_La_fig = specific_data["LaCl3 cond cal"]

# number of data points
ndata_La_fig = len(specific_cond_calibrated_La_fig)

# %% [markdown]
# ### Calculating NaCl, CaCl2, and LaCl3 Specific Conductivity

# %%
# concentration in M
conc2 = [molar_conc_specific_Na[i]*10**(-3) for i in range(ndata2)]
conc_Ca_fig = [molar_conc_specific_Ca_fig[i]*10**(-3) for i in range(ndata_Ca_fig)]
conc_La_fig = [molar_conc_specific_La_fig[i]*10**(-3) for i in range(ndata_La_fig)]

# function the predicts specific conductivity
def specific_cond_model(conc, temp, epsilon, eta, lambda_0, a, z_1, z_2, lambda_0_cation, lambda_0_anion):
    """
    Calculates specific conductivity from equivalent conductivity

    Arguments:
        conc: salt concentration in M
        temp: temperature of salt solution in K
        epsilon: dielectric constant
        eta: viscosity of salt solution in poise
        lambda_0: limiting equivalent conductivity of salt in cm^2.Siemen.equiv^(-1)
        a: distance within which no other ions can penetrate in cm
        z_1: valency of cation
        z_2: valency of anion
        lambda_0_cation: limiting equivalent conductivity of cation in cm^2.Siemen.equiv^(-1)
        lambda_0_anion: limiting equivalent conductivity of anion in cm^2.Siemen.equiv^(-1)
    
    Returns:
        specific_cond_calc: specific conductivity values in micro Siemen per cm
    """
    
    # equivalent conductivity
    equiv_cond = cond_calc_ref(conc, temp, epsilon, eta, lambda_0, a, z_1, z_2, lambda_0_cation, lambda_0_anion)
    
    # species concentration
    cation_conc = conc
    Cl_conc = [np.abs(z_1)*conc[i] for i in range(len(conc))]
    
    # converting the concentrations in mM to equivalent per litre
    equiv_conc = [cation_conc[i]*np.abs(z_1) for i in range(len(conc))]
    
    # specific conductivity in Siemen per cm
    specific_cond = []
    for i in range(len(conc)):
        specific_cond.append((equiv_conc[i]/1000)*equiv_cond[i])
    
    # specific conductivity in micro Siemen per cm
    specific_cond_calc = [specific_cond[i]*10**6 for i in range(len(conc))]

    return specific_cond_calc

# NaCl specific conductivity in micro Siemen per cm
specific_cond_calc_Na = specific_cond_model(conc2, temp_NaCl, epsilon, eta, lambda_0_NaCl, a_NaCl, z_Na, z_Cl, lambda_0_Na, lambda_0_Cl)

# CaCl2 constants
lambda_0_CaCl2 = 135.85 # cm^2.Siemen.equiv^(-1)
a_CaCl2 = 4.31*10**(-8) # cm
lambda_0_Ca = 59.5 # cm^2.Siemen.equiv^(-1)
z_Ca = 2

# CaCl2 specific conductivity in micro Siemen per cm
specific_cond_calc_Ca_fig = specific_cond_model(conc_Ca_fig, temp_NaCl, epsilon, eta, lambda_0_CaCl2, a_CaCl2, z_Ca, z_Cl, lambda_0_Ca, lambda_0_Cl)

# LaCl3 constants
lambda_0_LaCl3 = 145.9 # cm^2.Siemen.equiv^(-1)
a_LaCl3 = 4.9*10**(-8) # cm
lambda_0_La = 69.7 # cm^2.Siemen.equiv^(-1)
z_La = 3

# LaCl3 specific conductivity in micro Siemen per cm
specific_cond_calc_La_fig = specific_cond_model(conc_La_fig, temp_NaCl, epsilon, eta, lambda_0_LaCl3, a_LaCl3, z_La, z_Cl, lambda_0_La, lambda_0_Cl)

# %%
# making plot comparison of the calibrated data and the calculated values
fig = plt.figure(figsize=(4,4))
plt.plot(molar_conc_specific_Na, specific_cond_calc_Na, "r-", label="Variant Shedlovsky")
# plt.plot(molar_conc_specific_Na, specific_cond_exp_Na, "b.", markersize=10, label="Data")
plt.plot(molar_conc_specific_Na, specific_cond_calibrated_Na, "s", markersize=5, label="Data")
plt.xlabel("NaCl Concentration (mM)", fontsize=14,fontweight='bold')
plt.ylabel("Conductivity ($\mathbf{\mu}$S/cm)", fontsize=14,fontweight='bold')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.tick_params(direction="in",top=True, right=True)
plt.title("Model Predictions", fontsize=14,fontweight='bold')
plt.legend()
plt.tight_layout()
# plt.savefig("single_model_na.png")
plt.savefig("single_model_na1.png")
# plt.savefig("single_model_na1_uncal.png")
plt.show()

# %%
# making plot comparison of the calibrated data and the calculated values
fig = plt.figure(figsize=(4,4))
plt.plot(molar_conc_specific_Na, specific_cond_calc_Na, "g-", label="NaCl")
plt.plot(molar_conc_specific_Ca_fig, specific_cond_calc_Ca_fig, "b-", label="CaCl$_2$")
# plt.plot(molar_conc_specific_La_fig, specific_cond_calc_La_fig, "r-", label="LaCl$_3$")
plt.plot(molar_conc_specific_Na, specific_cond_calibrated_Na, "s", markersize=5, color="black", label="Data")
plt.plot(molar_conc_specific_Ca_fig, specific_cond_calibrated_Ca_fig, "s", markersize=5, color="black")
# plt.plot(molar_conc_specific_La_fig, specific_cond_calibrated_La_fig, "s", markersize=5, color="black")
plt.xlabel("Concentration (mM)", fontsize=14,fontweight='bold')
plt.ylabel("Conductivity ($\mathbf{\mu}$S/cm)", fontsize=14,fontweight='bold')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.tick_params(direction="in",top=True, right=True)
# plt.title("Theory Predictions", fontsize=16,fontweight='bold')
plt.legend(prop={"weight":"bold"})
plt.tight_layout()
# plt.savefig("single_model_na1.png")
# plt.savefig("single_model_na1_uncal.png")
# plt.savefig("single_model_na_ca_la.png")
plt.savefig("single_model_na_ca.png")
plt.show()

# %%
# residuals of the calibrated data
e_Na_fig = [specific_cond_calc_Na[i]- specific_cond_calibrated_Na[i] for i in range(ndata2)]
e_Ca_fig = [specific_cond_calc_Ca_fig[i] - specific_cond_calibrated_Ca_fig[i] for i in range(ndata_Ca_fig)]
e_La_fig = [specific_cond_calc_La_fig[i] - specific_cond_calibrated_La_fig[i] for i in range(ndata_La_fig)]

# relative error
residuals_percent_Na = [100*e_Na_fig[i]/specific_cond_calibrated_Na[i] for i in range(ndata2)]
residuals_percent_Ca = [100*e_Ca_fig[i]/specific_cond_calibrated_Ca_fig[i] for i in range(ndata_Ca_fig)]
residuals_percent_La = [100*e_La_fig[i]/specific_cond_calibrated_La_fig[i] for i in range(ndata_La_fig)]

# calculate mean absolute prediction errors
residuals_percent_Na_abs = [np.abs(residuals_percent_Na[i]) for i in range(ndata2)]
residuals_percent_Ca_abs = [np.abs(residuals_percent_Ca[i]) for i in range(ndata_Ca_fig)]
residuals_percent_La_abs = [np.abs(residuals_percent_La[i]) for i in range(ndata_La_fig)]
print(np.mean(residuals_percent_Na_abs))
print(np.mean(residuals_percent_Ca_abs))
print(np.mean(residuals_percent_La_abs))

# making plot of residuals of calculated specific conductivity
fig = plt.figure(figsize=(4,4))
plt.plot(molar_conc_specific_Na, residuals_percent_Na, "g.", markersize=10, label="NaCl")
plt.plot(molar_conc_specific_Ca_fig, residuals_percent_Ca, "s", color="blue", label="CaCl$_2$")
# plt.plot(molar_conc_specific_La_fig, residuals_percent_La, "^", color="red", label="LaCl$_3$")
plt.xlabel("Concentration (mM)", fontsize=14,fontweight='bold')
plt.ylabel("Residuals (%)", fontsize=14,fontweight='bold')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.tick_params(direction="in",top=True, right=True)
plt.legend(prop={"weight":"bold"})
plt.tight_layout()
# plt.savefig("single_model_na_ca_la_residuals.png")
plt.savefig("single_model_na_ca_residuals.png")
plt.show()
# Out:
# 0.9621813735402541
# 2.209604978740327
# 1.9129892832924154

# %%
# residuals of the uncalibrated data
residuals = [specific_cond_calc_Na[i] - specific_cond_exp_Na[i] for i in range(ndata2)]

# making plot of residuals of calculated specific conductivity
plt.plot(molar_conc_specific_Na, residuals, "b.")
plt.xlabel("NaCl concentration (mM)")
plt.ylabel("Residuals (uS/cm)")
plt.show()

# %%
# residual fraction of the uncalibrated data
residuals_percent_Na_uncal = [(residuals[i]/specific_cond_exp_Na[i])*100 for i in range(ndata2)]

# residuals percent average
residual_percent_avg = np.average(residuals_percent_Na_uncal)
print(residual_percent_avg)

# visualizing in plot
fig = plt.figure(figsize=(4,4))
plt.plot(molar_conc_specific_Na, residuals_percent_Na_uncal, "b.")
plt.xlabel("NaCl Concentration (mM)", fontsize=14,fontweight='bold')
plt.ylabel("Residuals (%)", fontsize=14,fontweight='bold')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.tick_params(direction="in",top=True, right=True)
plt.title("Instrument Error", fontsize=14,fontweight='bold')
plt.tight_layout()
plt.savefig("single_model_na_residuals.png")
plt.show()
# Out:
# 14.544853819557831

# %% [markdown]
# ### KCl

# %%
# loading KCl equivalent conductivity data
equiv_data = pd.read_csv("./Data/KCl_Equiv.csv")
molar_conc_equiv = equiv_data["KCl Conc"] # mM
equiv_cond = equiv_data["Equiv Cond"] # cm^2.Siemen.equiv^(-1)

# number of data points
ndata = len(equiv_cond)

# %%
# constants
temp_KCl = 298.16 # K
epsilon = 78.3
eta = 8.903*10**(-3) # poise
lambda_0_KCl = 149.85 # cm^2.Siemen.equiv^(-1)
lambda_0_K = 73.50 # cm^2.Siemen.equiv^(-1)
lambda_0_Cl = 76.35 # cm^2.Siemen.equiv^(-1)
a_KCl = 4*10**(-8) # cm
z_K = 1 # cation valency
z_Cl = -1 # anion valency

# concentration in M
conc = [molar_conc_equiv[i]*10**(-3) for i in range(ndata)]

# making smoother plots
conc_smooth = np.linspace(0, np.max(conc), 100)
equiv_cond_smooth = cond_calc_ref(conc_smooth, temp_KCl, epsilon, eta, lambda_0_KCl, a_KCl, z_K, z_Cl, lambda_0_K, lambda_0_Cl)

# prediction accuracy
prediction_acc = [equiv_cond_smooth[i]/equiv_cond[i] for i in range(ndata)]
prediction_acc_avg = np.mean(prediction_acc)
# print(prediction_acc_avg)
# print(prediction_acc)

# %%
# making plot comparison of data values and calculated
plt.plot(conc_smooth, equiv_cond_smooth, "r-", label="Python code")
plt.plot(conc, equiv_cond, "b.", markersize=10, label="Theory calculation")
plt.xlabel("KCl concentration (M)", fontsize=12,fontweight='bold')
plt.ylabel("Equivalent conductivity (cm$\mathbf{^2}$.S/equiv)", fontsize=12,fontweight='bold')
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.tick_params(direction="in",top=True, right=True)
plt.title("Python code predictions", fontsize=16,fontweight='bold')
plt.ylim((120, 160))
plt.legend()
plt.show()

# %% [markdown]
# ### Load KCl Data

# %%
# loading KCl specific conductivity data
specific_data_probe1 = pd.read_csv("./Data/KCl_Probe1.csv")
specific_data_probe2 = pd.read_csv("./Data/KCl_Probe2.csv")
specific_data_probe3 = pd.read_csv("./Data/KCl_Probe3.csv")
molar_conc_specific = specific_data_probe1["KCl Conc"]
specific_cond_exp1 = specific_data_probe1["Cond"]
specific_cond_calibrated_exp1 = specific_data_probe1["Cond_cal"]
specific_cond_exp2 = specific_data_probe2["Cond"]
specific_cond_exp3 = specific_data_probe3["Cond"]

# number of data points
ndata2 = len(specific_cond_exp1)

# %%
# concentration in M
conc2 = [molar_conc_specific[i]*10**(-3) for i in range(ndata2)]

# specific conductivity in micro Siemen per cm
specific_cond_calc = specific_cond_model(conc2, temp_KCl, epsilon, eta, lambda_0_KCl, a_KCl, z_K, z_Cl, lambda_0_K, lambda_0_Cl)

# %% [markdown]
# ### KCl Probe 1

# %%
# making plot comparison of probe 1 calibrated data and the calculated values
fig = plt.figure(figsize=(4,4))
# plt.plot(molar_conc_specific, specific_cond_calc, "r-", label="Variant Shedlovsky")
# plt.plot(molar_conc_specific, specific_cond_exp1, "b.", markersize=10, label="Data")
# plt.plot(molar_conc_specific, specific_cond_calibrated_exp1, "s", markersize=5, label="Calibrated Data")
plt.plot(molar_conc_specific, specific_cond_calc, "r-", label="KCl")
plt.plot(molar_conc_specific_Na, specific_cond_calc_Na, "g-", label="NaCl")
plt.plot(molar_conc_specific_Ca_fig, specific_cond_calc_Ca_fig, "b-", label="CaCl$_{\mathbf{2}}$")
plt.plot(molar_conc_specific_Na, specific_cond_calibrated_Na, "s", markersize=5, color="black", label="Data")
plt.plot(molar_conc_specific, specific_cond_calibrated_exp1, "s", markersize=5, color="black")
plt.plot(molar_conc_specific_Ca_fig, specific_cond_calibrated_Ca_fig, "s", markersize=5, color="black")
# plt.xlabel("KCl Concentration (mM)", fontsize=14,fontweight='bold')
plt.xlabel("Concentration (mM)", fontsize=14,fontweight='bold')
plt.ylabel("Conductivity ($\mathbf{\mu}$S/cm)", fontsize=14,fontweight='bold')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.tick_params(direction="in",top=True, right=True)
# plt.title("Model Predictions", fontsize=14,fontweight='bold')
plt.legend(prop={"weight":"bold"})
plt.tight_layout()
# plt.savefig("single_model_k1_uncal.png")
plt.savefig("single_model_k_na_ca.png")
plt.show()

# %%
# residuals of the calibrated probe 1 data
e_K_fig = [specific_cond_calc[i] - specific_cond_calibrated_exp1[i] for i in range(ndata2)]

# relative error
residuals_percent_K = [100*e_K_fig[i]/specific_cond_calibrated_exp1[i] for i in range(ndata2)]

# calculate mean absolute prediction errors
residuals_percent_K_abs = [np.abs(residuals_percent_K[i]) for i in range(ndata2)]
print(np.mean(residuals_percent_K_abs))

# making plot of residuals of calculated specific conductivity
fig = plt.figure(figsize=(4,4))
plt.plot(molar_conc_specific_Na, residuals_percent_Na, "g.", markersize=10, label="NaCl")
plt.plot(molar_conc_specific_Ca_fig, residuals_percent_Ca, "s", color="blue", label="CaCl$_2$")
plt.plot(molar_conc_specific, residuals_percent_K, "^", color="red", label="KCl")
plt.xlabel("Concentration (mM)", fontsize=14,fontweight='bold')
plt.ylabel("Residuals (%)", fontsize=14,fontweight='bold')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.tick_params(direction="in",top=True, right=True)
plt.legend(prop={"weight":"bold"})
plt.tight_layout()
plt.savefig("single_model_na_ca_k_residuals.png")
plt.show()
# Out:
# 1.6706557115771483

# %%
# making plot comparison of probe 1 uncalibrated data and the calculated values
fig = plt.figure(figsize=(4,4))
plt.plot(molar_conc_specific, specific_cond_calc, "r-", label="KCl")
plt.plot(molar_conc_specific_Na, specific_cond_calc_Na, "g-", label="NaCl")
plt.plot(molar_conc_specific, specific_cond_exp1, "b.", markersize=10, label="KCl Data")
plt.plot(molar_conc_specific_Na, specific_cond_exp_Na, "s", color="black", markersize=5, label="NaCl Data")
plt.xlabel("Concentration (mM)", fontsize=14,fontweight='bold')
plt.ylabel("Conductivity ($\mathbf{\mu}$S/cm)", fontsize=14,fontweight='bold')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.tick_params(direction="in",top=True, right=True)
plt.legend(prop={"weight":"bold"})
plt.tight_layout()
plt.savefig("single_model_na_k_uncal.png")
plt.show()

# %%
# residuals of the uncalibrated probe 1 data
residuals_uncal = [specific_cond_calc[i] - specific_cond_exp1[i] for i in range(ndata2)]

# making plot of residuals of calculated specific conductivity
plt.plot(molar_conc_specific, residuals_uncal, "b.")
plt.xlabel("KCl concentration (mM)")
plt.ylabel("Residuals (uS/cm)")
plt.show()

# %%
# residual fraction of the uncalibrated probe 1 data
residuals_percent_uncal = [(residuals_uncal[i]/specific_cond_exp1[i])*100 for i in range(ndata2)]
residual_percent_avg = np.average(residuals_percent_uncal)
print(residual_percent_avg)

# visualizing in plot
fig = plt.figure(figsize=(4,4))
plt.plot(molar_conc_specific, residuals_percent_uncal, "r.", label="KCl")
plt.plot(molar_conc_specific_Na, residuals_percent_Na_uncal, "g.", label="NaCl")
plt.xlabel("Concentration (mM)", fontsize=14,fontweight='bold')
plt.ylabel("Residuals (%)", fontsize=14,fontweight='bold')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.tick_params(direction="in",top=True, right=True)
# plt.title("Instrument Error", fontsize=14,fontweight='bold')
plt.legend(prop={"weight":"bold"})
plt.tight_layout()
plt.savefig("single_model_na_k_residuals.png")
plt.show()
# Out:
# 13.649056128559133

# %% [markdown]
# ### KCl Probe 2

# %%
# making plot comparison of probe 2 uncalibrated data and the calculated values
fig = plt.figure(figsize=(4,4))
plt.plot(molar_conc_specific, specific_cond_calc, "r-", label="Theory")
plt.plot(molar_conc_specific, specific_cond_exp2, "b.", markersize=10, label="Data")
plt.xlabel("KCl concentration (mM)", fontsize=16,fontweight='bold')
plt.ylabel("Conductivity (uS/cm)", fontsize=16,fontweight='bold')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.tick_params(direction="in",top=True, right=True)
plt.title("Theory Predictions", fontsize=16,fontweight='bold')
plt.legend()
plt.show()

# %%
# residuals of the uncalibrated probe 2 data
residuals = [specific_cond_calc[i] - specific_cond_exp2[i] for i in range(ndata2)]

# making plot of residuals of calculated specific conductivity
plt.plot(molar_conc_specific, residuals, "b.")
plt.xlabel("KCl concentration (mM)")
plt.ylabel("Residuals (uS/cm)")
plt.show()

# %%
# residual fraction of the uncalibrated probe 2 data
residuals_percent = [(residuals[i]/specific_cond_exp2[i])*100 for i in range(ndata2)]
residual_percent_avg = np.average(residuals_percent)
print(residual_percent_avg)

# visualizing in plot
fig = plt.figure(figsize=(4,4))
plt.plot(molar_conc_specific, residuals_percent, "b.")
plt.xlabel("KCl concentration (mM)", fontsize=16,fontweight='bold')
plt.ylabel("Residuals/Experiments (%)", fontsize=16,fontweight='bold')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.tick_params(direction="in",top=True, right=True)
plt.title("Instrument Error", fontsize=16,fontweight='bold')
plt.show()
# Out:
# 11.547789999491929

# %% [markdown]
# ### KCl Probe 3

# %%
# making plot comparison of probe 3 uncalibrated data and the calculated values
fig = plt.figure(figsize=(4,4))
plt.plot(molar_conc_specific, specific_cond_calc, "r-", label="Theory")
plt.plot(molar_conc_specific, specific_cond_exp3, "b.", markersize=10, label="Data")
plt.xlabel("KCl concentration (mM)", fontsize=16,fontweight='bold')
plt.ylabel("Conductivity (uS/cm)", fontsize=16,fontweight='bold')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.tick_params(direction="in",top=True, right=True)
plt.title("Theory Predictions", fontsize=16,fontweight='bold')
plt.legend()
plt.show()

# %%
# residuals of the uncalibrated probe 3 data
residuals = [specific_cond_calc[i] - specific_cond_exp3[i] for i in range(ndata2)]

# making plot of residuals of calculated specific conductivity
plt.plot(molar_conc_specific, residuals, "b.")
plt.xlabel("KCl concentration (mM)")
plt.ylabel("Residuals (uS/cm)")
plt.show()

# %%
# residual fraction of the uncalibrated probe 3 data
residuals_percent = [(residuals[i]/specific_cond_exp3[i])*100 for i in range(ndata2)]
residual_percent_avg = np.average(residuals_percent)
print(residual_percent_avg)

# visualizing in plot
fig = plt.figure(figsize=(4,4))
plt.plot(molar_conc_specific, residuals_percent, "b.")
plt.xlabel("KCl concentration (mM)", fontsize=16,fontweight='bold')
plt.ylabel("Residuals/Experiments (%)", fontsize=16,fontweight='bold')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.tick_params(direction="in",top=True, right=True)
plt.title("Instrument Error", fontsize=16,fontweight='bold')
plt.show()
# Out:
# 11.938732322109008

# %% [markdown]
# ### CaCl2

# %%
# loading LaCl3 equivalent conductivity data
equiv_data = pd.read_csv("./Data/CaCl2_equiv.csv")
molar_conc_equiv = equiv_data["CaCl2_conc"] # mM
equiv_cond = equiv_data["CaCl2_equiv_cond"] # cm^2.Siemen.equiv^(-1)

# number of data points
ndata = len(equiv_cond)

# %%
# constants
temp_CaCl2 = 298.16 # K
epsilon = 78.3
eta = 8.903*10**(-3) # poise
lambda_0_CaCl2 = 135.85 # cm^2.Siemen.equiv^(-1)
a_CaCl2 = 4.31*10**(-8) # cm
lambda_0_Ca = 59.5 # cm^2.Siemen.equiv^(-1)
lambda_0_Cl = 76.35 # cm^2.Siemen.equiv^(-1)
z_Ca = 2
z_Cl = -1

# concentration in M
conc = [molar_conc_equiv[i]*10**(-3) for i in range(ndata)]

# making smoother plots
conc_smooth = np.linspace(0, np.max(conc), 100)
equiv_cond_smooth = cond_calc_ref(conc_smooth, temp_CaCl2, epsilon, eta, lambda_0_CaCl2, a_CaCl2, z_Ca, z_Cl, lambda_0_Ca, lambda_0_Cl)

# %%
# making plot comparison of data values and calculated
plt.plot(conc_smooth, equiv_cond_smooth, "r-", label="Python code")
plt.plot(conc, equiv_cond, "b.", markersize=10, label="Theory calculation")
plt.xlabel("CaCl2 concentration (M)")
plt.ylabel("Equivalent conductivity (cm^2.S/equiv)")
plt.ylim((70, 150))
plt.legend()
plt.show()

# %% [markdown]
# ### LaCl3

# %%
# loading LaCl3 equivalent conductivity data
equiv_data = pd.read_csv("./Data/LaCl3_equiv.csv")
molar_conc_equiv = equiv_data["Conc"] # mM
equiv_cond = equiv_data["Equiv_cond"] # cm^2.Siemen.equiv^(-1)

# number of data points
ndata = len(equiv_cond)

# %%
# constants
temp_LaCl3 = 298.16 # K
epsilon = 78.3
eta = 8.903*10**(-3) # poise
lambda_0_LaCl3 = 145.9 # cm^2.Siemen.equiv^(-1)
a_LaCl3 = 4.9*10**(-8) # cm
lambda_0_La = 69.7 # cm^2.Siemen.equiv^(-1)
lambda_0_Cl = 76.35 # cm^2.Siemen.equiv^(-1)
z_La = 3
z_Cl = -1

# concentration in M
conc = [molar_conc_equiv[i]*10**(-3) for i in range(ndata)]

# making smoother plots
conc_smooth = np.linspace(0, np.max(conc), 100)
equiv_cond_smooth = cond_calc_ref(conc_smooth, temp_LaCl3, epsilon, eta, lambda_0_LaCl3, a_LaCl3, z_La, z_Cl, lambda_0_La, lambda_0_Cl)

# %%
# making plot comparison of data values and calculated
plt.plot(conc_smooth, equiv_cond_smooth, "r-", label="Python code")
plt.plot(conc, equiv_cond, "b.", markersize=10, label="Theory calculation")
plt.xlabel("LaCl3 concentration (M)")
plt.ylabel("Equivalent conductivity (cm^2.S/equiv)")
plt.ylim((70, 150))
plt.legend()
plt.show()

# %% [markdown]
# ### NaCl and CaCl2

# %%
# loading NaCl and CaCl2 experiment data
data = pd.read_csv("./Data/NaCl_CaCl2_rearranged.csv")
NaCl_conc = data["NaCl conc"]
NaCl_conc12 = data["NaCl conc2"]
NaCl_conc13 = data["NaCl conc3"]
CaCl2_conc = data["CaCl2 conc"]
CaCl2_conc12 = data["CaCl2 conc2"]
CaCl2_conc13 = data["CaCl2 conc3"]
cond_exp = data["Cal bulk cond"]
cond_exp12 = data["Cal bulk cond2"]
cond_exp13 = data["Cal bulk cond3"]

# number of data points
ndata = len(cond_exp)

# %% [markdown]
# #### NaCl

# %%
# constants
temp_NaCl_CaCl2 = 298.16 # K
epsilon = 78.3
eta = 8.903*10**(-3) # poise
a_NaCl_CaCl2 = (a_NaCl + a_CaCl2)/2 # cm

# %%
# concentration in M
conc = [NaCl_conc[i]*10**(-3) for i in range(ndata)]
conc12 = [NaCl_conc12[i]*10**(-3) for i in range(ndata)]
conc13 = [NaCl_conc13[i]*10**(-3) for i in range(ndata)]

# specific conductivity in micro Siemen per cm
specific_cond_nacl = specific_cond_model(conc, temp_NaCl_CaCl2, epsilon, eta, lambda_0_NaCl, a_NaCl_CaCl2, z_Na, z_Cl, lambda_0_Na, lambda_0_Cl)
specific_cond_nacl_12 = specific_cond_model(conc12, temp_NaCl_CaCl2, epsilon, eta, lambda_0_NaCl, a_NaCl_CaCl2, z_Na, z_Cl, lambda_0_Na, lambda_0_Cl)
specific_cond_nacl_13 = specific_cond_model(conc13, temp_NaCl_CaCl2, epsilon, eta, lambda_0_NaCl, a_NaCl_CaCl2, z_Na, z_Cl, lambda_0_Na, lambda_0_Cl)

# %% [markdown]
# #### CaCl2

# %%
# concentration in M
conc21 = [CaCl2_conc[i]*10**(-3) for i in range(ndata)]
conc22 = [CaCl2_conc12[i]*10**(-3) for i in range(ndata)]
conc23 = [CaCl2_conc13[i]*10**(-3) for i in range(ndata)]

# specific conductivity in micro Siemen per cm
specific_cond_cacl2 = specific_cond_model(conc21, temp_NaCl_CaCl2, epsilon, eta, lambda_0_CaCl2, a_NaCl_CaCl2, z_Ca, z_Cl, lambda_0_Ca, lambda_0_Cl)
specific_cond_cacl2_12 = specific_cond_model(conc22, temp_NaCl_CaCl2, epsilon, eta, lambda_0_CaCl2, a_NaCl_CaCl2, z_Ca, z_Cl, lambda_0_Ca, lambda_0_Cl)
specific_cond_cacl2_13 = specific_cond_model(conc23, temp_NaCl_CaCl2, epsilon, eta, lambda_0_CaCl2, a_NaCl_CaCl2, z_Ca, z_Cl, lambda_0_Ca, lambda_0_Cl)

# %% [markdown]
# #### NaCl2 + CaCl2

# %%
# bulk conductivity
specific_cond = [specific_cond_nacl[i] + specific_cond_cacl2[i] for i in range(ndata)]
specific_cond_12 = [specific_cond_nacl_12[i] + specific_cond_cacl2_12[i] for i in range(ndata)]
specific_cond_13 = [specific_cond_nacl_13[i] + specific_cond_cacl2_13[i] for i in range(ndata)]

# making plot comparison of calculated and experimental conductivity of NaCl and CaCl2
fig = plt.figure()
ax = fig.add_subplot(projection='3d')

# plotting
ax.plot3D(NaCl_conc, CaCl2_conc, specific_cond, color="red", label="Theory")
ax.plot3D(NaCl_conc12, CaCl2_conc12, specific_cond_12, color="red")
ax.plot3D(NaCl_conc13, CaCl2_conc13, specific_cond_13, color="red")
ax.plot3D(NaCl_conc, CaCl2_conc, cond_exp, "b.", markersize=10, label="Data")
ax.plot3D(NaCl_conc12, CaCl2_conc12, cond_exp12, "b.", markersize=10)
ax.plot3D(NaCl_conc13, CaCl2_conc13, cond_exp13, "b.", markersize=10)
ax.set_xlim(50, 0)
ax.set_ylim(0, 50)
ax.tick_params(axis='x', labelsize=10)
ax.tick_params(axis='y', labelsize=10)
ax.tick_params(axis='z', labelsize=10)
ax.tick_params(direction="in",top=True, right=True)
ax.set_title('3D Conductivity Plot', fontsize=12,fontweight='bold')
ax.set_zlabel("Conductivity ($\mathbf{\mu}$S/cm)", fontsize=12,fontweight='bold')
ax.set_xlabel("NaCl Conc. (mM)", fontsize=12,fontweight='bold')
ax.set_ylabel("CaC$\mathbf{l_2}$ Conc. (mM)", fontsize=12,fontweight='bold')
ax.legend()
plt.tight_layout()
# plt.savefig("single_model_na_ca.png")
plt.show()

# %%
# residuals for NaCl and CaCl2
e = [specific_cond[i] - cond_exp[i] for i in range(ndata)]
e12 = [specific_cond_12[i] - cond_exp12[i] for i in range(ndata)]
e13 = [specific_cond_13[i] - cond_exp13[i] for i in range(ndata)]

# making plots of residuals
fig = plt.figure()
ax = fig.add_subplot(projection ='3d')

# plotting
ax.plot3D(NaCl_conc, CaCl2_conc, e, "r.")
ax.plot3D(NaCl_conc12, CaCl2_conc12, e12, "b.")
ax.plot3D(NaCl_conc13, CaCl2_conc13, e13, ".", color="black")
ax.set_xlim(50, 0)
ax.set_ylim(0, 50)
ax.set_zlim(0, 600)
ax.tick_params(axis='x', labelsize=10)
ax.tick_params(axis='y', labelsize=10)
ax.tick_params(axis='z', labelsize=10)
ax.tick_params(direction="in",top=True, right=True)
ax.set_title("Residuals Plot", fontsize=12,fontweight='bold')
ax.set_zlabel("Residuals ($\mathbf{\mu}$S/cm)", fontsize=12,fontweight='bold')
ax.set_xlabel("NaCl Conc. (mM)", fontsize=12,fontweight='bold')
ax.set_ylabel("CaC$\mathbf{l_2}$ Conc. (mM)", fontsize=12,fontweight='bold')
plt.tight_layout()
# plt.savefig("residuals_single_model_na_ca.png")
plt.show()

# %%
# residuals fraction
residuals_percent = [100*e[i]/cond_exp[i] for i in range(ndata)]
residuals_percent12 = [100*e12[i]/cond_exp12[i] for i in range(ndata)]
residuals_percent13 = [100*e13[i]/cond_exp13[i] for i in range(ndata)]

# absolute value of relative error
residuals_percent_abs = [np.abs(residuals_percent[i]) for i in range(ndata)]
residuals_percent2_abs = [np.abs(residuals_percent12[i]) for i in range(ndata)]
residuals_percent3_abs = [np.abs(residuals_percent13[i]) for i in range(ndata)]
print(np.mean(residuals_percent_abs))
print(np.mean(residuals_percent2_abs))
print(np.mean(residuals_percent3_abs))


# making plot
fig = plt.figure()
ax = fig.add_subplot(projection ='3d')

# plotting
ax.plot3D(NaCl_conc, CaCl2_conc, residuals_percent, "r.")
ax.plot3D(NaCl_conc12, CaCl2_conc12, residuals_percent12, "b.")
ax.plot3D(NaCl_conc13, CaCl2_conc13, residuals_percent13, ".", color="black")
ax.set_xlim(50, 0)
ax.set_ylim(0, 50)
ax.tick_params(axis='x', labelsize=10)
ax.tick_params(axis='y', labelsize=10)
ax.tick_params(axis='z', labelsize=10)
ax.tick_params(direction="in",top=True, right=True)
ax.set_title("Relative Error", fontsize=12,fontweight='bold')
ax.set_zlabel("Residuals (%)", fontsize=12,fontweight='bold')
ax.set_xlabel("NaCl Conc. (mM)", fontsize=12,fontweight='bold')
ax.set_ylabel("CaC$\mathbf{l_2}$ Conc. (mM)", fontsize=12,fontweight='bold')
plt.tight_layout()
# plt.savefig("proportion_single_model_na_ca.png")
plt.show()
# Out:
# 2.7865910248423167
# 0.8887307854883193
# 2.6357674864908147

# %% [markdown]
# ### NaCl and LaCl3

# %%
# loading NaCl and LaCl3 experiment data
data4 = pd.read_csv("./Data/NaCl_LaCl3_rearranged.csv")
NaCl_conc2 = data4["NaCl conc"]
NaCl_conc22 = data4["NaCl conc2"]
NaCl_conc23 = data4["NaCl conc3"]
LaCl3_conc = data4["LaCl3 conc"]
LaCl3_conc12 = data4["LaCl3 conc2"]
LaCl3_conc13 = data4["LaCl3 conc3"]
cond_exp2 = data4["Cal bulk cond"]
cond_exp22 = data4["Cal bulk cond2"]
cond_exp23 = data4["Cal bulk cond3"]

# number of data points
ndata = len(cond_exp2)

# %% [markdown]
# #### NaCl

# %%
# constants
temp_NaCl_LaCl3 = 298.16 # K
epsilon = 78.3
eta = 8.903*10**(-3) # poise
a_NaCl_LaCl3 = (a_NaCl + a_LaCl3)/2 # cm

# %%
# concentration in M
conc_nacl_21 = [NaCl_conc2[i]*10**(-3) for i in range(ndata)]
conc_nacl_22 = [NaCl_conc22[i]*10**(-3) for i in range(ndata)]
conc_nacl_23 = [NaCl_conc23[i]*10**(-3) for i in range(ndata)]

# specific conductivity in micro Siemen per cm
specific_cond_nacl_21 = specific_cond_model(conc_nacl_21, temp_NaCl_LaCl3, epsilon, eta, lambda_0_NaCl, a_NaCl_LaCl3, z_Na, z_Cl, lambda_0_Na, 
                                            lambda_0_Cl)
specific_cond_nacl_22 = specific_cond_model(conc_nacl_22, temp_NaCl_LaCl3, epsilon, eta, lambda_0_NaCl, a_NaCl_LaCl3, z_Na, z_Cl, lambda_0_Na, 
                                            lambda_0_Cl)
specific_cond_nacl_23 = specific_cond_model(conc_nacl_23, temp_NaCl_LaCl3, epsilon, eta, lambda_0_NaCl, a_NaCl_LaCl3, z_Na, z_Cl, lambda_0_Na, 
                                            lambda_0_Cl)

# %% [markdown]
# #### LaCl3

# %%
# concentration in M
conc_lacl3_11 = [LaCl3_conc[i]*10**(-3) for i in range(ndata)]
conc_lacl3_12 = [LaCl3_conc12[i]*10**(-3) for i in range(ndata)]
conc_lacl3_13 = [LaCl3_conc13[i]*10**(-3) for i in range(ndata)]

# specific conductivity in micro Siemen per cm
specific_cond_lacl3_11 = specific_cond_model(conc_lacl3_11, temp_NaCl_LaCl3, epsilon, eta, lambda_0_LaCl3, a_NaCl_LaCl3, z_La, z_Cl, lambda_0_La, 
                                             lambda_0_Cl)
specific_cond_lacl3_12 = specific_cond_model(conc_lacl3_12, temp_NaCl_LaCl3, epsilon, eta, lambda_0_LaCl3, a_NaCl_LaCl3, z_La, z_Cl, lambda_0_La, 
                                             lambda_0_Cl)
specific_cond_lacl3_13 = specific_cond_model(conc_lacl3_13, temp_NaCl_LaCl3, epsilon, eta, lambda_0_LaCl3, a_NaCl_LaCl3, z_La, z_Cl, lambda_0_La, 
                                             lambda_0_Cl)

# %%
# bulk conductivity
specific_cond_21 = [specific_cond_nacl_21[i] + specific_cond_lacl3_11[i] for i in range(ndata)]
specific_cond_22 = [specific_cond_nacl_22[i] + specific_cond_lacl3_12[i] for i in range(ndata)]
specific_cond_23 = [specific_cond_nacl_23[i] + specific_cond_lacl3_13[i] for i in range(ndata)]

# making plot comparison of calculated and experimental conductivity of NaCl and CaCl2
fig = plt.figure()
ax = fig.add_subplot(projection='3d')

# plotting
ax.plot3D(NaCl_conc2, LaCl3_conc, specific_cond_21, color="red", label="Theory")
ax.plot3D(NaCl_conc22, LaCl3_conc12, specific_cond_22, color="red")
ax.plot3D(NaCl_conc23, LaCl3_conc13, specific_cond_23, color="red")
ax.plot3D(NaCl_conc2, LaCl3_conc, cond_exp2, "b.", markersize=10, label="Data")
ax.plot3D(NaCl_conc22, LaCl3_conc12, cond_exp22, "b.", markersize=10)
ax.plot3D(NaCl_conc23, LaCl3_conc13, cond_exp23, "b.", markersize=10)
ax.set_xlim(60, 0)
ax.set_ylim(0, 20)
ax.tick_params(axis='x', labelsize=10)
ax.tick_params(axis='y', labelsize=10)
ax.tick_params(axis='z', labelsize=10)
ax.tick_params(direction="in",top=True, right=True)
ax.set_title('3D Conductivity Plot', fontsize=12,fontweight='bold')
ax.set_zlabel("Conductivity ($\mathbf{\mu}$S/cm)", fontsize=12,fontweight='bold')
ax.set_xlabel("NaCl Conc. (mM)", fontsize=12,fontweight='bold')
ax.set_ylabel("LaC$\mathbf{l_3}$ Conc. (mM)", fontsize=12,fontweight='bold')
ax.legend()
plt.tight_layout()
# plt.savefig("single_model_na_la.png")
plt.show()

# %%
# residuals for NaCl and CaCl2
e21 = [specific_cond_21[i] - cond_exp2[i] for i in range(ndata)]
e22 = [specific_cond_22[i] - cond_exp22[i] for i in range(ndata)]
e23 = [specific_cond_23[i] - cond_exp23[i] for i in range(ndata)]

# making plots of residuals
fig = plt.figure()
ax = fig.add_subplot(projection ='3d')

# plotting
ax.plot3D(NaCl_conc2, LaCl3_conc, e21, "r.")
ax.plot3D(NaCl_conc22, LaCl3_conc12, e22, "b.")
ax.plot3D(NaCl_conc23, LaCl3_conc13, e23, ".", color="black")
ax.set_xlim(60, 0)
ax.set_ylim(0, 20)
ax.set_zlim(0, 600)
ax.tick_params(axis='x', labelsize=10)
ax.tick_params(axis='y', labelsize=10)
ax.tick_params(axis='z', labelsize=10)
ax.tick_params(direction="in",top=True, right=True)
ax.set_title("Residuals Plot", fontsize=12,fontweight='bold')
ax.set_zlabel("Residuals ($\mathbf{\mu}$S/cm)", fontsize=12,fontweight='bold')
ax.set_xlabel("NaCl Conc. (mM)", fontsize=12,fontweight='bold')
ax.set_ylabel("LaC$\mathbf{l_3}$ Conc. (mM)", fontsize=12,fontweight='bold')
plt.tight_layout()
# plt.savefig("residuals_single_model_na_la.png")
plt.show()

# %%
# residuals fraction
residuals_percent21 = [100*e21[i]/cond_exp2[i] for i in range(ndata)]
residuals_percent22 = [100*e22[i]/cond_exp22[i] for i in range(ndata)]
residuals_percent23 = [100*e23[i]/cond_exp23[i] for i in range(ndata)]

# absolute value of relative error
residuals_percent_abs = [np.abs(residuals_percent21[i]) for i in range(ndata)]
residuals_percent2_abs = [np.abs(residuals_percent22[i]) for i in range(ndata)]
residuals_percent3_abs = [np.abs(residuals_percent23[i]) for i in range(ndata)]
print(np.mean(residuals_percent_abs))
print(np.mean(residuals_percent2_abs))
print(np.mean(residuals_percent3_abs))

# making plot
fig = plt.figure()
ax = fig.add_subplot(projection ='3d')

# plotting
ax.plot3D(NaCl_conc2, LaCl3_conc, residuals_percent21, "r.")
ax.plot3D(NaCl_conc22, LaCl3_conc12, residuals_percent22, "b.")
ax.plot3D(NaCl_conc23, LaCl3_conc13, residuals_percent23, ".", color="black")
ax.set_xlim(60, 0)
ax.set_ylim(0, 20)
ax.tick_params(axis='x', labelsize=10)
ax.tick_params(axis='y', labelsize=10)
ax.tick_params(axis='z', labelsize=10)
ax.tick_params(direction="in",top=True, right=True)
ax.set_title("Relative Error", fontsize=12,fontweight='bold')
ax.set_zlabel("Residuals (%)", fontsize=12,fontweight='bold')
ax.set_xlabel("NaCl Conc. (mM)", fontsize=12,fontweight='bold')
ax.set_ylabel("LaC$\mathbf{l_3}$ Conc. (mM)", fontsize=12,fontweight='bold')
plt.tight_layout()
# plt.savefig("proportion_single_model_na_la.png")
plt.show()
# Out:
# 2.125384853139745
# 4.2613093160673525
# 1.2663909195761114
