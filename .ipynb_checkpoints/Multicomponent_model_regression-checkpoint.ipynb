# %% [markdown]
# ## Import Packages

# %%
# importing packages
import pyomo.environ as pyo
import numpy as np
from matplotlib import pyplot as plt
import math
import scipy.stats as stats
from scipy.optimize import fsolve, bisect, minimize
import pandas as pd
import conductivity as cd
from scipy.optimize import brute
from scipy.optimize import differential_evolution

# %% [markdown]
# ## NaCl Data

# %%
# loading NaCl specific conductivity data
specific_data = pd.read_csv("./Data/NaCl.csv")
salt_conc = specific_data["NaCl conc"]
cond_exp = specific_data["NaCl cond cal"]

# number of data points
ndata = len(cond_exp)

# %%
# loading CaCl2 specific conductivity data
specific_data_Ca = pd.read_csv("./Data/CaCl2.csv")
salt_conc_Ca = specific_data_Ca["CaCl2_conc"]
cond_exp_Ca = specific_data_Ca["CaCl2_cond_cal"]

# number of data points
ndata_Ca = len(cond_exp_Ca)

# %% [markdown]
# ## Constants

# %%
# temperature
temp = 298.15

# diffusion coefficients at infinite dilution
Diff_Na = 1.334 * 10**(-9)
Diff_Cl = 2.032 * 10**(-9)
Diff_Ca = 0.792 * 10**(-9)
Diff_La = 0.619 * 10**(-9)
diffusion_coeff = [Diff_Na, Diff_Cl] 
diffusion_coeff_Ca = [Diff_Ca, Diff_Cl] 

# valencies
z_Na = 1
z_Cl = -1
z_Ca = 2
z_La = 3
valency = [z_Na, z_Cl]
valency_Ca = [z_Ca, z_Cl]

# measuring voltage and probe distance
voltage = 25 * 10**(-3)
distance = 9 * 10**(-6)

# solvent viscosity
eta_msa = 0.89 * 10**(-3)

# electric field
E_field = voltage/distance

# relative permittivity
epsilon = 78.4

# %%
def msa_transport(valency, diameters, diff_coeff, T, sensor_voltage, probe_distance, eta, epsilon,
                           salt_1_conc, salt_2_conc=None, salt_3_conc=None):
    """Calculates the specific conductivity of single-salt, two-salt, and three-salt solutions

    Argument:
        valency: list of the valency of ions with cations listed before anions in decreasing order
        diameters: list of the corresponding hard sphere diameter of the ions in pm
        diff_coeff: list of the corresponding diffusion coefficient of the ions at infinite dilution in m^2/s
        T: integer or float value of the temperature in K
        sensor_voltage: integer or float value of the sensor measuring voltage in V
        probe_distance: integer or float value of the distance between the probes in m
        eta: integer or float value of the viscosity in Pa.s
        epsilon: integer or float value of the relative permittivity
        salt_1_conc = Pandas series or list of the concentration of salt 1 in mM
        salt_2_conc = Pandas series or list of the concentration of salt 2 in mM
        salt_3_conc = Pandas series or list of the concentration of salt 3 in mM

    Returns:
        all_cond_calc_con: specific conductivity of the salt solution in micro.S/cm"""

    # constants
    Avogadros_num = 6.022 * 10**23 # Avogadro's constant
    k_B = 1.381 * 10**(-23) # Boltzmann constant in J/K
    charge = 1.602 * 10**(-19) # elementary charge in C
    epsilon_0 = 8.854 * 10**(-12) # permittivity of free space in F/m

    # diameters in m
    diameters = [diameters[i] * 10**(-12) for i in range(len(diameters))]

    # electric field
    E_field = sensor_voltage/probe_distance

    # number of data points
    ndata = len(salt_1_conc)

    # number of species
    n_species = len(valency)

    # species charge
    ion_charge = [valency[i] * charge for i in range(len(valency))]

    # converting molar concentrations to number density
    if salt_2_conc is None and salt_3_conc is None:
        number_density_salt_1 = [salt_1_conc[i] * Avogadros_num for i in range(ndata)]

        # valency of cation
        valency_cation = valency[0]

        # evaluating the number density of individual species
        number_density_cat_1 = number_density_salt_1
        number_density_an = [valency_cation * number_density_salt_1[i] for i in range(ndata)]
    elif salt_2_conc is not None and salt_3_conc is None:
        number_density_salt_1 = [salt_1_conc[i] * Avogadros_num for i in range(ndata)]
        number_density_salt_2 = [salt_2_conc[i] * Avogadros_num for i in range(ndata)]

        # valency of cations
        valency_cation_1 = valency[0]
        valency_cation_2 = valency[1]

        # evaluating the number density of individual species
        number_density_cat_1 = number_density_salt_1
        number_density_cat_2 = number_density_salt_2
        number_density_an = [valency_cation_1 * number_density_salt_1[i] + valency_cation_2 * number_density_salt_2[i]
                             for i in range(ndata)]
    else:
        number_density_salt_1 = [salt_1_conc[i] * Avogadros_num for i in range(ndata)]
        number_density_salt_2 = [salt_2_conc[i] * Avogadros_num for i in range(ndata)]
        number_density_salt_3 = [salt_3_conc[i] * Avogadros_num for i in range(ndata)]

        # valency of cations
        valency_cation_1 = valency[0]
        valency_cation_2 = valency[1]
        valency_cation_3 = valency[2]

        # evaluating the number density of individual species
        number_density_cat_1 = number_density_salt_1
        number_density_cat_2 = number_density_salt_2
        number_density_cat_3 = number_density_salt_3
        number_density_an = [valency_cation_1 * number_density_salt_1[i] + valency_cation_2 * number_density_salt_2[i]
                             + valency_cation_3 * number_density_salt_3[i] for i in range(ndata)]

    # calculate the bulk conductivity of the salt solution
    all_cond_calc = np.zeros(ndata)
    for n in range(ndata): # loop through the salts concentration
        if salt_2_conc is None and salt_3_conc is None:
            # number density of species
            n_cat = number_density_cat_1[n]
            n_an = number_density_an[n]
            number_density = [n_cat, n_an]
        elif salt_2_conc is not None and salt_3_conc is None:
            # number density of species
            n_cat_1 = number_density_cat_1[n]
            n_cat_2 = number_density_cat_2[n]
            n_an = number_density_an[n]
            number_density = [n_cat_1, n_cat_2, n_an]
        else:
            # number density of species
            n_cat_1 = number_density_cat_1[n]
            n_cat_2 = number_density_cat_2[n]
            n_cat_3 = number_density_cat_3[n]
            n_an = number_density_an[n]
            number_density = [n_cat_1, n_cat_2, n_cat_3, n_an]

        # calculate the species ionic mobility (omega) and the relative ionic strength (mew)
        omega = np.zeros(n_species)
        mew = np.zeros(n_species)
        for a in range(n_species):
            omega[a] = diff_coeff[a] / (k_B * T)
            mew[a] = number_density[a] * ion_charge[a] ** 2 / sum(
                number_density[j] * ion_charge[j] ** 2 for j in range(n_species))

        # calculate the Debye length from equation (5)
        kappa = math.sqrt(
            sum(number_density[l] * ion_charge[l] ** 2 / (epsilon * epsilon_0 * k_B * T) for l in range(n_species)))

        # calculate the mean mobility from equation (7)
        omega_bar = sum(mew[j] * omega[j] for j in range(n_species))

        # calculate the transport number of all species from equation (8)
        transport_num = np.zeros(n_species)
        for j in range(n_species):
            transport_num[j] = mew[j] * omega[j] / omega_bar

        # calculate delta from equation (21)
        delta = 1 - ((math.pi / 6) * sum(number_density[k] * diameters[k] ** 3 for k in range(n_species)))

        # function that evaluates equation (18)
        def func_gamma(gamma):
            """
            Evaluates residual of equation (18)

            Arguments:
                gamma

            Returns:
                Residual of the equation
            """
            # calculating capital omega from equation (20)
            capital_omega = 1 + ((math.pi / (2 * delta)) * sum(
                number_density[k] * diameters[k] ** 3 / (1 + gamma * diameters[k]) for k in range(n_species)))

            # calculating Pn from equation (19)
            P_n = (1 / capital_omega) * sum(
                number_density[k] * diameters[k] * valency[k] / (1 + gamma * diameters[k]) for k in range(n_species))

            return (4 * epsilon_0 * gamma ** 2 - ((charge ** 2) / (epsilon * k_B * T)) *
                    sum(number_density[l] * ((valency[l] - (math.pi * P_n * diameters[l] ** 2 / (2 * delta))) / (
                                1 + gamma * diameters[l])) ** 2 for l in range(n_species)))

        # finding gamma, the root of equation (18)
        gamma = bisect(func_gamma, 0, 0.5 * kappa)

        # re-evaluating capital_omega, P_n and nu
        capital_omega = 1 + ((math.pi / (2 * delta)) * sum(
            number_density[k] * diameters[k] ** 3 / (1 + gamma * diameters[k]) for k in range(n_species)))
        P_n = (1 / capital_omega) * sum(
            number_density[k] * diameters[k] * valency[k] / (1 + gamma * diameters[k]) for k in range(n_species))

        # calculate the nu values of all species from equation (17)
        nu = np.zeros(n_species)
        for k in range(n_species):
            nu[k] = (gamma * valency[k] / (1 + gamma * diameters[k])) + (math.pi / (2 * delta)) * (
                        P_n * diameters[k] / (1 + gamma * diameters[k]))

        # evaluating q and N for all species from equation (9) and (11) respectively
        q = np.zeros(n_species)
        N = np.zeros(n_species)
        alpha_scaled = np.zeros(n_species)

        # function that evaluates equation (12)
        def func_alpha(alpha_scaled):
            """
            Evaluates residuals of equation 12

            Arguments:
                alpha_scaled = alpha/omega_bar

            Returns:
                residual of equation 12
            """
            return ((alpha_scaled) * sum(
                transport_num[k] / ((omega[k] / omega_bar) ** 2 - (alpha_scaled) ** 2) for k in range(n_species)))

        # since alpha is scaled by omega_bar, omega need to be scaled by same factor
        omega_scaled = np.zeros(n_species)
        for k in range(n_species):
                omega_scaled[k] = omega[k] / omega_bar

        # updating the values of alpha_scaled
        for p in range(n_species):
            if p == 0:
                alpha_scaled[p] = bisect(func_alpha, 0, 0.991 * omega_scaled[p])
            else:
                alpha_scaled[p] = bisect(func_alpha, 1.001 * omega_scaled[p-1], 0.991 * omega_scaled[p])

        # re-scaling alpha_scaled back to alpha
        alphas = [alpha_scaled[p] * omega_bar for p in range(n_species)]

        # updating q and N values
        for p in range(n_species):
            q[p] = sum(omega_bar * transport_num[r] / (omega[r] + alphas[p]) for r in range(n_species))
            N[p] = math.sqrt(1 / sum(
                transport_num[r] * omega[r] ** 2 / (omega[r] ** 2 - alphas[p] ** 2) ** 2 for r in range(n_species)))

        # ksi matrix
        ksi = np.zeros((n_species, n_species))

        # calculate the velocity of the species
        vel = np.zeros(n_species)

        # calculate the change in the velocity of the species
        delta_vel = np.zeros(n_species)

        # calculate the hydrodynamic correction
        delta_vel_divide_vel = np.zeros(n_species)
        for i in range(n_species):
            # update the velocity of species from equation (2)
            vel[i] = valency[i] * charge * E_field * diff_coeff[i] / (k_B * T)

            # update the change in the velocity of species from equation (16)
            delta_vel[i] = -(charge * E_field / (3 * math.pi * eta)) * (nu[i] + (math.pi / 4) * sum(
                number_density[j] * valency[j] * diameters[j] ** 2 for j in range(n_species))
                                                                        - (math.pi / 6) * sum(
                        number_density[j] * (diameters[j] ** 3) * nu[j] for j in range(n_species)))

            # update the hydrodynamic correction; equation (16) divide equation (2)
            delta_vel_divide_vel[i] = delta_vel[i] / vel[i]

            # update the ksi matrix
            for p in range(n_species):
                ksi[i][p] = N[p] * omega[i] / (omega[i] ** 2 - alphas[p] ** 2)

        # conductivity of species from equation (1)
        cond_species = np.zeros(n_species)

        # calculate the relaxation correction from equation (4)
        delta_k_divide_k = np.zeros(n_species)
        for i in range(n_species):
            delta_k_divide_k_sum = 0.0
            for p in range(n_species):
                inner_delta_k_divide_k_sum = 0.0
                for j in range(n_species):
                    for a in range(n_species):
                        # calculate the average diameter
                        sigma_aj = 0.5 * (diameters[a] + diameters[j])

                        # first fraction of summation term
                        term1 = transport_num[j] * ksi[j][p] * mew[a] * (
                                    ion_charge[a] * omega[a] - ion_charge[j] * omega[j]) / (
                                            ion_charge[a] * ion_charge[j] * (omega[a] + omega[j]))

                        # second fraction of summation term
                        term2 = math.sinh(kappa * math.sqrt(q[p]) * sigma_aj) / (kappa * math.sqrt(q[p]) * sigma_aj)

                        # integral numerator from equation (14)
                        integral_num = -ion_charge[a] * ion_charge[j] * kappa * math.sqrt(q[p]) * sigma_aj * np.exp(
                            -kappa * math.sqrt(q[p]) * sigma_aj)

                        # calculate Y from equation (15)
                        Y_num = sum(
                            number_density[m] * (valency[m] ** 2) * np.exp(-kappa * math.sqrt(q[p]) * diameters[m]) / (
                                        1 + gamma * diameters[m]) ** 2 for m in range(n_species))
                        Y_denom = sum(number_density[m] * valency[m] ** 2 / (1 + gamma * diameters[m]) ** 2 for m in
                                      range(n_species))
                        Y = Y_num / Y_denom

                        # integral denominator from equation (14)
                        integral_denom = 4 * math.pi * epsilon_0 * epsilon * k_B * T * (
                                    (kappa ** 2) * q[p] + 2 * gamma * kappa * math.sqrt(q[p]) + 2 * gamma ** 2 - 2 * (
                                        gamma ** 2) * Y)

                        inner_delta_k_divide_k_sum += term1 * term2 * (integral_num / integral_denom)

                delta_k_divide_k_sum += ksi[i][p] * inner_delta_k_divide_k_sum

            # relaxation correction from equation (4)
            delta_k_divide_k[i] = -(kappa ** 2) * ion_charge[i] * delta_k_divide_k_sum / 3

            # calculate the conductivity of the species from equation (1)
            cond_species[i] = (charge ** 2) * number_density[i] * diff_coeff[i] * (valency[i] ** 2) * (
                        1 + delta_vel_divide_vel[i]) * (1 + delta_k_divide_k[i]) / (k_B * T)

        # calculate the bulk conductivity from equation (1)
        all_cond_calc[n] = sum(cond_species)

    # convert the calculated conductivity from S/m to micro.S/cm
    cond_calc_con = [all_cond_calc[i] * 10 ** 6 / 100 for i in range(ndata)]

    print(f"Relaxation correction: {delta_k_divide_k}")
    print(f"Hydrodynamic correction: {delta_vel_divide_vel}")
    print(f"omega_bar: {omega_bar}")
    print(f"Alpha: {alphas}")
    print(f"Mew: {mew}")
    print(f"Transport number: {transport_num}")
    print(f"Omega: {omega}")
    print(f"ksi: {ksi}")

    return cond_calc_con

# %%
# create the objective function of the optimization problem
def SSE(diameter):
    """
    Calculates the sum of squared errors between the variant Shedlovsky and MSA Transport model

    Argument:
        cation_ratio: list of the cation ratio of the salts"""

    # calculate the bulk conductivity using the MSA transport model
    msa_cond = msa_transport(valency, diameter, diffusion_coeff, temp, voltage, distance, eta_msa, epsilon, salt_conc)

    # calculate the sum of squared errors between the variant Shedlovsky and MSA transport models
    sse = sum((msa_cond[i] - cond_exp[i])**2 for i in range(ndata))

    print("Diameter is: ",diameter)
    print("SSE is: ",sse)
    
    return sse

# %%
# create the objective function of the optimization problem
def SSE_Ca(diameter):
    """
    Calculates the sum of squared errors between the variant Shedlovsky and MSA Transport model

    Argument:
        cation_ratio: list of the cation ratio of the salts"""

    # calculate the bulk conductivity using the MSA transport model
    msa_cond = msa_transport(valency_Ca, diameter, diffusion_coeff_Ca, temp, voltage, distance, eta_msa, epsilon, salt_conc_Ca)

    # calculate the sum of squared errors between the variant Shedlovsky and MSA transport models
    sse = sum((msa_cond[i] - cond_exp_Ca[i])**2 for i in range(ndata_Ca))

    print("Diameter is: ",diameter)
    print("SSE is: ",sse)
    
    return sse

# %%
# initial guess of cation ratio
diameter = [300, 300]

# solve the optimization problem
result = minimize(SSE, diameter, bounds=[(204, 400), (204, 400)], method="L-BFGS-B")

# get the optimal cation ratio
diameter_opt_scaled = result.x

# get the sse value at the optimal cation ratio
opt_sse = result.fun

print("The optimal cation ratio is:",diameter_opt_scaled)
print("The objective function at the optimal is:",opt_sse)
# Out:
# Relaxation correction: [-1.77262522e-11 -1.77262522e-11]
# Hydrodynamic correction: [-0.14795644 -0.09713282]
# omega_bar: 408747984038.1848
# Alpha: [0.0, 399863050037.51556]
# Mew: [0.5 0.5]
# Transport number: [0.3963161 0.6036839]
# Omega: [3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.23419544 -1.        ]
#  [ 0.81024445  1.        ]]
# Diameter is:  [300. 300.]
# SSE is:  795349.262281635
# Relaxation correction: [-1.77262522e-11 -1.77262522e-11]
# Hydrodynamic correction: [-0.14795644 -0.09713282]
# omega_bar: 408747984038.1848
# Alpha: [0.0, 399863050037.51556]
# Mew: [0.5 0.5]
# Transport number: [0.3963161 0.6036839]
# Omega: [3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.23419544 -1.        ]
#  [ 0.81024445  1.        ]]
# Diameter is:  [300.00000001 300.        ]
# SSE is:  795349.2622971901
# Relaxation correction: [-1.77262522e-11 -1.77262522e-11]
# Hydrodynamic correction: [-0.14795644 -0.09713282]
# omega_bar: 408747984038.1848
# Alpha: [0.0, 399863050037.51556]
# Mew: [0.5 0.5]
# Transport number: [0.3963161 0.6036839]
# Omega: [3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.23419544 -1.        ]
#  [ 0.81024445  1.        ]]
# Diameter is:  [300.         300.00000001]
# SSE is:  795349.2622971936
# Relaxation correction: [-1.28333136e-11 -1.28333136e-11]
# Hydrodynamic correction: [-0.15907313 -0.10443088]
# omega_bar: 408747984038.1848
# Alpha: [0.0, 399863050037.51556]
# Mew: [0.5 0.5]
# Transport number: [0.3963161 0.6036839]
# Omega: [3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.23419544 -1.        ]
#  [ 0.81024445  1.        ]]
# Diameter is:  [204. 204.]
# SSE is:  505167.1190010607
# Relaxation correction: [-1.28333136e-11 -1.28333136e-11]
# Hydrodynamic correction: [-0.15907313 -0.10443088]
# omega_bar: 408747984038.1848
# Alpha: [0.0, 399863050037.51556]
# Mew: [0.5 0.5]
# Transport number: [0.3963161 0.6036839]
# Omega: [3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.23419544 -1.        ]
#  [ 0.81024445  1.        ]]
# Diameter is:  [204.00000001 204.        ]
# SSE is:  505167.1190155586
# Relaxation correction: [-1.28333136e-11 -1.28333136e-11]
# Hydrodynamic correction: [-0.15907313 -0.10443088]
# omega_bar: 408747984038.1848
# Alpha: [0.0, 399863050037.51556]
# Mew: [0.5 0.5]
# Transport number: [0.3963161 0.6036839]
# Omega: [3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.23419544 -1.        ]
#  [ 0.81024445  1.        ]]
# Diameter is:  [204.         204.00000001]
# SSE is:  505167.119015559
# The optimal cation ratio is: [204. 204.]
# The objective function at the optimal is: 505167.1190010607

# %%
# initial guess of cation ratio
diameter_Ca = [300, 300]

# solve the optimization problem
result = differential_evolution(SSE_Ca, bounds=[(200, 400), (200, 400)])

# get the optimal cation ratio
diameter_Ca_scaled = result.x
# Out:
# Relaxation correction: [-4.84024349e-11 -4.84024349e-11]
# Hydrodynamic correction: [-0.37372951 -0.14612481]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [302.93412773 295.28644115]
# SSE is:  12242308.129376233
# Relaxation correction: [-4.85035569e-11 -4.85035569e-11]
# Hydrodynamic correction: [-0.38706982 -0.14454181]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [248.52539051 352.46309248]
# SSE is:  10781038.331123836
# Relaxation correction: [-4.59768344e-11 -4.59768344e-11]
# Hydrodynamic correction: [-0.38285224 -0.14910798]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [277.80926817 279.55447708]
# SSE is:  10566957.993547477
# Relaxation correction: [-5.37791172e-11 -5.37791172e-11]
# Hydrodynamic correction: [-0.36062409 -0.1387421 ]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [329.54809964 366.70565755]
# SSE is:  15501712.971970363
# Relaxation correction: [-4.26347427e-11 -4.26347427e-11]
# Hydrodynamic correction: [-0.4085549  -0.15172232]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [201.3076471  302.84291101]
# SSE is:  7324867.800468303
# Relaxation correction: [-4.98189708e-11 -4.98189708e-11]
# Hydrodynamic correction: [-0.39207507 -0.14247293]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [224.59123156 399.66417311]
# SSE is:  10505371.44366895
# Relaxation correction: [-5.6167213e-11 -5.6167213e-11]
# Hydrodynamic correction: [-0.34429876 -0.13672594]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [399.49341092 341.43877792]
# SSE is:  18566611.493128777
# Relaxation correction: [-5.24195659e-11 -5.24195659e-11]
# Hydrodynamic correction: [-0.3589685  -0.14117919]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [347.19512515 322.54975501]
# SSE is:  15275654.956800606
# Relaxation correction: [-4.8165929e-11 -4.8165929e-11]
# Hydrodynamic correction: [-0.36694512 -0.14781081]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [336.25927538 256.73381426]
# SSE is:  12880228.038807947
# Relaxation correction: [-4.87878793e-11 -4.87878793e-11]
# Hydrodynamic correction: [-0.36856312 -0.14626285]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [324.30035499 280.03462858]
# SSE is:  12927095.60209816
# Relaxation correction: [-5.02353754e-11 -5.02353754e-11]
# Hydrodynamic correction: [-0.35674282 -0.1459057 ]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [375.47028687 252.6487352 ]
# SSE is:  14709701.039550817
# Relaxation correction: [-4.2447489e-11 -4.2447489e-11]
# Hydrodynamic correction: [-0.39923739 -0.15305993]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [233.11757309 267.79279053]
# SSE is:  8099715.38770058
# Relaxation correction: [-4.46762728e-11 -4.46762728e-11]
# Hydrodynamic correction: [-0.3814012  -0.15181506]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [291.01216375 244.47241027]
# SSE is:  10320189.32216818
# Relaxation correction: [-4.42361227e-11 -4.42361227e-11]
# Hydrodynamic correction: [-0.40223809 -0.14977961]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [215.05908514 314.56664654]
# SSE is:  8236607.718138315
# Relaxation correction: [-4.32957635e-11 -4.32957635e-11]
# Hydrodynamic correction: [-0.37951089 -0.15514943]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [307.35001035 205.22989547]
# SSE is:  10039185.772788275
# Relaxation correction: [-5.69180593e-11 -5.69180593e-11]
# Hydrodynamic correction: [-0.34771494 -0.13506131]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [373.21519565 384.22736602]
# SSE is:  18346782.594638072
# Relaxation correction: [-5.82047086e-11 -5.82047086e-11]
# Hydrodynamic correction: [-0.34256028 -0.13353453]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [391.99988135 391.57224332]
# SSE is:  19570550.35574021
# Relaxation correction: [-4.19658183e-11 -4.19658183e-11]
# Hydrodynamic correction: [-0.39136484 -0.1552438 ]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [264.6573963  228.09764382]
# SSE is:  8648941.862033846
# Relaxation correction: [-4.7520575e-11 -4.7520575e-11]
# Hydrodynamic correction: [-0.38684996 -0.14604757]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [254.18874504 329.74609455]
# SSE is:  10563283.087986622
# Relaxation correction: [-5.70643719e-11 -5.70643719e-11]
# Hydrodynamic correction: [-0.34623279 -0.13497266]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [380.37462723 379.81019776]
# SSE is:  18617466.355863754
# Relaxation correction: [-4.41367518e-11 -4.41367518e-11]
# Hydrodynamic correction: [-0.37662831 -0.15404527]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [315.51364514 210.36198143]
# SSE is:  10564540.999754831
# Relaxation correction: [-4.51565954e-11 -4.51565954e-11]
# Hydrodynamic correction: [-0.39504602 -0.14899895]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [235.56986628 308.89363934]
# SSE is:  9138247.03847919
# Relaxation correction: [-4.3993557e-11 -4.3993557e-11]
# Hydrodynamic correction: [-0.38335621 -0.1527848 ]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [286.50698798 237.97806875]
# SSE is:  9933498.057536697
# Relaxation correction: [-4.67116365e-11 -4.67116365e-11]
# Hydrodynamic correction: [-0.36553925 -0.15134382]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [353.55233944 213.63104553]
# SSE is:  12464130.361405805
# Relaxation correction: [-4.86815384e-11 -4.86815384e-11]
# Hydrodynamic correction: [-0.38191846 -0.1446925 ]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [267.23209763 336.63239394]
# SSE is:  11407361.020940391
# Relaxation correction: [-4.80540127e-11 -4.80540127e-11]
# Hydrodynamic correction: [-0.36160129 -0.149424  ]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [365.00251429 224.79173842]
# SSE is:  13351941.511285808
# Relaxation correction: [-4.92069036e-11 -4.92069036e-11]
# Hydrodynamic correction: [-0.36350082 -0.146446  ]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [346.55517749 264.37380134]
# SSE is:  13612413.28564259
# Relaxation correction: [-4.64441826e-11 -4.64441826e-11]
# Hydrodynamic correction: [-0.40143985 -0.14658299]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [208.33154989 357.664977  ]
# SSE is:  8782347.687357428
# Relaxation correction: [-4.85812485e-11 -4.85812485e-11]
# Hydrodynamic correction: [-0.38908096 -0.14429379]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [240.82636786 361.58019347]
# SSE is:  10573355.498494543
# Relaxation correction: [-4.75237718e-11 -4.75237718e-11]
# Hydrodynamic correction: [-0.37663602 -0.1472624 ]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [295.33751415 287.84772004]
# SSE is:  11661806.323148783
# Relaxation correction: [-5.31743709e-11 -5.31743709e-11]
# Hydrodynamic correction: [-0.35877988 -0.13990917]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [342.81350211 341.41543911]
# SSE is:  15554008.7802167
# Relaxation correction: [-4.06811722e-11 -4.06811722e-11]
# Hydrodynamic correction: [-0.41008887 -0.15475507]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [204.33105145 269.51705885]
# SSE is:  6789177.088742984
# Relaxation correction: [-5.09876844e-11 -5.09876844e-11]
# Hydrodynamic correction: [-0.35200798 -0.14556091]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [397.25957217 243.48350621]
# SSE is:  15502388.560976882
# Relaxation correction: [-5.53373928e-11 -5.53373928e-11]
# Hydrodynamic correction: [-0.34776004 -0.13767837]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [385.97029357 338.85806423]
# SSE is:  17778568.472623553
# Relaxation correction: [-4.26083323e-11 -4.26083323e-11]
# Hydrodynamic correction: [-0.40857547 -0.15176197]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [201.3491317  302.38564181]
# SSE is:  7317638.227844372
# Relaxation correction: [-5.10971147e-11 -5.10971147e-11]
# Hydrodynamic correction: [-0.36202796 -0.1430807 ]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [340.92401825 304.41553084]
# SSE is:  14449823.106228134
# Relaxation correction: [-5.67246152e-11 -5.67246152e-11]
# Hydrodynamic correction: [-0.34841339 -0.13529746]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [370.89791003 382.65340805]
# SSE is:  18178005.350397438
# Relaxation correction: [-4.62961634e-11 -4.62961634e-11]
# Hydrodynamic correction: [-0.36731017 -0.15177489]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [347.19512515 213.22231697]
# SSE is:  12148676.423104037
# Relaxation correction: [-3.97787976e-11 -3.97787976e-11]
# Hydrodynamic correction: [-0.40912406 -0.15644951]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [211.14660258 248.95072342]
# SSE is:  6671607.430747099
# Relaxation correction: [-5.57933221e-11 -5.57933221e-11]
# Hydrodynamic correction: [-0.34850076 -0.1367907 ]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [377.9435108  356.38751619]
# SSE is:  17843254.843252085
# Relaxation correction: [-5.31481267e-11 -5.31481267e-11]
# Hydrodynamic correction: [-0.36406038 -0.13940681]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [317.4657788  366.99538897]
# SSE is:  14850406.041048251
# Relaxation correction: [-3.86962613e-11 -3.86962613e-11]
# Hydrodynamic correction: [-0.40403684 -0.15932589]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [233.11757309 210.46840154]
# SSE is:  6803583.5897398805
# Relaxation correction: [-4.25401725e-11 -4.25401725e-11]
# Hydrodynamic correction: [-0.38419925 -0.15561561]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [291.01216375 210.06528121]
# SSE is:  9410957.253863428
# Relaxation correction: [-4.44430838e-11 -4.44430838e-11]
# Hydrodynamic correction: [-0.38964237 -0.15085885]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [258.87966711 273.55621031]
# SSE is:  9481035.435520923
# Relaxation correction: [-4.82741131e-11 -4.82741131e-11]
# Hydrodynamic correction: [-0.39122363 -0.14459857]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [234.65064177 362.45532231]
# SSE is:  10263649.598244086
# Relaxation correction: [-5.38595942e-11 -5.38595942e-11]
# Hydrodynamic correction: [-0.36382823 -0.13836646]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [313.96750488 384.22736602]
# SSE is:  15088888.551769655
# Relaxation correction: [-5.63678197e-11 -5.63678197e-11]
# Hydrodynamic correction: [-0.35183862 -0.1355524 ]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [355.22986045 391.57224332]
# SSE is:  17554150.931553137
# Relaxation correction: [-4.14603049e-11 -4.14603049e-11]
# Hydrodynamic correction: [-0.40184407 -0.15445266]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [228.43434077 257.13017349]
# SSE is:  7640792.677737103
# Relaxation correction: [-4.9897295e-11 -4.9897295e-11]
# Hydrodynamic correction: [-0.37350601 -0.14360435]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [295.13599466 329.74609455]
# SSE is:  12714321.263901493
# Relaxation correction: [-4.57111202e-11 -4.57111202e-11]
# Hydrodynamic correction: [-0.39559391 -0.1480739 ]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [231.11579195 322.55217971]
# SSE is:  9213905.51459369
# Relaxation correction: [-5.14951222e-11 -5.14951222e-11]
# Hydrodynamic correction: [-0.35626338 -0.14339151]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [368.4060152 283.1789978]
# SSE is:  15261424.822484914
# Relaxation correction: [-4.31208055e-11 -4.31208055e-11]
# Hydrodynamic correction: [-0.39767723 -0.1520908 ]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [235.56986628 275.96085069]
# SSE is:  8401030.647273293
# Relaxation correction: [-5.02358849e-11 -5.02358849e-11]
# Hydrodynamic correction: [-0.36845853 -0.1436545 ]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [315.60785107 314.8462929 ]
# SSE is:  13409912.15192918
# Relaxation correction: [-4.19290172e-11 -4.19290172e-11]
# Hydrodynamic correction: [-0.38911452 -0.15578133]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [273.82255163 218.12649712]
# SSE is:  8824005.691591047
# Relaxation correction: [-5.18382001e-11 -5.18382001e-11]
# Hydrodynamic correction: [-0.36468749 -0.14142249]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [323.00233917 336.63239394]
# SSE is:  14370136.70726508
# Relaxation correction: [-4.54691941e-11 -4.54691941e-11]
# Hydrodynamic correction: [-0.37332828 -0.15197722]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [322.74775475 224.79173842]
# SSE is:  11315049.055404358
# Relaxation correction: [-4.15721094e-11 -4.15721094e-11]
# Hydrodynamic correction: [-0.40328609 -0.15405905]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [222.99427345 264.37380134]
# SSE is:  7545898.869774973
# Relaxation correction: [-4.95577215e-11 -4.95577215e-11]
# Hydrodynamic correction: [-0.37589197 -0.14389767]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [286.934408   332.05373527]
# SSE is:  12337915.075969722
# Relaxation correction: [-5.2966205e-11 -5.2966205e-11]
# Hydrodynamic correction: [-0.36605784 -0.13951725]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [309.48760161 371.69849357]
# SSE is:  14532154.723051481
# Relaxation correction: [-4.2979001e-11 -4.2979001e-11]
# Hydrodynamic correction: [-0.38262569 -0.1550526 ]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [295.33751415 212.57639077]
# SSE is:  9679497.501724642
# Relaxation correction: [-4.30167558e-11 -4.30167558e-11]
# Hydrodynamic correction: [-0.3910754  -0.15325491]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [260.48708797 248.95072342]
# SSE is:  8964587.657490145
# Relaxation correction: [-4.65356015e-11 -4.65356015e-11]
# Hydrodynamic correction: [-0.38166374 -0.14828495]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [279.66420973 287.05349179]
# SSE is:  10847307.396258665
# Relaxation correction: [-4.45843604e-11 -4.45843604e-11]
# Hydrodynamic correction: [-0.37865557 -0.15258378]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [303.55203896 230.0446837 ]
# SSE is:  10539862.10866722
# Relaxation correction: [-4.23098081e-11 -4.23098081e-11]
# Hydrodynamic correction: [-0.38493441 -0.15593375]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [289.15187631 208.34339327]
# SSE is:  9278986.821731409
# Relaxation correction: [-4.73487854e-11 -4.73487854e-11]
# Hydrodynamic correction: [-0.38637663 -0.14636217]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [256.83387689 324.12399941]
# SSE is:  10570867.724327628
# Relaxation correction: [-4.14513414e-11 -4.14513414e-11]
# Hydrodynamic correction: [-0.40469963 -0.1540876 ]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [218.74375299 266.80327001]
# SSE is:  7399710.28842322
# Relaxation correction: [-4.89501797e-11 -4.89501797e-11]
# Hydrodynamic correction: [-0.35931752 -0.14804891]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [370.89791003 234.37886659]
# SSE is:  13930153.049841411
# Relaxation correction: [-3.82394357e-11 -3.82394357e-11]
# Hydrodynamic correction: [-0.40730597 -0.15962577]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [223.77172079 213.22231697]
# SSE is:  6459107.465681973
# Relaxation correction: [-4.52061836e-11 -4.52061836e-11]
# Hydrodynamic correction: [-0.38190067 -0.15069063]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [285.94308899 258.40332809]
# SSE is:  10434466.218407497
# Relaxation correction: [-3.84217371e-11 -3.84217371e-11]
# Hydrodynamic correction: [-0.4051586  -0.15966176]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [230.40326148 209.16665846]
# SSE is:  6655985.351783852
# Relaxation correction: [-4.75498667e-11 -4.75498667e-11]
# Hydrodynamic correction: [-0.38493824 -0.14618482]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [261.32123587 323.01527533]
# SSE is:  10777858.796404878
# Relaxation correction: [-4.80273472e-11 -4.80273472e-11]
# Hydrodynamic correction: [-0.37049363 -0.14736361]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [320.00025034 271.16273766]
# SSE is:  12467619.605905954
# Relaxation correction: [-3.82589849e-11 -3.82589849e-11]
# Hydrodynamic correction: [-0.40613877 -0.15980181]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [227.70923739 209.5065446 ]
# SSE is:  6546936.644945394
# Relaxation correction: [-3.81992875e-11 -3.81992875e-11]
# Hydrodynamic correction: [-0.40994133 -0.15924773]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [215.05908514 221.47608422]
# SSE is:  6261629.746837142
# Relaxation correction: [-4.82914772e-11 -4.82914772e-11]
# Hydrodynamic correction: [-0.3728895  -0.14645394]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [307.35001035 288.80842085]
# SSE is:  12298966.145400312
# Relaxation correction: [-3.88141125e-11 -3.88141125e-11]
# Hydrodynamic correction: [-0.41064276 -0.15798357]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [210.18416218 235.49916971]
# SSE is:  6346249.027830004
# Relaxation correction: [-3.89075531e-11 -3.89075531e-11]
# Hydrodynamic correction: [-0.40546364 -0.15864707]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [227.18401618 219.64566568]
# SSE is:  6750057.391724818
# Relaxation correction: [-4.92897908e-11 -4.92897908e-11]
# Hydrodynamic correction: [-0.394929   -0.14305618]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [217.37204732 397.51003095]
# SSE is:  10068061.39570431
# Relaxation correction: [-4.25788539e-11 -4.25788539e-11]
# Hydrodynamic correction: [-0.39759727 -0.15305201]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [238.33926244 264.56450801]
# SSE is:  8275568.277992583
# Relaxation correction: [-3.70402073e-11 -3.70402073e-11]
# Hydrodynamic correction: [-0.41582831 -0.16049958]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [200.74115196 219.08338334]
# SSE is:  5603461.732176043
# Relaxation correction: [-3.71586923e-11 -3.71586923e-11]
# Hydrodynamic correction: [-0.41247814 -0.16082728]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [211.04424917 210.36198143]
# SSE is:  5855160.147297421
# Relaxation correction: [-3.88733184e-11 -3.88733184e-11]
# Hydrodynamic correction: [-0.4126993 -0.1575813]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [203.31516768 243.32286965]
# SSE is:  6206941.39685318
# Relaxation correction: [-3.66809771e-11 -3.66809771e-11]
# Hydrodynamic correction: [-0.41278258 -0.16171445]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [212.0342639  202.46626758]
# SSE is:  5730289.375493791
# Relaxation correction: [-3.81668775e-11 -3.81668775e-11]
# Hydrodynamic correction: [-0.41069934 -0.15918522]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [212.6885922  223.40248435]
# SSE is:  6200261.051360935
# Relaxation correction: [-4.17513669e-11 -4.17513669e-11]
# Hydrodynamic correction: [-0.39221759 -0.15550467]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [262.40746429 227.04938134]
# SSE is:  8518393.236365136
# Relaxation correction: [-4.22500062e-11 -4.22500062e-11]
# Hydrodynamic correction: [-0.38909037 -0.15512926]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [272.23644571 224.79173842]
# SSE is:  8919526.379165439
# Relaxation correction: [-4.01313148e-11 -4.01313148e-11]
# Hydrodynamic correction: [-0.41179175 -0.15549184]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [201.14144782 264.37380134]
# SSE is:  6538916.09136214
# Relaxation correction: [-4.06199295e-11 -4.06199295e-11]
# Hydrodynamic correction: [-0.39306845 -0.15764106]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [264.80302289 207.10310979]
# SSE is:  8133020.921792036
# Relaxation correction: [-4.12903548e-11 -4.12903548e-11]
# Hydrodynamic correction: [-0.40503636 -0.15432436]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [218.30408477 264.76027758]
# SSE is:  7335295.200020989
# Relaxation correction: [-4.7464343e-11 -4.7464343e-11]
# Hydrodynamic correction: [-0.39801872 -0.14535116]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [215.13440702 368.10794606]
# SSE is:  9349698.060818566
# Relaxation correction: [-3.69643562e-11 -3.69643562e-11]
# Hydrodynamic correction: [-0.41159781 -0.16136754]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [214.7634553  203.77868115]
# SSE is:  5871630.748497899
# Relaxation correction: [-4.8801663e-11 -4.8801663e-11]
# Hydrodynamic correction: [-0.39817347 -0.14357449]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [208.87320463 397.43038656]
# SSE is:  9606601.907584695
# Relaxation correction: [-4.59462441e-11 -4.59462441e-11]
# Hydrodynamic correction: [-0.36913079 -0.15204612]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [340.26298346 214.55648819]
# SSE is:  11857740.92420855
# Relaxation correction: [-3.7152517e-11 -3.7152517e-11]
# Hydrodynamic correction: [-0.41441298 -0.16051326]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [204.79591187 216.60360944]
# SSE is:  5722640.169911225
# Relaxation correction: [-3.8897769e-11 -3.8897769e-11]
# Hydrodynamic correction: [-0.40390558 -0.15894903]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [232.67233684 213.91688211]
# SSE is:  6862372.7084717415
# Relaxation correction: [-4.16767482e-11 -4.16767482e-11]
# Hydrodynamic correction: [-0.40441184 -0.15373443]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [218.74375299 270.29693851]
# SSE is:  7474806.312923871
# Relaxation correction: [-5.49291198e-11 -5.49291198e-11]
# Hydrodynamic correction: [-0.35099424 -0.13793416]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [370.89791003 346.44828523]
# SSE is:  17191081.557094067
# Relaxation correction: [-4.7151388e-11 -4.7151388e-11]
# Hydrodynamic correction: [-0.37022895 -0.14916247]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [326.85012696 248.95072342]
# SSE is:  12194766.617648482
# Relaxation correction: [-5.5541682e-11 -5.5541682e-11]
# Hydrodynamic correction: [-0.35527795 -0.13651789]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [343.63180097 386.86050713]
# SSE is:  16792594.29631682
# Relaxation correction: [-4.43444906e-11 -4.43444906e-11]
# Hydrodynamic correction: [-0.39757036 -0.15005207]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [230.40326148 300.85010026]
# SSE is:  8702542.89694428
# Relaxation correction: [-3.77511586e-11 -3.77511586e-11]
# Hydrodynamic correction: [-0.41220114 -0.15973169]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [209.4956457  220.54636578]
# SSE is:  6003167.678633914
# Relaxation correction: [-3.7084203e-11 -3.7084203e-11]
# Hydrodynamic correction: [-0.41365483 -0.16077039]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [207.51777109 212.85886682]
# SSE is:  5759423.456770167
# Relaxation correction: [-4.01648492e-11 -4.01648492e-11]
# Hydrodynamic correction: [-0.40260891 -0.1567207 ]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [231.54111882 234.11437369]
# SSE is:  7268642.760963556
# Relaxation correction: [-4.89344454e-11 -4.89344454e-11]
# Hydrodynamic correction: [-0.39349547 -0.14357544]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [223.77172079 384.87368767]
# SSE is:  10155305.73453429
# Relaxation correction: [-3.95375469e-11 -3.95375469e-11]
# Hydrodynamic correction: [-0.40296919 -0.15786251]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [233.09332031 223.05955841]
# SSE is:  7088404.094748018
# Relaxation correction: [-4.73177485e-11 -4.73177485e-11]
# Hydrodynamic correction: [-0.36451776 -0.1502524 ]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [354.62701197 222.8892742 ]
# SSE is:  12793672.473210953
# Relaxation correction: [-3.73333094e-11 -3.73333094e-11]
# Hydrodynamic correction: [-0.41212867 -0.16054763]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [211.4644662  212.46713591]
# SSE is:  5917131.421461515
# Relaxation correction: [-3.98867492e-11 -3.98867492e-11]
# Hydrodynamic correction: [-0.40279184 -0.15721949]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [232.14644905 229.28665334]
# SSE is:  7187005.654744625
# Relaxation correction: [-4.07430325e-11 -4.07430325e-11]
# Hydrodynamic correction: [-0.40819602 -0.15487593]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [210.17708827 264.56450801]
# SSE is:  6955136.103091888
# Relaxation correction: [-4.77063825e-11 -4.77063825e-11]
# Hydrodynamic correction: [-0.3659144  -0.14901623]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [344.59378937 240.07342721]
# SSE is:  12813360.420160048
# Relaxation correction: [-4.48412305e-11 -4.48412305e-11]
# Hydrodynamic correction: [-0.38922541 -0.15021292]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [258.49233028 280.45723427]
# SSE is:  9626973.202656303
# Relaxation correction: [-4.07606819e-11 -4.07606819e-11]
# Hydrodynamic correction: [-0.40068199 -0.15591223]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [235.65536996 239.0198624 ]
# SSE is:  7567343.853730293
# Relaxation correction: [-4.54807703e-11 -4.54807703e-11]
# Hydrodynamic correction: [-0.3702278 -0.1527931]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [337.86988061 209.26107656]
# SSE is:  11588492.233834304
# Relaxation correction: [-4.77130792e-11 -4.77130792e-11]
# Hydrodynamic correction: [-0.36343977 -0.14966523]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [357.52561372 226.68940426]
# SSE is:  13047632.514529392
# Relaxation correction: [-4.83081991e-11 -4.83081991e-11]
# Hydrodynamic correction: [-0.37079574 -0.14677285]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [316.82594328 279.33619704]
# SSE is:  12528833.949806133
# Relaxation correction: [-3.75691229e-11 -3.75691229e-11]
# Hydrodynamic correction: [-0.41454876 -0.15970379]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [202.6792057  224.79173842]
# SSE is:  5800921.951943803
# Relaxation correction: [-4.36347211e-11 -4.36347211e-11]
# Hydrodynamic correction: [-0.3861621  -0.15294669]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [276.807189   242.14116696]
# SSE is:  9575664.442542601
# Relaxation correction: [-3.74491442e-11 -3.74491442e-11]
# Hydrodynamic correction: [-0.41492976 -0.15986979]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# ...
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [229.4463486  316.61116682]
# SSE is:  8999804.505458722
# Relaxation correction: [-4.58229505e-11 -4.58229505e-11]
# Hydrodynamic correction: [-0.36795955 -0.15267977]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [347.12770157 205.32264534]
# SSE is:  11909628.198636627
# Relaxation correction: [-4.48654139e-11 -4.48654139e-11]
# Hydrodynamic correction: [-0.40593725 -0.14855911]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [200.53609656 339.36039154]
# SSE is:  8018190.813672409
# Relaxation correction: [-3.57114816e-11 -3.57114816e-11]
# Hydrodynamic correction: [-0.41768696 -0.16275617]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [200.17386044 200.65872972]
# SSE is:  5208992.49947547
# Relaxation correction: [-3.56962112e-11 -3.56962112e-11]
# Hydrodynamic correction: [-0.41767636 -0.16278815]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [200.26839156 200.34681742]
# SSE is:  5206528.269797912
# Relaxation correction: [-4.85606306e-11 -4.85606306e-11]
# Hydrodynamic correction: [-0.35545489 -0.15027915]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [396.76469   200.2296894]
# SSE is:  14095734.861064421
# Relaxation correction: [-4.49373336e-11 -4.49373336e-11]
# Hydrodynamic correction: [-0.37121247 -0.15375918]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [336.5729841  201.59666901]
# SSE is:  11302052.256431026
# Relaxation correction: [-3.61185423e-11 -3.61185423e-11]
# Hydrodynamic correction: [-0.4171814  -0.16204625]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [200.14550466 206.46802136]
# SSE is:  5324549.139298892
# Relaxation correction: [-3.57806354e-11 -3.57806354e-11]
# Hydrodynamic correction: [-0.41755738 -0.16264266]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [200.30713128 201.50336835]
# SSE is:  5231313.004809799
# Relaxation correction: [-4.17381168e-11 -4.17381168e-11]
# Hydrodynamic correction: [-0.39759704 -0.15458101]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [242.23779026 247.42421902]
# SSE is:  8065592.174945332
# Relaxation correction: [-4.59399376e-11 -4.59399376e-11]
# Hydrodynamic correction: [-0.40450737 -0.14711928]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [200.65852617 356.92368696]
# SSE is:  8372422.507990024
# Relaxation correction: [-4.2053317e-11 -4.2053317e-11]
# Hydrodynamic correction: [-0.38484039 -0.15651443]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [290.99235711 202.40988438]
# SSE is:  9205733.446509363
# Relaxation correction: [-4.5726448e-11 -4.5726448e-11]
# Hydrodynamic correction: [-0.40464697 -0.14740985]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [201.0905959  352.95305659]
# SSE is:  8315989.018047569
# Relaxation correction: [-4.39121163e-11 -4.39121163e-11]
# Hydrodynamic correction: [-0.37587894 -0.1547574 ]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [320.44489424 201.59666901]
# SSE is:  10547425.035511594
# Relaxation correction: [-4.61452246e-11 -4.61452246e-11]
# Hydrodynamic correction: [-0.37155657 -0.15096255]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [326.93281831 231.76989723]
# SSE is:  11714347.906094212
# Relaxation correction: [-3.57253874e-11 -3.57253874e-11]
# Hydrodynamic correction: [-0.41764569 -0.162736  ]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [200.24874983 200.77979067]
# SSE is:  5214432.349536434
# Relaxation correction: [-3.58828902e-11 -3.58828902e-11]
# Hydrodynamic correction: [-0.41680935 -0.16257256]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [202.27036718 200.96530626]
# SSE is:  5299650.014924087
# Relaxation correction: [-4.47879237e-11 -4.47879237e-11]
# Hydrodynamic correction: [-0.37199739 -0.15387119]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [333.6488824  202.17926063]
# SSE is:  11181970.32265773
# Relaxation correction: [-3.58127754e-11 -3.58127754e-11]
# Hydrodynamic correction: [-0.41758987 -0.16257381]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [200.07599493 202.19303946]
# SSE is:  5235851.837044498
# Relaxation correction: [-4.13145312e-11 -4.13145312e-11]
# Hydrodynamic correction: [-0.41026417 -0.15367812]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [201.22220093 282.36479441]
# SSE is:  6907170.865100041
# Relaxation correction: [-3.57698396e-11 -3.57698396e-11]
# Hydrodynamic correction: [-0.4174822  -0.16267708]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [200.5881649  201.06576781]
# SSE is:  5233831.57375017
# Relaxation correction: [-3.57855107e-11 -3.57855107e-11]
# Hydrodynamic correction: [-0.41764608 -0.1626176 ]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [200.00732253 201.87606008]
# SSE is:  5226724.009082503
# Relaxation correction: [-3.57822727e-11 -3.57822727e-11]
# Hydrodynamic correction: [-0.41748688 -0.16265177]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [200.52359301 201.30736422]
# SSE is:  5236089.792014338
# Relaxation correction: [-3.56962112e-11 -3.56962112e-11]
# Hydrodynamic correction: [-0.41767636 -0.16278815]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [200.26839156 200.34681742]
# SSE is:  5206528.269797912
# Relaxation correction: [-3.5752544e-11 -3.5752544e-11]
# Hydrodynamic correction: [-0.41743901 -0.16271877]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [200.79419656 200.61203902]
# SSE is:  5232995.58836635
# Relaxation correction: [-3.5989326e-11 -3.5989326e-11]
# Hydrodynamic correction: [-0.41736254 -0.16226724]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [200.08919679 204.68629591]
# SSE is:  5286454.514445406
# Relaxation correction: [-4.62096195e-11 -4.62096195e-11]
# Hydrodynamic correction: [-0.40413927 -0.14676538]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [200.71380645 361.35672314]
# SSE is:  8462740.785145737
# Relaxation correction: [-3.5704523e-11 -3.5704523e-11]
# Hydrodynamic correction: [-0.41762898 -0.16278009]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [200.38502836 200.34635536]
# SSE is:  5211203.8429004755
# Relaxation correction: [-3.94093745e-11 -3.94093745e-11]
# Hydrodynamic correction: [-0.41273051 -0.15662609]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [201.06481977 253.58560414]
# SSE is:  6316621.723679429
# Relaxation correction: [-4.4102186e-11 -4.4102186e-11]
# Hydrodynamic correction: [-0.37478077 -0.15463732]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [324.49421797 200.47784584]
# SSE is:  10704287.834144104
# Relaxation correction: [-3.57041364e-11 -3.57041364e-11]
# Hydrodynamic correction: [-0.4176994  -0.16276847]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [200.16388975 200.56483631]
# SSE is:  5206707.440618975
# Relaxation correction: [-3.58161671e-11 -3.58161671e-11]
# Hydrodynamic correction: [-0.41719078 -0.16263696]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [201.32616033 200.97505276]
# SSE is:  5261735.25273594
# Relaxation correction: [-4.60816722e-11 -4.60816722e-11]
# Hydrodynamic correction: [-0.4044874  -0.14692396]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [200.14336932 359.79445695]
# SSE is:  8402604.914300265
# Relaxation correction: [-5.4483646e-11 -5.4483646e-11]
# Hydrodynamic correction: [-0.35088775 -0.13872442]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [375.02895792 333.3550856 ]
# SSE is:  17044516.861374535
# Relaxation correction: [-3.56748012e-11 -3.56748012e-11]
# Hydrodynamic correction: [-0.41771581 -0.16282346]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [200.22926292 200.08343032]
# SSE is:  5199669.918537426
# Relaxation correction: [-3.56748012e-11 -3.56748012e-11]
# Hydrodynamic correction: [-0.41771581 -0.16282346]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [200.22926293 200.08343032]
# SSE is:  5199669.918938763
# Relaxation correction: [-3.56748012e-11 -3.56748012e-11]
# Hydrodynamic correction: [-0.41771581 -0.16282346]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [200.22926292 200.08343033]
# SSE is:  5199669.918738155
# Relaxation correction: [-3.56524937e-11 -3.56524937e-11]
# Hydrodynamic correction: [-0.41781655 -0.16284976]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [200. 200.]
# SSE is:  5188798.320259644
# Relaxation correction: [-3.56524937e-11 -3.56524937e-11]
# Hydrodynamic correction: [-0.41781655 -0.16284976]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [200.00000001 200.        ]
# SSE is:  5188798.3206607
# Relaxation correction: [-3.56524937e-11 -3.56524937e-11]
# Hydrodynamic correction: [-0.41781655 -0.16284976]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [200.         200.00000001]
# SSE is:  5188798.3204601575

# %%
# initial guess of cation ratio
diameter_Ca = [300, 300]

# solve the optimization problem
result = minimize(SSE_Ca, diameter_Ca, bounds=[(200, 400), (362, 362)], method="L-BFGS-B")

# get the optimal cation ratio
diameter_Ca_scaled = result.x

# get the sse value at the optimal cation ratio
opt_sse_Ca = result.fun

print("The optimal cation ratio is:",diameter_Ca_scaled)
print("The objective function at the optimal is:",opt_sse_Ca)
# Out:
# Relaxation correction: [-5.19347603e-11 -5.19347603e-11]
# Hydrodynamic correction: [-0.36961556 -0.14077956]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [300. 362.]
# SSE is:  13775110.110122714
# Relaxation correction: [-5.19347603e-11 -5.19347603e-11]
# Hydrodynamic correction: [-0.36961556 -0.14077956]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [300.00000001 362.        ]
# SSE is:  13775110.110665837
# Relaxation correction: [-4.62054612e-11 -4.62054612e-11]
# Hydrodynamic correction: [-0.40437219 -0.14675935]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [200. 362.]
# SSE is:  8438640.597527744
# Relaxation correction: [-4.62054612e-11 -4.62054612e-11]
# Hydrodynamic correction: [-0.40437219 -0.14675935]
# omega_bar: 292737712474.16846
# Alpha: [0.0, 357043456714.2952]
# Mew: [0.66666667 0.33333333]
# Transport number: [0.4380531 0.5619469]
# Omega: [1.92351992e+11 4.93509152e+11]
# ksi: [[ 1.38221033 -0.61018268]
#  [ 0.53873552  1.22036535]]
# Diameter is:  [200.00000001 362.        ]
# SSE is:  8438640.598042797
# The optimal cation ratio is: [200. 362.]
# The objective function at the optimal is: 8438640.597527744

# %%
# calculated conductivity in uS/cm
all_cond_calc_con = msa_transport(valency, diameter_opt_scaled, diffusion_coeff, temp, voltage, distance, eta_msa, epsilon, salt_conc)
# Out:
# Relaxation correction: [-1.28333136e-11 -1.28333136e-11]
# Hydrodynamic correction: [-0.15907313 -0.10443088]
# omega_bar: 408747984038.1848
# Alpha: [0.0, 399863050037.51556]
# Mew: [0.5 0.5]
# Transport number: [0.3963161 0.6036839]
# Omega: [3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.23419544 -1.        ]
#  [ 0.81024445  1.        ]]

# %%
# making plot comparison of data and calculated values
fig = plt.figure(figsize=(4,4))
plt.plot(salt_conc, all_cond_calc_con, "r-", label="Theory")
plt.plot(salt_conc, cond_exp, "b.", markersize=10, label="Data")
plt.xlabel("NaCl Conc. (mM)", fontsize=16,fontweight='bold')
plt.ylabel("Conductivity ($\mathbf{\mu}$S/cm)", fontsize=16,fontweight='bold')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.tick_params(direction="in",top=True, right=True)
plt.title("Theory Predictions", fontsize=16,fontweight='bold')
plt.legend()
plt.tight_layout()
# plt.savefig("msc_model_na.png")
plt.show()

# %%
# residuals
residuals_Na = [all_cond_calc_con[i] - cond_exp[i] for i in range(ndata)]

# making plot of residuals of calculated specific conductivity
fig = plt.figure(figsize=(4,4))
plt.plot(salt_conc, residuals_Na, "r.", label="MSA transport")
plt.title("Residuals Plot", fontsize=16,fontweight='bold')
plt.xlabel("NaCl Conc. (mM)", fontsize=16,fontweight='bold')
plt.ylabel("Residuals ($\mathbf{\mu}$S/cm)", fontsize=16,fontweight='bold')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.tick_params(direction="in",top=True, right=True)
plt.legend()
plt.tight_layout()
plt.show()
