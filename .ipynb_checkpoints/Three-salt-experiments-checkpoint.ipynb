# %%
# importing packages
import pyomo.environ as pyo
import numpy as np
from matplotlib import pyplot as plt
import math
import scipy.stats as stats
from scipy.optimize import fsolve, bisect, minimize
import pandas as pd
import conductivity_paper as cd
from scipy.optimize import brute
from matplotlib.ticker import MaxNLocator

# %% [markdown]
# # Determining the Best Cation Ratio for Three-Salt System Experiments

# %% [markdown]
# ## Load the data

# %%
data = pd.read_csv("./Data/Three_salts_cation_ratio.csv")
NaCl_conc_raw = data["NaCl_conc"]
CaCl2_conc_raw = data["CaCl2_conc"]
LaCl3_conc_raw = data["LaCl3_conc"]

# number of data points
ndata = len(NaCl_conc_raw)

print(data)
# Out:
#    NaCl_conc  CaCl2_conc  LaCl3_conc
# 0          1           1           2
# 1          2           2           4
# 2          3           3           6
# 3          4           4           8
# 4          5           5          10
# 5          6           6          12
# 6          7           7          14
# 7          8           8          16
# 8          9           9          18
# 9         10          10          20

# %% [markdown]
# ## MSA Transport model constants in SI units

# %%
# temperature in K
temp = 298.15

# diffusion coefficients at infinite dilution in m^2/s
Diff_Na = 1.334 * 10**(-9)
Diff_Cl = 2.032 * 10**(-9)
Diff_Ca = 0.792 * 10**(-9)
Diff_La = 0.619 * 10**(-9)
diffusion_coeff = [Diff_La, Diff_Ca, Diff_Na, Diff_Cl] 

# valencies
z_Na = 1
z_Cl = -1
z_Ca = 2
z_La = 3
valency = [z_La, z_Ca, z_Na, z_Cl]

# sensor voltage in V and probe distance in m
voltage = 25 * 10**(-3)
distance = 9 * 10**(-6)

# hard sphere diameters in m
sigma_Cl = 2 * 181 * 10**(-12)
sigma_Ca = 2 * 100 * 10**(-12)
sigma_La = 2 * 118 * 10**(-12)
sigma_Na = 2 * 102 * 10**(-12)
diameter = [sigma_La, sigma_Ca, sigma_Na, sigma_Cl]

# solvent viscosity in Pa.s
eta_msa = 0.89 * 10**(-3)

# relative permittivity
epsilon = 78.43

# limiting molar conductivity of ions in m^2.S/mol
lambda_0_Na_mol = 50.08 * 10**(-4)
lambda_0_Cl_mol = 76.31 * 10**(-4)
lambda_0_Ca_mol = 59.47 * 10**(-4)
lambda_0_La_mol = 69.7 * 10**(-4)
lambda_0_La_Ca_Na_Cl = [lambda_0_La_mol, lambda_0_Ca_mol, lambda_0_Na_mol, lambda_0_Cl_mol]

# %% [markdown]
# ## Variant Shedlovsky model constants

# %%
# solvent viscosity in poise
eta_shed = 8.903*10**(-3)

# limiting equivalent conductivity of salts in cm^2.Siemen.equiv^(-1)
lambda_0_NaCl = 126.45 
lambda_0_CaCl2 = 135.85
lambda_0_LaCl3 = 145.9

# limiting equivalent conductivity of ions in cm^2.Siemen.equiv^(-1)
lambda_0_Na = 50.10 
lambda_0_Ca = 59.5
lambda_0_La = 69.7
lambda_0_Cl = 76.35

# distance from an ion within which no other ion can penetrate in cm
a_NaCl = 4*10**(-8)
a_CaCl2 = 4.31*10**(-8)
a_LaCl3 = 4.9*10**(-8)

# %% [markdown]
# ## Validate the models with two-salt data

# %%
validation_data = pd.read_csv("./Data/NaCl_LaCl3_rearranged.csv")
NaCl_conc22 = validation_data["NaCl conc2"]
LaCl3_conc22 = validation_data["LaCl3 conc2"]
cond_exp_raw = validation_data["Cal bulk cond2"]

# number of data points
ndata_valid = len(cond_exp_raw)

# convert the conductivity from micro Siemen per cm to milli Siemen per cm
cond_exp = [cond_exp_raw[i]/1000 for i in range(ndata_valid)]

# diffusion coefficients, valencies, and hard sphere diameters of the two salts system
diffusion_coeff_2 = [Diff_La, Diff_Na, Diff_Cl]
valency_2 = [z_La, z_Na, z_Cl]
diameter_2 = [sigma_La, sigma_Na, sigma_Cl]
lambda_0_La_Na_Cl = [lambda_0_La_mol, lambda_0_Na_mol, lambda_0_Cl_mol]
a = (a_NaCl + a_LaCl3)/2

# evaluate the salts concentration in mM using the cation ratio
conc_NaCl_msa = [6*NaCl_conc_raw[i] for i in range(ndata)]

# evaluate the salts concentration in M using the cation ratio
conc_NaCl_shed = [conc_NaCl_msa[i]*10**(-3) for i in range(ndata)]
conc_LaCl3_shed = [LaCl3_conc_raw[i]*10**(-3) for i in range(ndata)]

# calculate the individual salt conductivity using the variant Shedlovsky model
variant_shed_cond_NaCl = cd.variant_shedlovsky(conc_NaCl_shed, temp, epsilon, eta_shed, lambda_0_NaCl, a, z_Na, z_Cl, 
                             lambda_0_Na, lambda_0_Cl)
variant_shed_cond_LaCl3 = cd.variant_shedlovsky(conc_LaCl3_shed, temp, epsilon, eta_shed, lambda_0_LaCl3, a, z_La, z_Cl, 
                             lambda_0_La, lambda_0_Cl)

# calculate the bulk conductivity using the variant Shedlovsky model
variant_shed_cond = [variant_shed_cond_NaCl[i] + variant_shed_cond_LaCl3[i] for i in range(ndata)] 

# calculate the bulk conductivity using the MSA transport model
msa_cond = cd.msa_transport(valency_2, diameter_2, diffusion_coeff_2, temp, eta_msa, epsilon, lambda_0_La_Na_Cl, LaCl3_conc_raw, conc_NaCl_msa)

sse = sum((msa_cond[i] - cond_exp[i])**2 for i in range(ndata))

err = [(msa_cond[i] - cond_exp[i])/msa_cond[i] for i in range(ndata)]
err_abs = [np.abs(err[i]) for i in range(ndata)]
print("MAPE",np.mean(err_abs))

print("The variant Shedlovsky:\n",variant_shed_cond)
print("MSA transport:\n",msa_cond)
print("SSE",sse)
# Out:
# Relaxation correction: [-0.17116259 -0.02670757 -0.09893508]
# Hydrodynamic correction: [-0.40925151 -0.19314246 -0.1171157 ]
# omega_bar: 293668709070.8091
# Alpha: [0.0, 242876329097.13528, 388092787538.26306]
# Mew: [0.5        0.16666667 0.33333333]
# Transport number: [0.25596141 0.18387319 0.5601654 ]
# Omega: [1.50335711e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.69629658 -0.98749428 -0.23296339]
#  [ 0.78711213  1.6842391  -1.40795025]
#  [ 0.51673602  0.63912188  1.0534202 ]]
# MAPE 0.020757235331234615
# The variant Shedlovsky:
#  [1.4836887591090644, 2.864356235130524, 4.188158227157195, 5.470507290133768, 6.719897842857053, 7.941830542973447, 9.140197040213245, 10.317912087125002, 11.477248024580849, 12.62003003909751]
# MSA transport:
#  [1.4308664142594345, 2.7320048114702002, 3.965863844897389, 5.152524109650507, 6.30276307653146, 7.423402745461817, 8.519172355316185, 9.593548816540238, 10.649196609867742, 11.688221935056538]
# SSE 0.4520929863589307

# %% [markdown]
# ## Solve the Optimization Problem

# %% [markdown]
# ### Validation of cation ratio with two-salt data

# %%
# create the objective function of the optimization problem
def SSE_validation(cation_ratio):
    """
    Calculates the sum of squared errors between the variant Shedlovsky and MSA Transport model

    Argument:
        cation_ratio: cation ratio of the salt"""

    # evaluate the salts concentration in mM using the cation ratio
    conc_NaCl = [cation_ratio*NaCl_conc_raw[i] for i in range(ndata)]

    # evaluate the salts concentration in M using the cation ratio
    conc_NaCl_shed = [conc_NaCl[i]*10**(-3) for i in range(ndata)]
    conc_LaCl3_shed = [LaCl3_conc_raw[i]*10**(-3) for i in range(ndata)]

    # calculate the individual salt conductivity using the variant Shedlovsky model
    variant_shed_cond_NaCl = cd.variant_shedlovsky(conc_NaCl_shed, temp, epsilon, eta_shed, lambda_0_NaCl, a, z_Na, z_Cl, 
                                 lambda_0_Na, lambda_0_Cl)
    variant_shed_cond_LaCl3 = cd.variant_shedlovsky(conc_LaCl3_shed, temp, epsilon, eta_shed, lambda_0_LaCl3, a, z_La, z_Cl, 
                                 lambda_0_La, lambda_0_Cl)

    # calculate the bulk conductivity using the variant Shedlovsky model
    variant_shed_cond = [variant_shed_cond_NaCl[i] + variant_shed_cond_LaCl3[i] for i in range(ndata)]

    # calculate the bulk conductivity using the MSA transport model
    msa_cond = cd.msa_transport(valency_2, diameter_2, diffusion_coeff_2, temp, eta_msa, epsilon, lambda_0_La_Na_Cl, LaCl3_conc_raw, conc_NaCl)

    # calculate the sum of squared errors between the variant Shedlovsky and MSA transport models
    sse = sum((msa_cond[i] - cond_exp[i])**2 for i in range(ndata))
    
    return sse

# %%
# Define bounds and step size for integers
ranges = (slice(1, 11, 1),)

# Run brute-force grid search
result = brute(SSE_validation, ranges=ranges, finish=None)

# Output
print("Best solution found for the cation ratio is:", result)
print("Objective value at best solution:", SSE_validation(result))
# Out:
# Relaxation correction: [-0.12637798 -0.01308509 -0.11019328]
# Hydrodynamic correction: [-0.36243161 -0.17069429 -0.10443014]
# omega_bar: 249407449467.97238
# Alpha: [0.0, 296713649948.1031, 372366303979.31903]
# Mew: [0.69230769 0.03846154 0.26923077]
# Transport number: [0.41730337 0.04996255 0.53273408]
# Omega: [1.50335711e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.44715366 -0.45169903 -0.31313326]
#  [ 0.67150534  3.76294459 -2.32471958]
#  [ 0.44084061  0.62394828  1.1373026 ]]
# Relaxation correction: [-0.13744596 -0.01647846 -0.10720408]
# Hydrodynamic correction: [-0.37274898 -0.17563275 -0.10724013]
# omega_bar: 260788916222.98755
# Alpha: [0.0, 280185123994.9613, 378474712351.47736]
# Mew: [0.64285714 0.07142857 0.28571429]
# Transport number: [0.37058471 0.08873811 0.54067718]
# Omega: [1.50335711e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.50778913 -0.58944861 -0.27849707]
#  [ 0.69964128  2.68345218 -1.89174574]
#  [ 0.45931175  0.65539633  1.09955484]]
# Relaxation correction: [-0.14726542 -0.01947212 -0.10466765]
# Hydrodynamic correction: [-0.38253793 -0.18032258 -0.10989853]
# omega_bar: 270652854077.33405
# Alpha: [0.0, 267813482005.23676, 382191609333.9359]
# Mew: [0.6 0.1 0.3]
# Transport number: [0.33327351 0.11970567 0.54702082]
# Omega: [1.50335711e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.56210047 -0.70202899 -0.25987673]
#  [ 0.72484272  2.23563967 -1.68236184]
#  [ 0.47585639  0.65884475  1.08054073]]
# Relaxation correction: [-0.15605343 -0.02213997 -0.10248805]
# Hydrodynamic correction: [-0.39185443 -0.18478999 -0.11242176]
# omega_bar: 279283799699.8872
# Alpha: [0.0, 257938769253.2734, 384750323408.8878]
# Mew: [0.5625 0.125  0.3125]
# Transport number: [0.3027882  0.14500788 0.55220392]
# Omega: [1.50335711e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.61111645 -0.80343498 -0.24786022]
#  [ 0.74758702  1.97908905 -1.55579469]
#  [ 0.49078793  0.65454734  1.06846628]]
# Relaxation correction: [-0.16397593 -0.02453754 -0.10059485]
# Hydrodynamic correction: [-0.4007456  -0.18905702 -0.11482358]
# omega_bar: 286899339955.0812
# Alpha: [0.0, 249777879676.05475, 386637077931.0033]
# Mew: [0.52941176 0.14705882 0.32352941]
# Transport number: [0.27741261 0.16606912 0.55651828]
# Omega: [1.50335711e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.65563681 -0.89795169 -0.23934982]
#  [ 0.76824527  1.80834802 -1.47012443]
#  [ 0.50434999  0.64739912  1.05990172]]
# Relaxation correction: [-0.17116259 -0.02670757 -0.09893508]
# Hydrodynamic correction: [-0.40925151 -0.19314246 -0.1171157 ]
# omega_bar: 293668709070.8091
# Alpha: [0.0, 242876329097.13528, 388092787538.26306]
# Mew: [0.5        0.16666667 0.33333333]
# Transport number: [0.25596141 0.18387319 0.5601654 ]
# Omega: [1.50335711e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.69629658 -0.98749428 -0.23296339]
#  [ 0.78711213  1.6842391  -1.40795025]
#  [ 0.51673602  0.63912188  1.0534202 ]]
# Relaxation correction: [-0.17771665 -0.02868365 -0.09746811]
# Hydrodynamic correction: [-0.41740657 -0.19706243 -0.11930813]
# omega_bar: 299725513016.4606
# Alpha: [0.0, 236940498593.5068, 389253155198.10046]
# Mew: [0.47368421 0.18421053 0.34210526]
# Transport number: [0.23758956 0.19912146 0.56328898]
# Omega: [1.50335711e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.73360883 -1.0731109  -0.22797496]
#  [ 0.80442568  1.58860351 -1.36062435]
#  [ 0.52810229  0.63044398  1.04830151]]
# Relaxation correction: [-0.1837216  -0.03049263 -0.09616219]
# Hydrodynamic correction: [-0.42524057 -0.20083089 -0.12140956]
# omega_bar: 305176636567.54675
# Alpha: [0.0, 231767716987.44742, 390201354983.3484]
# Mew: [0.45 0.2  0.35]
# Transport number: [0.22167841 0.2123274  0.56599419]
# Omega: [1.50335711e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.76799419 -1.1554554  -0.22396136]
#  [ 0.82038111  1.51178679 -1.32332278]
#  [ 0.53857697  0.62170735  1.04413477]]
# Relaxation correction: [-0.18924592 -0.03215629 -0.09499214]
# Hydrodynamic correction: [-0.43277951 -0.20446004 -0.1234275 ]
# omega_bar: 310108605494.72
# Alpha: [0.0, 227211586926.63376, 390991555841.196]
# Mew: [0.42857143 0.21428571 0.35714286]
# Transport number: [0.2077646  0.22387559 0.56835981]
# Omega: [1.50335711e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.79980186 -1.23497496 -0.22065722]
#  [ 0.83514044  1.44814689 -1.29312708]
#  [ 0.54826641  0.61308181  1.04066491]]
# Relaxation correction: [-0.19434642 -0.03369257 -0.09393776]
# Hydrodynamic correction: [-0.44004619 -0.20796059 -0.1253686 ]
# omega_bar: 314592213610.33203
# Alpha: [0.0, 223162755539.23566, 391660703361.5547]
# Mew: [0.40909091 0.22727273 0.36363636]
# Transport number: [0.19549426 0.23405973 0.57044601]
# Omega: [1.50335711e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.82932485 -1.31199679 -0.21788681]
#  [ 0.84883964  1.39414907 -1.26816143]
#  [ 0.55725988  0.60465321  1.03772356]]
# Best solution found for the cation ratio is: 6.0
# Relaxation correction: [-0.17116259 -0.02670757 -0.09893508]
# Hydrodynamic correction: [-0.40925151 -0.19314246 -0.1171157 ]
# omega_bar: 293668709070.8091
# Alpha: [0.0, 242876329097.13528, 388092787538.26306]
# Mew: [0.5        0.16666667 0.33333333]
# Transport number: [0.25596141 0.18387319 0.5601654 ]
# Omega: [1.50335711e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.69629658 -0.98749428 -0.23296339]
#  [ 0.78711213  1.6842391  -1.40795025]
#  [ 0.51673602  0.63912188  1.0534202 ]]
# Objective value at best solution: 0.4520929863589307

# %% [markdown]
# ## Determine the optimal concentrations for model discrimination in future three-salt experiments

# %%
# shedlovsky constants
a_Na_Ca_La = (a_NaCl + a_CaCl2 + a_LaCl3)/3

# %%
def three_salts_conc(LaCl3_conc, NaCl_conc, ionic_strength, fig_name):
    """
    Calculates the concentration of CaCl2 and the prediction difference between the Variant Shedlovsky and MSA models

    Arguments:
        LaCl3_conc: list or Pandas series of the concentration of LaCl3 in mM
        NaCl_conc: list or Pandas series of the concentration of NaCl in mM
        ionic_strength: int or float of the desired ionic strength of the three-salt solution

    Returns:
        residuals_percent: list of the prediction difference between the Variant Shedlovsky and MSA models
    """
    na_conc_plot = []
    la_conc_plot = []
    ca_conc_plot = []
    
    # save the results
    residuals_percent = []
    
    for conc_na in NaCl_conc:
        for conc_la in LaCl3_conc:
            conc_ca = (2 * ionic_strength - conc_na * (z_Na**2 + z_Cl**2) - conc_la * z_La * (z_La + z_Cl**2)) / (z_Ca * (z_Ca + z_Cl**2))
            conc_list = [conc_na, conc_ca, conc_la]
            
            print("The concentration of NaCl is:",conc_na)
            print("The concentration of LaCl3 is:",conc_la)
            print("The concentration of CaCl2 is:",conc_ca)

            if all(conc_species >= 1 for conc_species in conc_list):
                # append the species concentration to their respective list
                na_conc_plot.append(conc_na)
                la_conc_plot.append(conc_la)
                ca_conc_plot.append(conc_ca)

                # calculate the species ionic strength
                ionic_str_na = 0.5 * conc_na * z_Na**2
                ionic_str_la = 0.5 * conc_la * z_La**2
                ionic_str_ca = 0.5 * conc_ca * z_Ca**2
                ionic_str_cl = 0.5 * (z_Na * conc_na + z_Ca * conc_ca + z_La * conc_la) * z_Cl**2
                # print("The ionic strength of Na+ is:",ionic_str_na)
                # print("The ionic strength of La3+ is:",ionic_str_la)
                # print("The ionic strength of Ca2+ is:",ionic_str_ca)
                # print("The ionic strength of Cl- is:",ionic_str_cl)
                
                # evaluate the salts concentration in M using the cation ratio
                conc_NaCl_shed = [conc_na * 10**(-3)]
                conc_CaCl2_shed = [conc_ca * 10**(-3)]
                conc_LaCl3_shed = [conc_la * 10**(-3)]
        
                # calculate the individual salt conductivity using the variant Shedlovsky model
                variant_shed_cond_NaCl = cd.variant_shedlovsky(conc_NaCl_shed, temp, epsilon, eta_shed, lambda_0_NaCl, a_Na_Ca_La, z_Na, z_Cl, 
                                             lambda_0_Na, lambda_0_Cl)
                variant_shed_cond_CaCl2 = cd.variant_shedlovsky(conc_CaCl2_shed, temp, epsilon, eta_shed, lambda_0_CaCl2, a_Na_Ca_La, z_Ca, z_Cl, 
                                             lambda_0_Ca, lambda_0_Cl)
                variant_shed_cond_LaCl3 = cd.variant_shedlovsky(conc_LaCl3_shed, temp, epsilon, eta_shed, lambda_0_LaCl3, a_Na_Ca_La, z_La, z_Cl, 
                                             lambda_0_La, lambda_0_Cl)
            
                # get the number of data
                ndata_all = len(variant_shed_cond_NaCl)
            
                # calculate the bulk conductivity using the variant Shedlovsky model
                variant_shed_cond = [variant_shed_cond_NaCl[i] + variant_shed_cond_CaCl2[i] + variant_shed_cond_LaCl3[i] for i in range(ndata_all)]
            
                # calculate the bulk conductivity using the MSA transport model
                msa_cond = cd.msa_transport(valency, diameter, diffusion_coeff, temp, eta_msa, epsilon, lambda_0_La_Ca_Na_Cl, 
                                            [conc_la], [conc_ca], [conc_na])
        
                # mean of the predictions which may be treated as data
                mean_cond_pred = [(msa_cond[i] + variant_shed_cond[i])/2 for i in range(ndata_all)]
            
                # calculate the residuals between the MSA transport and variant Shedlovksy models
                residuals = [variant_shed_cond[i] - msa_cond[i] for i in range(ndata_all)]
                residuals_per = [100 * residuals[i] / msa_cond[i] for i in range(ndata_all)]
            
                # calculate the mean absolute percent error
                abs_residuals_per = [np.abs(residuals_per[i]) for i in range(ndata_all)]
                mean_abs_residuals_per = np.mean(abs_residuals_per)

                print(f"The MAPE is of {(conc_na, conc_la)}", mean_abs_residuals_per)
                
                residuals_percent.append([mean_abs_residuals_per])
            else:
                na_conc_plot.append(conc_na)
                la_conc_plot.append(conc_la)
                ca_conc_plot.append(np.nan)
                residuals_percent.append([np.nan])

    # plot the model difference results
    residuals_percent_array = np.asarray(residuals_percent)

    # X and Y axis labels
    x_label = "Concentration of Na$\mathbf{^{+}} (mM)$"
    y_label = "Concentration of La$\mathbf{^{3+}} (mM)$"
    data_res = np.zeros((len(residuals_percent_array), 3))
    data_res[:, 0] = na_conc_plot
    data_res[:, 1] = la_conc_plot
    data_res[:, 2] = residuals_percent_array[:, 0]

    plot_heatmap(data_res, y_label, x_label, "Model Prediction Difference (%)", fig_name)

    # plot the salt concentration results
    data_conc = np.zeros((len(ca_conc_plot), 3))
    data_conc[:, 0] = na_conc_plot
    data_conc[:, 1] = la_conc_plot
    data_conc[:, 2] = ca_conc_plot
    
    plot_heatmap(data_conc, y_label, x_label, "Concentration of Ca$\mathbf{^{2+}} (mM)$", f"{fig_name}_conc")

# %%
# # Make heat map
# def plot_heatmap(data, y_label, x_label, colorbar_label, figure_name):
#     # set heatmap x,y ranges
#     x_tick_labels_0 = np.sort(np.unique(data[:, 0]))
#     y_tick_labels_0 = np.sort(np.unique(data[:, 1]))[::-1]

#     x_tick_labels = [int(x_tick_labels_0[i]) for i in range(len(x_tick_labels_0))]
#     y_tick_labels = [int(y_tick_labels_0[i]) for i in range(len(y_tick_labels_0))]

#     # optimality-values
#     opt_vals = np.asarray(data[:, 2]).reshape(len(x_tick_labels), len(y_tick_labels))

#     # Plot the colormap
#     fig = plt.figure()

#     # Plotting options
#     ax = fig.add_subplot(111)
#     params = {"mathtext.default": "regular"}
#     plt.rcParams.update(params)

#     # Plotting data
#     ax.set_yticks(range(len(y_tick_labels)))
#     ax.set_yticklabels(y_tick_labels)
#     ax.set_ylabel(y_label, fontsize=16.5, fontweight='bold')
#     ax.set_xticks(range(len(x_tick_labels)))
#     ax.set_xticklabels(x_tick_labels)
#     ax.set_xlabel(x_label, fontsize=16.5, fontweight='bold')
#     ax.xaxis.set_major_locator(MaxNLocator(nbins=9))
#     ax.yaxis.set_major_locator(MaxNLocator(nbins=9))
#     plt.xticks(fontsize=16.5)
#     plt.yticks(fontsize=16.5)
#     im = ax.imshow(opt_vals.T, cmap=plt.cm.hot_r)
#     ba = plt.colorbar(im)
#     ba.set_label(colorbar_label, fontsize=16.5, fontweight='bold')
#     ba.ax.tick_params(labelsize=16.5)
#     plt.tight_layout()
#     plt.savefig(f"{figure_name}_three_salts_heat.png")
#     plt.show()

# %%
# Make heat map
def plot_heatmap(data, y_label, x_label, colorbar_label, figure_name):
    # set heatmap x,y ranges
    x_tick_labels_0 = np.sort(np.unique(data[:, 0]))
    y_tick_labels_0 = np.sort(np.unique(data[:, 1]))[::-1]

    x_tick_labels = [int(x) for x in x_tick_labels_0]
    y_tick_labels = [int(y) for y in y_tick_labels_0]

    # reshape values
    opt_vals = data[:, 2].reshape(len(x_tick_labels), len(y_tick_labels))

    # create figure
    fig, ax = plt.subplots()

    params = {"mathtext.default": "regular"}
    plt.rcParams.update(params)

    # colormap with solid gray for NaN
    cmap = plt.cm.hot_r.copy()
    cmap.set_bad(color='lightgray')

    # plot heatmap
    im = ax.imshow(opt_vals.T, cmap=cmap)

    # ticks and labels
    ax.set_yticks(range(len(y_tick_labels)))
    ax.set_yticklabels(y_tick_labels)
    ax.set_ylabel(y_label, fontsize=16.5, fontweight='bold')

    ax.set_xticks(range(len(x_tick_labels)))
    ax.set_xticklabels(x_tick_labels)
    ax.set_xlabel(x_label, fontsize=16.5, fontweight='bold')

    ax.xaxis.set_major_locator(MaxNLocator(nbins=9))
    ax.yaxis.set_major_locator(MaxNLocator(nbins=9))

    plt.xticks(fontsize=16.5)
    plt.yticks(fontsize=16.5)

    # colorbar
    cbar = plt.colorbar(im)
    cbar.set_label(colorbar_label, fontsize=16.5, fontweight='bold')
    cbar.ax.tick_params(labelsize=16.5)

    plt.tight_layout()
    plt.savefig(f"{figure_name}_three_salts_heat.png")
    plt.show()

# %% [markdown]
# ### 50 mM Ionic Strength

# %%
# desired ionic strength in mM
ionic_strength_50 = 50

# cation concentration in mM
# na_50 = [1, 2, 4, 6, 8, 10]
# la_50 = [6, 5, 4, 3, 2, 1]
na_50 = [1, 2, 4, 8, 10, 12, 14, 25, 50]
la_50 = [9, 8, 7, 6, 5, 4, 3, 2, 1]

three_salts_conc(la_50, na_50, ionic_strength_50, "ionic_str_50")
# Out:
# The concentration of NaCl is: 1
# The concentration of LaCl3 is: 9
# The concentration of CaCl2 is: -1.6666666666666667
# The concentration of NaCl is: 1
# The concentration of LaCl3 is: 8
# The concentration of CaCl2 is: 0.3333333333333333
# The concentration of NaCl is: 1
# The concentration of LaCl3 is: 7
# The concentration of CaCl2 is: 2.3333333333333335
# Relaxation correction: [-0.09547004 -0.03787809 -0.00984675 -0.08218058]
# Hydrodynamic correction: [-0.24638383 -0.1947205  -0.11546729 -0.07221905]
# omega_bar: 247506659560.32922
# Alpha: [0.0, 185817594865.33917, 315583157007.6054, 363032203089.45233]
# Mew: [0.63       0.09333333 0.01       0.26666667]
# Transport number: [0.38266242 0.07253483 0.01309002 0.53171273]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.44468591 -0.56170106 -0.26102938 -0.37750181]
#  [ 1.12911689  3.4688991  -0.4108092  -0.55637285]
#  [ 0.67036025  0.20497438  8.05829496 -3.31157634]
#  [ 0.44008887  0.10521752  0.45827907  1.21076264]]
# The MAPE is of (1, 7) 4.021410079690047
# The concentration of NaCl is: 1
# The concentration of LaCl3 is: 6
# The concentration of CaCl2 is: 4.333333333333333
# Relaxation correction: [-0.10143918 -0.04212955 -0.01169176 -0.07961638]
# Hydrodynamic correction: [-0.2465194  -0.19482762 -0.11553082 -0.07225883]
# omega_bar: 254299696466.77484
# Alpha: [0.0, 180387649440.44147, 315971065068.8834, 362728084606.32153]
# Mew: [0.54       0.17333333 0.01       0.27666667]
# Transport number: [0.31923469 0.13110913 0.01274035 0.53691583]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.48759237 -0.84537763 -0.25214399 -0.37592645]
#  [ 1.16265111  2.41061692 -0.396536   -0.55422155]
#  [ 0.69026962  0.25000476  8.18168913 -3.31839466]
#  [ 0.45315929  0.13071182  0.44484494  1.20090107]]
# The MAPE is of (1, 6) 5.713211647258711
# The concentration of NaCl is: 1
# The concentration of LaCl3 is: 5
# The concentration of CaCl2 is: 6.333333333333333
# Relaxation correction: [-0.10732494 -0.04631902 -0.01350523 -0.07709606]
# Hydrodynamic correction: [-0.24665497 -0.19493474 -0.11559434 -0.07229861]
# omega_bar: 261092733373.22052
# Alpha: [0.0, 175099100575.77954, 316322491934.8884, 362446505263.3725]
# Mew: [0.45       0.25333333 0.01       0.28666667]
# Transport number: [0.25910744 0.18663549 0.01240888 0.54184819]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.53200906 -1.14566151 -0.24412641 -0.37445039]
#  [ 1.19736566  1.8633889  -0.38367491 -0.55220327]
#  [ 0.71087976  0.26776969  8.30402593 -3.32468931]
#  [ 0.46668977  0.14236557  0.43260791  1.19177116]]
# The MAPE is of (1, 5) 6.548975394986452
# The concentration of NaCl is: 1
# The concentration of LaCl3 is: 4
# The concentration of CaCl2 is: 8.333333333333334
# Relaxation correction: [-0.11313029 -0.05044875 -0.01528847 -0.0746179 ]
# Hydrodynamic correction: [-0.24679054 -0.19504186 -0.11565786 -0.07233838]
# omega_bar: 267885770279.66617
# Alpha: [0.0, 169938160744.26645, 316642602391.1347, 362185037858.7051]
# Mew: [0.36       0.33333333 0.01       0.29666667]
# Transport number: [0.2020296  0.23934579 0.01209422 0.54653039]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.57807803 -1.50471501 -0.23684281 -0.37306515]
#  [ 1.23337159  1.48849712 -0.37200623 -0.55030696]
#  [ 0.7322566   0.2675669   8.42519951 -3.33052238]
#  [ 0.48072357  0.14445851  0.4213938   1.18329551]]
# The MAPE is of (1, 4) 6.690154059138299
# The concentration of NaCl is: 1
# The concentration of LaCl3 is: 3
# The concentration of CaCl2 is: 10.333333333333334
# Relaxation correction: [-0.11885797 -0.05452089 -0.01704265 -0.07218031]
# Hydrodynamic correction: [-0.24692611 -0.19514898 -0.11572138 -0.07237816]
# omega_bar: 274678807186.11182
# Alpha: [0.0, 164892365370.32532, 316935594411.348, 361941592006.33215]
# Mew: [0.27       0.41333333 0.01       0.30666667]
# Transport number: [0.14777493 0.28944894 0.01179512 0.55098101]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.62595747 -1.98295643 -0.23018675 -0.37176307]
#  [ 1.27079252  1.18679073 -0.36135551 -0.54852265]
#  [ 0.75447352  0.25212054  8.54514638 -3.33594632]
#  [ 0.49530889  0.13805499  0.41106273  1.17540714]]
# The MAPE is of (1, 3) 6.218939573467193
# The concentration of NaCl is: 1
# The concentration of LaCl3 is: 2
# The concentration of CaCl2 is: 12.333333333333334
# Relaxation correction: [-0.12451062 -0.05853742 -0.01876892 -0.06978176]
# Hydrodynamic correction: [-0.24706168 -0.19525609 -0.1157849  -0.07241794]
# omega_bar: 281471844092.5575
# Alpha: [0.0, 159950300470.24866, 317204921552.0537, 361714357740.9621]
# Mew: [0.18       0.49333333 0.01       0.31666667]
# Transport number: [0.09613902 0.33713372 0.01151045 0.55521681]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.67582441 -2.72134338 -0.22407231 -0.37053727]
#  [ 1.30976681  0.9099712  -0.35158218 -0.54684128]
#  [ 0.77761268  0.2204002   8.66383196 -3.34100572]
#  [ 0.51049966  0.12226952  0.40150076  1.16804778]]
# The MAPE is of (1, 2) 5.163572262847179
# The concentration of NaCl is: 1
# The concentration of LaCl3 is: 1
# The concentration of CaCl2 is: 14.333333333333334
# Relaxation correction: [-0.13009068 -0.06250025 -0.02046831 -0.06742084]
# Hydrodynamic correction: [-0.24719725 -0.19536321 -0.11584842 -0.07245772]
# omega_bar: 288264880999.0031
# Alpha: [0.0, 155101388104.71426, 317453455354.2293, 361501760050.10596]
# Mew: [0.09       0.57333333 0.01       0.32666667]
# Transport number: [0.04693674 0.38257109 0.01123921 0.55925297]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.72787801 -4.25858601 -0.21842928 -0.36938155]
#  [ 1.35045011  0.61279676 -0.34257152 -0.54525468]
#  [ 0.80176649  0.16510846  8.78124164 -3.34573875]
#  [ 0.52635654  0.09270871  0.39261394  1.16116656]]
# The MAPE is of (1, 1) 3.485285058843336
# The concentration of NaCl is: 2
# The concentration of LaCl3 is: 9
# The concentration of CaCl2 is: -2.0
# The concentration of NaCl is: 2
# The concentration of LaCl3 is: 8
# The concentration of CaCl2 is: 0.0
# The concentration of NaCl is: 2
# The concentration of LaCl3 is: 7
# The concentration of CaCl2 is: 2.0
# Relaxation correction: [-0.09641817 -0.03864609 -0.01022482 -0.08147465]
# Hydrodynamic correction: [-0.24634025 -0.19468607 -0.11544688 -0.07220625]
# omega_bar: 249826864991.60953
# Alpha: [0.0, 186572897565.1567, 308668402701.2538, 366828591024.95044]
# Mew: [0.63 0.08 0.02 0.27]
# Transport number: [0.37910854 0.06159529 0.02593691 0.53335926]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.45584564 -0.5317497  -0.33920814 -0.34707432]
#  [ 1.13783895  3.79310969 -0.5412421  -0.5096123 ]
#  [ 0.67553857  0.1994168   5.48198382 -2.82963451]
#  [ 0.44348841  0.10209333  0.54578081  1.17043887]]
# The MAPE is of (2, 7) 4.1804710249225865
# The concentration of NaCl is: 2
# The concentration of LaCl3 is: 6
# The concentration of CaCl2 is: 4.0
# Relaxation correction: [-0.10236888 -0.04288325 -0.01206201 -0.0789225 ]
# Hydrodynamic correction: [-0.24647582 -0.19479319 -0.1155104  -0.07224603]
# omega_bar: 256619901898.05518
# Alpha: [0.0, 180981633934.03104, 309370304281.88446, 366430799797.4742]
# Mew: [0.54 0.16 0.02 0.28]
# Transport number: [0.31634836 0.11992959 0.02525033 0.53847173]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.49904316 -0.82891105 -0.32696842 -0.34632344]
#  [ 1.17160065  2.53681075 -0.52094863 -0.50870587]
#  [ 0.695583    0.25117359  5.56481072 -2.84418812]
#  [ 0.4566475   0.13106707  0.53078041  1.16175486]]
# The MAPE is of (2, 6) 5.945403268794407
# The concentration of NaCl is: 2
# The concentration of LaCl3 is: 5
# The concentration of CaCl2 is: 6.0
# Relaxation correction: [-0.10823696 -0.04705899 -0.01386802 -0.07641373]
# Hydrodynamic correction: [-0.24661139 -0.19490031 -0.11557392 -0.07228581]
# omega_bar: 263412938804.50082
# Alpha: [0.0, 175556120050.73782, 310002903196.29, 366059839932.3729]
# Mew: [0.45 0.24 0.02 0.29]
# Transport number: [0.25682516 0.17525517 0.02459916 0.54332052]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.54378003 -1.13625203 -0.31610073 -0.34562175]
#  [ 1.20656545  1.9337168  -0.50297591 -0.50785854]
#  [ 0.71634171  0.27143691  5.64771609 -2.85802005]
#  [ 0.47027551  0.14411257  0.51725939  1.15371116]]
# The MAPE is of (2, 5) 6.829773669916017
# The concentration of NaCl is: 2
# The concentration of LaCl3 is: 4
# The concentration of CaCl2 is: 8.0
# Relaxation correction: [-0.11402529 -0.05117554 -0.0156441  -0.07394668]
# Hydrodynamic correction: [-0.24674696 -0.19500743 -0.11563744 -0.07232559]
# omega_bar: 270205975710.94647
# Alpha: [0.0, 170277642790.2532, 310576832725.47, 365713039139.39935]
# Mew: [0.36 0.32 0.02 0.3 ]
# Transport number: [0.20029482 0.22779895 0.02398073 0.54792551]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.59020131 -1.50034732 -0.30636092 -0.34496543]
#  [ 1.24284673  1.53328878 -0.48690601 -0.507066  ]
#  [ 0.73788202  0.27211134  5.7304355  -2.87119216]
#  [ 0.48441664  0.146768    0.50497047  1.14624173]]
# The MAPE is of (2, 4) 7.009423946641854
# The concentration of NaCl is: 2
# The concentration of LaCl3 is: 3
# The concentration of CaCl2 is: 10.0
# Relaxation correction: [-0.11973662 -0.05523499 -0.01739144 -0.07151975]
# Hydrodynamic correction: [-0.24688253 -0.19511455 -0.11570096 -0.07236537]
# omega_bar: 276999012617.39215
# Alpha: [0.0, 165129989710.72302, 311100533868.85645, 365388071495.96533]
# Mew: [0.27 0.4  0.02 0.31]
# Transport number: [0.14653714 0.2777656  0.02339263 0.55230463]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.63846875 -1.98305522 -0.29756219 -0.34435097]
#  [ 1.2805709   1.2168612  -0.47241992 -0.50632423]
#  [ 0.76027898  0.25670094  5.81278917 -2.88375855]
#  [ 0.49912016  0.14047229  0.4937225   1.13928912]]
# The MAPE is of (2, 3) 6.57191257622509
# The concentration of NaCl is: 2
# The concentration of LaCl3 is: 2
# The concentration of CaCl2 is: 12.0
# Relaxation correction: [-0.12537351 -0.05923932 -0.01911114 -0.06913147]
# Hydrodynamic correction: [-0.2470181  -0.19522166 -0.11576448 -0.07240515]
# omega_bar: 283792049523.83777
# Alpha: [0.0, 160098841776.71463, 311580814718.8463, 365082902930.9846]
# Mew: [0.18 0.48 0.02 0.32]
# Transport number: [0.09535302 0.32534018 0.02283269 0.55647411]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.68876354 -2.72642573 -0.28955874 -0.34377513]
#  [ 1.31987959  0.9300722  -0.45926925 -0.50562946]
#  [ 0.78361667  0.22446503  5.89465405 -2.89576683]
#  [ 0.51444126  0.12447711  0.48336479  1.13280312]]
# The MAPE is of (2, 2) 5.548271311720541
# The concentration of NaCl is: 2
# The concentration of LaCl3 is: 1
# The concentration of CaCl2 is: 14.0
# Relaxation correction: [-0.13093838 -0.06319039 -0.02080422 -0.06678044]
# Hydrodynamic correction: [-0.24715366 -0.19532878 -0.115828   -0.07244493]
# omega_bar: 290585086430.28345
# Alpha: [0.0, 155171331796.7938, 312023242111.7215, 364795746690.81824]
# Mew: [0.09 0.56 0.02 0.33]
# Transport number: [0.04656197 0.37069045 0.02229893 0.56044865]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.74128973 -4.27167391 -0.28223482 -0.34323493]
#  [ 1.36093225  0.62489205 -0.44725721 -0.50497819]
#  [ 0.80798976  0.16813013  5.97594608 -2.90725914]
#  [ 0.5304421   0.0943894   0.47377651  1.12673973]]
# The MAPE is of (2, 1) 3.901823423806008
# The concentration of NaCl is: 4
# The concentration of LaCl3 is: 9
# The concentration of CaCl2 is: -2.6666666666666665
# The concentration of NaCl is: 4
# The concentration of LaCl3 is: 8
# The concentration of CaCl2 is: -0.6666666666666666
# The concentration of NaCl is: 4
# The concentration of LaCl3 is: 7
# The concentration of CaCl2 is: 1.3333333333333333
# Relaxation correction: [-0.09830137 -0.04017162 -0.01097487 -0.08007299]
# Hydrodynamic correction: [-0.24625309 -0.19461721 -0.11540604 -0.07218066]
# omega_bar: 254467275854.17017
# Alpha: [0.0, 188230197788.77542, 296818820800.8823, 372366903690.0086]
# Mew: [0.63       0.05333333 0.04       0.27666667]
# Transport number: [0.3721952  0.0403147  0.05092786 0.53656224]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.47831652 -0.455633   -0.44391454 -0.3109356 ]
#  [ 1.15540142  4.76797687 -0.72801469 -0.45418505]
#  [ 0.68596546  0.1811693   3.71532233 -2.30838229]
#  [ 0.45033363  0.09220453  0.61402668  1.12932983]]
# The MAPE is of (4, 7) 4.294639708212562
# The concentration of NaCl is: 4
# The concentration of LaCl3 is: 6
# The concentration of CaCl2 is: 3.3333333333333335
# Relaxation correction: [-0.10421581 -0.04438062 -0.01279672 -0.0775445 ]
# Hydrodynamic correction: [-0.24638866 -0.19472433 -0.11546956 -0.07222044]
# omega_bar: 261260312760.6158
# Alpha: [0.0, 182269375290.9291, 298106567154.1274, 371866154322.16003]
# Mew: [0.54       0.13333333 0.04       0.28666667]
# Transport number: [0.31072949 0.0981662  0.04960368 0.54150063]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.52211455 -0.79022543 -0.42459573 -0.31090651]
#  [ 1.18963246  2.84313411 -0.69407118 -0.45434988]
#  [ 0.70628853  0.25211586  3.76627577 -2.32649007]
#  [ 0.46367564  0.13099726  0.59711681  1.12161315]]
# The MAPE is of (4, 6) 6.23394338543366
# The concentration of NaCl is: 4
# The concentration of LaCl3 is: 5
# The concentration of CaCl2 is: 5.333333333333333
# Relaxation correction: [-0.11004904 -0.04852933 -0.01458806 -0.07505845]
# Hydrodynamic correction: [-0.24652423 -0.19483145 -0.11553308 -0.07226022]
# omega_bar: 268053349667.06152
# Alpha: [0.0, 176537353347.26016, 299250675931.592, 371395521964.34393]
# Mew: [0.45       0.21333333 0.04       0.29666667]
# Transport number: [0.25237913 0.15308554 0.04834662 0.54618872]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.56751182 -1.11447603 -0.40803378 -0.31088768]
#  [ 1.2251134   2.0934255  -0.66511318 -0.45451833]
#  [ 0.72735368  0.27872461  3.81880336 -2.34392419]
#  [ 0.47750483  0.14753187  0.58231644  1.11445057]]
# The MAPE is of (4, 5) 7.228468232007999
# The concentration of NaCl is: 4
# The concentration of LaCl3 is: 4
# The concentration of CaCl2 is: 7.333333333333333
# Relaxation correction: [-0.11580386 -0.05261991 -0.0163501  -0.07261322]
# Hydrodynamic correction: [-0.24665979 -0.19493857 -0.11559661 -0.0723    ]
# omega_bar: 274846386573.50714
# Alpha: [0.0, 171000749074.97272, 300277063326.88495, 370952275278.8314]
# Mew: [0.36       0.29333333 0.04       0.30666667]
# Transport number: [0.19691311 0.20529013 0.04715169 0.55064507]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.61465977 -1.48985847 -0.39361417 -0.31087865]
#  [ 1.26196263  1.63163924 -0.64001156 -0.45469071]
#  [ 0.74923118  0.28155305  3.87226979 -2.36073148]
#  [ 0.49186732  0.15154157  0.56917511  1.10778754]]
# The MAPE is of (4, 4) 7.493502418642449
# The concentration of NaCl is: 4
# The concentration of LaCl3 is: 3
# The concentration of CaCl2 is: 9.333333333333334
# Relaxation correction: [-0.12148293 -0.05665437 -0.01808397 -0.07020728]
# Hydrodynamic correction: [-0.24679536 -0.19504569 -0.11566013 -0.07233978]
# omega_bar: 281639423479.95276
# Alpha: [0.0, 165632812168.40143, 301205270070.5873, 370534008954.33777]
# Mew: [0.27       0.37333333 0.04       0.31666667]
# Transport number: [0.14412273 0.25497642 0.04601441 0.55488644]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.6637276  -1.98212269 -0.38090066 -0.3108789 ]
#  [ 1.30031235  1.28153447 -0.61796801 -0.4548671 ]
#  [ 0.77199954  0.26629364  3.92625992 -2.37695369]
#  [ 0.50681466  0.14552161  0.55737108  1.10157632]]
# The MAPE is of (4, 3) 7.1297304317067045
# The concentration of NaCl is: 4
# The concentration of LaCl3 is: 2
# The concentration of CaCl2 is: 11.333333333333334
# Relaxation correction: [-0.12708874 -0.06063464 -0.01979074 -0.0678392 ]
# Hydrodynamic correction: [-0.24693093 -0.1951528  -0.11572365 -0.07237956]
# omega_bar: 288432460386.39844
# Alpha: [0.0, 160411431939.82968, 302050406611.3975, 370138596132.50397]
# Mew: [0.18       0.45333333 0.04       0.32666667]
# Transport number: [0.09381894 0.30232232 0.0449307  0.55892804]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.71490523 -2.73581666 -0.36957331 -0.31088786]
#  [ 1.34031103  0.97269952 -0.59839938 -0.45504745]
#  [ 0.79574688  0.23297801  3.98049431 -2.39262825]
#  [ 0.52240469  0.12909417  0.54666676  1.09577487]]
# The MAPE is of (4, 2) 6.1746243433754975
# The concentration of NaCl is: 4
# The concentration of LaCl3 is: 1
# The concentration of CaCl2 is: 13.333333333333334
# Relaxation correction: [-0.13262366 -0.06456252 -0.02147142 -0.06550764]
# Hydrodynamic correction: [-0.2470665  -0.19525992 -0.11578717 -0.07241934]
# omega_bar: 295225497292.8441
# Alpha: [0.0, 155317837600.71365, 302824403470.3615, 369764148942.8115]
# Mew: [0.09       0.53333333 0.04       0.33666667]
# Transport number: [0.0458301  0.34748939 0.04389686 0.56278364]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.76840702 -4.29728215 -0.35939113 -0.31090497]
#  [ 1.3821262   0.6502841  -0.58086798 -0.45523162]
#  [ 0.82057267  0.17444413  4.0347806  -2.4077889 ]
#  [ 0.53870273  0.09789934  0.53688189  1.09034614]]
# The MAPE is of (4, 1) 4.596055318925643
# The concentration of NaCl is: 8
# The concentration of LaCl3 is: 9
# The concentration of CaCl2 is: -4.0
# The concentration of NaCl is: 8
# The concentration of LaCl3 is: 8
# The concentration of CaCl2 is: -2.0
# The concentration of NaCl is: 8
# The concentration of LaCl3 is: 7
# The concentration of CaCl2 is: 0.0
# The concentration of NaCl is: 8
# The concentration of LaCl3 is: 6
# The concentration of CaCl2 is: 2.0
# Relaxation correction: [-0.10786109 -0.04733636 -0.01424365 -0.07482647]
# Hydrodynamic correction: [-0.24621433 -0.19458661 -0.11538789 -0.07216926]
# omega_bar: 270541134485.73712
# Alpha: [0.0, 185362979476.60516, 278940250508.88763, 379112764910.1386]
# Mew: [0.54 0.08 0.08 0.3 ]
# Transport number: [0.30007002 0.05687919 0.09580408 0.54724671]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.56897723 -0.67751877 -0.58092498 -0.27269107]
#  [ 1.22625872  3.86128383 -1.00553724 -0.39597384]
#  [ 0.72803366  0.24315789  2.5447882  -1.83653554]
#  [ 0.47795123  0.12501598  0.63519805  1.08617975]]
# The MAPE is of (8, 6) 6.278241867434604
# The concentration of NaCl is: 8
# The concentration of LaCl3 is: 5
# The concentration of CaCl2 is: 4.0
# Relaxation correction: [-0.11362666 -0.05143265 -0.01600666 -0.07238434]
# Hydrodynamic correction: [-0.2463499  -0.19469373 -0.11545141 -0.07220904]
# omega_bar: 277334171392.18286
# Alpha: [0.0, 178833828998.85138, 281163909155.25775, 378554171667.3565]
# Mew: [0.45 0.16 0.08 0.31]
# Transport number: [0.24393341 0.11097197 0.09345745 0.55163717]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.61577898 -1.05542157 -0.54789644 -0.27318958]
#  [ 1.26283736  2.52456898 -0.94104194 -0.39688547]
#  [ 0.74975052  0.29233976  2.57220595 -1.85370559]
#  [ 0.49220826  0.15361771  0.61723752  1.07978527]]
# The MAPE is of (8, 5) 7.550387866754661
# The concentration of NaCl is: 8
# The concentration of LaCl3 is: 4
# The concentration of CaCl2 is: 6.0
# Relaxation correction: [-0.11931638 -0.0554728  -0.01774155 -0.06998133]
# Hydrodynamic correction: [-0.24648547 -0.19480085 -0.11551494 -0.07224882]
# omega_bar: 284127208298.6284
# Alpha: [0.0, 172659039055.32272, 283096145435.56647, 378023960618.58466]
# Mew: [0.36 0.24 0.08 0.32]
# Transport number: [0.19048107 0.1624782  0.09122303 0.55581769]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.66447254 -1.4604697  -0.52108277 -0.27367414]
#  [ 1.30089457  1.87441021 -0.88921942 -0.39776908]
#  [ 0.7723452   0.30195809  2.60308958 -1.87039374]
#  [ 0.50704159  0.16173124  0.60236028  1.07380865]]
# The MAPE is of (8, 4) 8.017484298845027
# The concentration of NaCl is: 8
# The concentration of LaCl3 is: 3
# The concentration of CaCl2 is: 8.0
# Relaxation correction: [-0.12493273 -0.05945873 -0.01944938 -0.06761604]
# Hydrodynamic correction: [-0.24662104 -0.19490797 -0.11557846 -0.07228859]
# omega_bar: 290920245205.0741
# Alpha: [0.0, 166767393613.40012, 284801619171.77814, 377519904789.55164]
# Mew: [0.27 0.32 0.08 0.33]
# Transport number: [0.13952498 0.21157908 0.08909296 0.55980298]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.71524352 -1.97516023 -0.49869928 -0.27414593]
#  [ 1.34057543  1.43318392 -0.84634695 -0.39862692]
#  [ 0.79590385  0.28746158  2.63605238 -1.88662725]
#  [ 0.52250775  0.15659843  0.58968376  1.06821272]]
# The MAPE is of (8, 3) 7.822233118128456
# The concentration of NaCl is: 8
# The concentration of LaCl3 is: 2
# The concentration of CaCl2 is: 10.0
# Relaxation correction: [-0.13047807 -0.06339223 -0.02113114 -0.06528712]
# Hydrodynamic correction: [-0.24675661 -0.19501508 -0.11564198 -0.07232837]
# omega_bar: 297713282111.5197
# Alpha: [0.0, 161107556106.36478, 286325249871.9, 377040010168.2432]
# Mew: [0.18 0.4  0.08 0.34]
# Transport number: [0.09089426 0.25843925 0.08706009 0.5636064 ]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.7683012  -2.7512663  -0.47961567 -0.27460599]
#  [ 1.38204349  1.06935962 -0.81008521 -0.39946096]
#  [ 0.82052357  0.2517531   2.67028789 -1.90243091]
#  [ 0.53867049  0.13924658  0.57865257  1.06296451]]
# The MAPE is of (8, 2) 7.019787845990865
# The concentration of NaCl is: 8
# The concentration of LaCl3 is: 1
# The concentration of CaCl2 is: 12.0
# Relaxation correction: [-0.13595465 -0.06727501 -0.02278777 -0.06299332]
# Hydrodynamic correction: [-0.24689218 -0.1951222  -0.1157055  -0.07236815]
# omega_bar: 304506319017.9654
# Alpha: [0.0, 155640589538.19846, 287699646515.5768, 376582485659.39935]
# Mew: [0.09 0.48 0.08 0.35]
# Transport number: [0.04443328 0.30320867 0.08511792 0.56724013]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.82388279 -4.34614923 -0.4630738  -0.27505518]
#  [ 1.42548415  0.7065313  -0.77887661 -0.40027289]
#  [ 0.84631443  0.1882893   2.70529932 -1.91782732]
#  [ 0.55560209  0.10558646  0.56889563  1.05803469]]
# The MAPE is of (8, 1) 5.589019976621495
# The concentration of NaCl is: 10
# The concentration of LaCl3 is: 9
# The concentration of CaCl2 is: -4.666666666666667
# The concentration of NaCl is: 10
# The concentration of LaCl3 is: 8
# The concentration of CaCl2 is: -2.6666666666666665
# The concentration of NaCl is: 10
# The concentration of LaCl3 is: 7
# The concentration of CaCl2 is: -0.6666666666666666
# The concentration of NaCl is: 10
# The concentration of LaCl3 is: 6
# The concentration of CaCl2 is: 1.3333333333333333
# Relaxation correction: [-0.10966017 -0.04879531 -0.01495626 -0.07348586]
# Hydrodynamic correction: [-0.24612717 -0.19451775 -0.11534706 -0.07214367]
# omega_bar: 275181545348.29785
# Alpha: [0.0, 187272882411.60233, 270061259665.1941, 381788490641.30786]
# Mew: [0.54       0.05333333 0.1        0.30666667]
# Transport number: [0.29500991 0.03728002 0.11773566 0.54997441]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.59279257 -0.58860113 -0.6622077  -0.26030383]
#  [ 1.24487197  4.87068966 -1.18678511 -0.37714527]
#  [ 0.73908441  0.22631277  2.24227872 -1.69361332]
#  [ 0.48520601  0.11557571  0.64128095  1.07621678]]
# The MAPE is of (10, 6) 6.068842509141192
# The concentration of NaCl is: 10
# The concentration of LaCl3 is: 5
# The concentration of CaCl2 is: 3.3333333333333335
# Relaxation correction: [-0.11539289 -0.05286617 -0.01670558 -0.07106495]
# Hydrodynamic correction: [-0.24626274 -0.19462487 -0.11541058 -0.07218345]
# omega_bar: 281974582254.74347
# Alpha: [0.0, 180201521217.44305, 272937856847.4078, 381208871367.2971]
# Mew: [0.45       0.13333333 0.1        0.31666667]
# Transport number: [0.23991904 0.09095477 0.1148993  0.5542269 ]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.64034051 -1.01481301 -0.61597659 -0.26092751]
#  [ 1.2820338   2.83161013 -1.09077585 -0.37822935]
#  [ 0.76114751  0.29780955  2.26069613 -1.71011412]
#  [ 0.49969034  0.15580069  0.62070516  1.07008223]]
# The MAPE is of (10, 5) 7.519172500676226
# The concentration of NaCl is: 10
# The concentration of LaCl3 is: 4
# The concentration of CaCl2 is: 5.333333333333333
# Relaxation correction: [-0.12105096 -0.05688185 -0.01842734 -0.06868239]
# Hydrodynamic correction: [-0.24639831 -0.19473199 -0.1154741  -0.07222322]
# omega_bar: 288767619161.1891
# Alpha: [0.0, 173621035414.9269, 275380515252.3503, 380657255734.6425]
# Mew: [0.36       0.21333333 0.1        0.32666667]
# Transport number: [0.1874201  0.1421042  0.11219638 0.55827932]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.68985552 -1.44046825 -0.58021323 -0.26153232]
#  [ 1.32073304  2.02814261 -1.01761418 -0.3792793 ]
#  [ 0.78412337  0.31296945  2.28482547 -1.72618562]
#  [ 0.5147739   0.16714653  0.60454666  1.06433607]]
# The MAPE is of (10, 4) 8.10438232215956
# The concentration of NaCl is: 10
# The concentration of LaCl3 is: 3
# The concentration of CaCl2 is: 7.333333333333333
# Relaxation correction: [-0.12663681 -0.06084419 -0.02012256 -0.06633678]
# Hydrodynamic correction: [-0.24653388 -0.19483911 -0.11553762 -0.072263  ]
# omega_bar: 295560656067.63477
# Alpha: [0.0, 167412556429.81287, 277501781274.14825, 380131538845.7282]
# Mew: [0.27       0.29333333 0.1        0.33666667]
# Transport number: [0.13733439 0.19090244 0.10961771 0.56214546]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.74153229 -1.96871818 -0.55136622 -0.26211972]
#  [ 1.36112183  1.52336482 -0.95935309 -0.38029767]
#  [ 0.80810231  0.29921585  2.31214394 -1.74185091]
#  [ 0.53051599  0.16270884  0.59128136  1.05894475]]
# The MAPE is of (10, 3) 8.003510266759177
# The concentration of NaCl is: 10
# The concentration of LaCl3 is: 2
# The concentration of CaCl2 is: 9.333333333333334
# Relaxation correction: [-0.13215272 -0.06475495 -0.02179221 -0.06402685]
# Hydrodynamic correction: [-0.24666945 -0.19494622 -0.11560114 -0.07230278]
# omega_bar: 302353692974.08044
# Alpha: [0.0, 161497253491.03183, 279374271616.1836, 379629827536.59705]
# Mew: [0.18       0.37333333 0.1        0.34666667]
# Transport number: [0.08949925 0.23750797 0.10715491 0.56583788]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.79559076 -2.75716851 -0.52739681 -0.26269099]
#  [ 1.40337207  1.12461512 -0.91147859 -0.38128669]
#  [ 0.83318642  0.26216473  2.34133385 -1.75713111]
#  [ 0.5469836   0.1448583   0.58004822  1.05387843]]
# The MAPE is of (10, 2) 7.28424248665672
# The concentration of NaCl is: 10
# The concentration of LaCl3 is: 1
# The concentration of CaCl2 is: 11.333333333333334
# Relaxation correction: [-0.13760088 -0.06861577 -0.02343719 -0.06175137]
# Hydrodynamic correction: [-0.24680502 -0.19505334 -0.11566467 -0.07234256]
# omega_bar: 309146729880.52606
# Alpha: [0.0, 155819023646.7429, 281047932663.8795, 379150414052.70764]
# Mew: [0.09       0.45333333 0.1        0.35666667]
# Transport number: [0.04376632 0.28206532 0.10480034 0.56936803]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.85228082 -4.36935871 -0.50703246 -0.26324726]
#  [ 1.44767907  0.73783392 -0.87120074 -0.38224837]
#  [ 0.85949162  0.19591085  2.37164538 -1.77204551]
#  [ 0.56425287  0.10981258  0.57031604  1.04911046]]
# The MAPE is of (10, 1) 5.93227756591708
# The concentration of NaCl is: 12
# The concentration of LaCl3 is: 9
# The concentration of CaCl2 is: -5.333333333333333
# The concentration of NaCl is: 12
# The concentration of LaCl3 is: 8
# The concentration of CaCl2 is: -3.3333333333333335
# The concentration of NaCl is: 12
# The concentration of LaCl3 is: 7
# The concentration of CaCl2 is: -1.3333333333333333
# The concentration of NaCl is: 12
# The concentration of LaCl3 is: 6
# The concentration of CaCl2 is: 0.6666666666666666
# The concentration of NaCl is: 12
# The concentration of LaCl3 is: 5
# The concentration of CaCl2 is: 2.6666666666666665
# Relaxation correction: [-0.11714449 -0.05428795 -0.0173978  -0.06975701]
# Hydrodynamic correction: [-0.24617558 -0.19455601 -0.11536975 -0.07215785]
# omega_bar: 286614993117.3041
# Alpha: [0.0, 181768867315.7993, 264964245202.01266, 383481679884.3766]
# Mew: [0.45       0.10666667 0.12       0.32333333]
# Transport number: [0.23603465 0.07158574 0.13564684 0.55673277]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.66520552 -0.96282778 -0.68827782 -0.25098396]
#  [ 1.30146745  3.24803079 -1.2624855  -0.36314153]
#  [ 0.77268532  0.30114902  2.03135699 -1.59935619]
#  [ 0.50726487  0.15673608  0.62049681  1.06268234]]
# The MAPE is of (12, 5) 7.374421566510907
# The concentration of NaCl is: 12
# The concentration of LaCl3 is: 4
# The concentration of CaCl2 is: 4.666666666666667
# Relaxation correction: [-0.1227715  -0.05827961 -0.01910672 -0.06739445]
# Hydrodynamic correction: [-0.24631115 -0.19466313 -0.11543327 -0.07219763]
# omega_bar: 293408030023.74976
# Alpha: [0.0, 174696621364.11484, 267991448012.3691, 382916221797.92804]
# Mew: [0.36       0.18666667 0.12       0.33333333]
# Transport number: [0.18445595 0.12237465 0.13250632 0.56066308]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.71557628 -1.41583901 -0.6404747  -0.25167194]
#  [ 1.3408355   2.21344145 -1.15833806 -0.36430348]
#  [ 0.79605826  0.32452107  2.04945537 -1.6147817 ]
#  [ 0.52260911  0.17275133  0.60257805  1.05713705]]
# The MAPE is of (12, 4) 8.091823252795301
# The concentration of NaCl is: 12
# The concentration of LaCl3 is: 3
# The concentration of CaCl2 is: 6.666666666666667
# Relaxation correction: [-0.12832739 -0.06221881 -0.0207896  -0.06506813]
# Hydrodynamic correction: [-0.24644672 -0.19477025 -0.11549679 -0.07223741]
# omega_bar: 300201066930.19543
# Alpha: [0.0, 168121363704.5906, 270566992887.36124, 382376182808.16296]
# Mew: [0.27       0.26666667 0.12       0.34333333]
# Transport number: [0.13521152 0.17086503 0.12950793 0.56441552]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.76819715 -1.95994406 -0.60352502 -0.25233962]
#  [ 1.38196216  1.6261517  -1.07927958 -0.36543045]
#  [ 0.82047529  0.31190268  2.07236402 -1.62984031]
#  [ 0.5386388   0.16927026  0.58857076  1.05192424]]
# The MAPE is of (12, 3) 8.092609611732588
# The concentration of NaCl is: 12
# The concentration of LaCl3 is: 2
# The concentration of CaCl2 is: 8.666666666666666
# Relaxation correction: [-0.13381439 -0.06610723 -0.02244738 -0.0627768 ]
# Hydrodynamic correction: [-0.24658229 -0.19487736 -0.11556031 -0.07227719]
# omega_bar: 306994103836.64105
# Alpha: [0.0, 161919839402.55124, 272808088308.04092, 381859773116.5837]
# Mew: [0.18       0.34666667 0.12       0.35333333]
# Transport number: [0.08814641 0.21720946 0.12664223 0.5680019 ]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.82329953 -2.7617332  -0.57373074 -0.25298843]
#  [ 1.4250283   1.18555162 -1.01650001 -0.36652482]
#  [ 0.84604379  0.27338397  2.09790027 -1.64455032]
#  [ 0.55542442  0.15089058  0.57710426  1.04701668]]
# The MAPE is of (12, 2) 7.461018558813294
# The concentration of NaCl is: 12
# The concentration of LaCl3 is: 1
# The concentration of CaCl2 is: 10.666666666666666
# Relaxation correction: [-0.13923461 -0.0699465  -0.02408094 -0.06051928]
# Hydrodynamic correction: [-0.24671786 -0.19498448 -0.11562383 -0.07231697]
# omega_bar: 313787140743.0867
# Alpha: [0.0, 156010580907.74716, 274790182236.0728, 381365372291.65985]
# Mew: [0.09       0.42666667 0.12       0.36333333]
# Transport number: [0.04311908 0.26154731 0.12390061 0.57143299]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.88114692 -4.3917167  -0.5489765  -0.25361962]
#  [ 1.47023983  0.77162108 -0.96502557 -0.36758868]
#  [ 0.87288601  0.204071    2.12493916 -1.65892855]
#  [ 0.57304623  0.114333    0.56741127  1.04238999]]
# The MAPE is of (12, 1) 6.190850310193308
# The concentration of NaCl is: 14
# The concentration of LaCl3 is: 9
# The concentration of CaCl2 is: -6.0
# The concentration of NaCl is: 14
# The concentration of LaCl3 is: 8
# The concentration of CaCl2 is: -4.0
# The concentration of NaCl is: 14
# The concentration of LaCl3 is: 7
# The concentration of CaCl2 is: -2.0
# The concentration of NaCl is: 14
# The concentration of LaCl3 is: 6
# The concentration of CaCl2 is: 0.0
# The concentration of NaCl is: 14
# The concentration of LaCl3 is: 5
# The concentration of CaCl2 is: 2.0
# Relaxation correction: [-0.11888177 -0.05569824 -0.01808348 -0.06846025]
# Hydrodynamic correction: [-0.24608842 -0.19448715 -0.11532891 -0.07213226]
# omega_bar: 291255403979.8648
# Alpha: [0.0, 183601122196.15024, 257083029103.23724, 385464176102.3382]
# Mew: [0.45 0.08 0.14 0.33]
# Transport number: [0.23227404 0.0528339  0.15573326 0.55915879]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.69038829 -0.89340932 -0.76862002 -0.24267231]
#  [ 1.32114944  3.85973326 -1.47016042 -0.3505607 ]
#  [ 0.78437058  0.30015026  1.85308701 -1.51062138]
#  [ 0.5149362   0.15525604  0.61836262  1.05677088]]
# The MAPE is of (14, 5) 7.119893349931004
# The concentration of NaCl is: 14
# The concentration of LaCl3 is: 4
# The concentration of CaCl2 is: 4.0
# Relaxation correction: [-0.12447828 -0.05966634 -0.01977982 -0.06611728]
# Hydrodynamic correction: [-0.24622399 -0.19459427 -0.11539243 -0.07217204]
# omega_bar: 298048440886.3104
# Alpha: [0.0, 175913117463.13824, 260809461311.25122, 384890015769.03815]
# Mew: [0.36 0.16 0.14 0.34]
# Transport number: [0.18158409 0.10325945 0.15218383 0.56297262]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.74165057 -1.38530046 -0.70387008 -0.24341968]
#  [ 1.36121427  2.44315659 -1.31858317 -0.35180027]
#  [ 0.8081572   0.33655312  1.86485875 -1.52542322]
#  [ 0.53055202  0.17848728  0.59790092  1.05140699]]
# The MAPE is of (14, 4) 7.987521392137336
# The concentration of NaCl is: 14
# The concentration of LaCl3 is: 3
# The concentration of CaCl2 is: 6.0
# Relaxation correction: [-0.13000474 -0.06358281 -0.02145062 -0.06380986]
# Hydrodynamic correction: [-0.24635956 -0.19470139 -0.11545595 -0.07221182]
# omega_bar: 304841477792.7561
# Alpha: [0.0, 168905641758.31717, 263895770708.1699, 384340672322.311]
# Mew: [0.27 0.24 0.14 0.35]
# Transport number: [0.13315328 0.15143765 0.14879259 0.56661647]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.79525567 -1.94847878 -0.6565231  -0.24414495]
#  [ 1.40311017  1.74488714 -1.21054416 -0.35300292]
#  [ 0.83303093  0.32567096  1.88401151 -1.53989063]
#  [ 0.54688152  0.17634978  0.58294349  1.04635579]]
# The MAPE is of (14, 3) 8.098193449822855
# The concentration of NaCl is: 14
# The concentration of LaCl3 is: 2
# The concentration of CaCl2 is: 8.0
# Relaxation correction: [-0.13546332 -0.0674493  -0.02309678 -0.06153677]
# Hydrodynamic correction: [-0.24649513 -0.1948085  -0.11551947 -0.0722516 ]
# omega_bar: 311634514699.2017
# Alpha: [0.0, 162380190853.9166, 266534554159.9176, 383814457044.5754]
# Mew: [0.18 0.32 0.14 0.36]
# Transport number: [0.08683386 0.19751547 0.1455492  0.57010147]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.85144724 -2.76485255 -0.61969911 -0.24484962]
#  [ 1.44702758  1.25323083 -1.12826464 -0.35417106]
#  [ 0.85910483  0.2855301   1.90680389 -1.5540397 ]
#  [ 0.56399894  0.15740383  0.57121661  1.0415923 ]]
# The MAPE is of (14, 2) 7.559014533772863
# The concentration of NaCl is: 14
# The concentration of LaCl3 is: 1
# The concentration of CaCl2 is: 10.0
# Relaxation correction: [-0.14085608 -0.07126738 -0.02471915 -0.05929686]
# Hydrodynamic correction: [-0.2466307  -0.19491562 -0.115583   -0.07229138]
# omega_bar: 318427551605.64734
# Alpha: [0.0, 156216851490.4932, 268839814239.4434, 383309836072.39]
# Mew: [0.09 0.4  0.14 0.37]
# Transport number: [0.04249071 0.24162732 0.14244419 0.57343777]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.91050337 -4.41319544 -0.58987239 -0.24553499]
#  [ 1.49318382  0.80823166 -1.06279139 -0.35530683]
#  [ 0.88650793  0.21283603  1.93153661 -1.56788529]
#  [ 0.58198897  0.11918347  0.56159444  1.03709411]]
# The MAPE is of (14, 1) 6.373632108538683
# The concentration of NaCl is: 25
# The concentration of LaCl3 is: 9
# The concentration of CaCl2 is: -9.666666666666666
# The concentration of NaCl is: 25
# The concentration of LaCl3 is: 8
# The concentration of CaCl2 is: -7.666666666666667
# The concentration of NaCl is: 25
# The concentration of LaCl3 is: 7
# The concentration of CaCl2 is: -5.666666666666667
# The concentration of NaCl is: 25
# The concentration of LaCl3 is: 6
# The concentration of CaCl2 is: -3.6666666666666665
# The concentration of NaCl is: 25
# The concentration of LaCl3 is: 5
# The concentration of CaCl2 is: -1.6666666666666667
# The concentration of NaCl is: 25
# The concentration of LaCl3 is: 4
# The concentration of CaCl2 is: 0.3333333333333333
# The concentration of NaCl is: 25
# The concentration of LaCl3 is: 3
# The concentration of CaCl2 is: 2.3333333333333335
# Relaxation correction: [-0.13900499 -0.07090412 -0.02498453 -0.05706579]
# Hydrodynamic correction: [-0.24588017 -0.19432266 -0.11523136 -0.07207107]
# omega_bar: 330363737536.8397
# Alpha: [0.0, 175670689426.9423, 228753332430.34155, 392082251738.6148]
# Mew: [0.27       0.09333333 0.25       0.38666667]
# Transport number: [0.12286652 0.05434269 0.24517432 0.57761648]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.9519798  -1.80356657 -1.01480447 -0.21449518]
#  [ 1.52560037  3.10462259 -2.51804622 -0.30829528]
#  [ 0.90575375  0.4331948   1.23507056 -1.24309444]
#  [ 0.59462377  0.2299125   0.51788073  1.02791776]]
# The MAPE is of (25, 3) 6.836536612176043
# The concentration of NaCl is: 25
# The concentration of LaCl3 is: 2
# The concentration of CaCl2 is: 4.333333333333333
# Relaxation correction: [-0.14431547 -0.07465652 -0.02657069 -0.05488697]
# Hydrodynamic correction: [-0.24601574 -0.19442978 -0.11529488 -0.07211085]
# omega_bar: 337156774443.28534
# Alpha: [0.0, 165955236962.0318, 234883622076.90878, 391545703072.44666]
# Mew: [0.18       0.17333333 0.25       0.39666667]
# Transport number: [0.08026067 0.09888875 0.24023454 0.58061604]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 2.01508365 -2.74986384 -0.88922661 -0.21532688]
#  [ 1.57492017  1.8377829  -2.03928754 -0.30961354]
#  [ 0.93503507  0.37813108  1.25338409 -1.25473238]
#  [ 0.61384684  0.20645467  0.50468388  1.02380238]]
# The MAPE is of (25, 2) 6.927730021095404
# The concentration of NaCl is: 25
# The concentration of LaCl3 is: 1
# The concentration of CaCl2 is: 6.333333333333333
# Relaxation correction: [-0.14956493 -0.07836426 -0.02813519 -0.05273824]
# Hydrodynamic correction: [-0.24615131 -0.19453689 -0.11535841 -0.07215063]
# omega_bar: 343949811349.73096
# Alpha: [0.0, 157719508873.96625, 239540147354.91776, 391027793012.37006]
# Mew: [0.09       0.25333333 0.25       0.40666667]
# Transport number: [0.03933776 0.14167524 0.23548989 0.58349711]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 2.08184256 -4.51458491 -0.81154749 -0.21613721]
#  [ 1.62709665  1.08372806 -1.77195616 -0.31089841]
#  [ 0.9660124   0.27631353  1.27818789 -1.26616483]
#  [ 0.63418334  0.15415529  0.49767507  1.01988808]]
# The MAPE is of (25, 1) 6.274439399893544
# The concentration of NaCl is: 50
# The concentration of LaCl3 is: 9
# The concentration of CaCl2 is: -18.0
# The concentration of NaCl is: 50
# The concentration of LaCl3 is: 8
# The concentration of CaCl2 is: -16.0
# The concentration of NaCl is: 50
# The concentration of LaCl3 is: 7
# The concentration of CaCl2 is: -14.0
# The concentration of NaCl is: 50
# The concentration of LaCl3 is: 6
# The concentration of CaCl2 is: -12.0
# The concentration of NaCl is: 50
# The concentration of LaCl3 is: 5
# The concentration of CaCl2 is: -10.0
# The concentration of NaCl is: 50
# The concentration of LaCl3 is: 4
# The concentration of CaCl2 is: -8.0
# The concentration of NaCl is: 50
# The concentration of LaCl3 is: 3
# The concentration of CaCl2 is: -6.0
# The concentration of NaCl is: 50
# The concentration of LaCl3 is: 2
# The concentration of CaCl2 is: -4.0
# The concentration of NaCl is: 50
# The concentration of LaCl3 is: 1
# The concentration of CaCl2 is: -2.0

# %% [markdown]
# ### 100 mM Ionic Strength

# %%
# data in mM
ionic_strength_100 = 100

# cation concentration in mM
# na_100 = [4, 8, 10, 12, 15, 20]
# la_100 = [12, 10, 8, 6, 5, 4]
na_100 = [4, 8, 12, 15, 20, 25, 30, 50, 75]
la_100 = [16, 14, 12, 10, 8, 7, 6, 5, 4]

three_salts_conc(la_100, na_100, ionic_strength_100, "ionic_str_100")
# Out:
# The concentration of NaCl is: 4
# The concentration of LaCl3 is: 16
# The concentration of CaCl2 is: 0.0
# The concentration of NaCl is: 4
# The concentration of LaCl3 is: 14
# The concentration of CaCl2 is: 4.0
# Relaxation correction: [-0.12043329 -0.0484649  -0.01285613 -0.10180263]
# Hydrodynamic correction: [-0.32737806 -0.25973342 -0.15395153 -0.09481732]
# omega_bar: 249826864991.60953
# Alpha: [0.0, 186572897565.1567, 308668402701.2538, 366828591024.95044]
# Mew: [0.63 0.08 0.02 0.27]
# Transport number: [0.37910854 0.06159529 0.02593691 0.53335926]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.45584564 -0.5317497  -0.33920814 -0.34707432]
#  [ 1.13783895  3.79310969 -0.5412421  -0.5096123 ]
#  [ 0.67553857  0.1994168   5.48198382 -2.82963451]
#  [ 0.44348841  0.10209333  0.54578081  1.17043887]]
# The MAPE is of (4, 14) 5.301159769954976
# The concentration of NaCl is: 4
# The concentration of LaCl3 is: 12
# The concentration of CaCl2 is: 8.0
# Relaxation correction: [-0.1278413  -0.05379197 -0.01517213 -0.09863655]
# Hydrodynamic correction: [-0.32762445 -0.25992877 -0.15406733 -0.09488889]
# omega_bar: 256619901898.05518
# Alpha: [0.0, 180981633934.03104, 309370304281.88446, 366430799797.4742]
# Mew: [0.54 0.16 0.02 0.28]
# Transport number: [0.31634836 0.11992959 0.02525033 0.53847173]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.49904316 -0.82891105 -0.32696842 -0.34632344]
#  [ 1.17160065  2.53681075 -0.52094863 -0.50870587]
#  [ 0.695583    0.25117359  5.56481072 -2.84418812]
#  [ 0.4566475   0.13106707  0.53078041  1.16175486]]
# The MAPE is of (4, 12) 7.581045975606135
# The concentration of NaCl is: 4
# The concentration of LaCl3 is: 10
# The concentration of CaCl2 is: 12.0
# Relaxation correction: [-0.13513672 -0.05903508 -0.01744542 -0.09552974]
# Hydrodynamic correction: [-0.32787083 -0.26012412 -0.15418313 -0.09496045]
# omega_bar: 263412938804.50082
# Alpha: [0.0, 175556120050.73782, 310002903196.29, 366059839932.3729]
# Mew: [0.45 0.24 0.02 0.29]
# Transport number: [0.25682516 0.17525517 0.02459916 0.54332052]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.54378003 -1.13625203 -0.31610073 -0.34562175]
#  [ 1.20656545  1.9337168  -0.50297591 -0.50785854]
#  [ 0.71634171  0.27143691  5.64771609 -2.85802005]
#  [ 0.47027551  0.14411257  0.51725939  1.15371116]]
# The MAPE is of (4, 10) 8.717113770252864
# The concentration of NaCl is: 4
# The concentration of LaCl3 is: 8
# The concentration of CaCl2 is: 16.0
# Relaxation correction: [-0.14232358 -0.06419735 -0.01967776 -0.09247987]
# Hydrodynamic correction: [-0.32811721 -0.26031947 -0.15429893 -0.09503201]
# omega_bar: 270205975710.94647
# Alpha: [0.0, 170277642790.2532, 310576832725.47, 365713039139.39935]
# Mew: [0.36 0.32 0.02 0.3 ]
# Transport number: [0.20029482 0.22779895 0.02398073 0.54792551]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.59020131 -1.50034732 -0.30636092 -0.34496543]
#  [ 1.24284673  1.53328878 -0.48690601 -0.507066  ]
#  [ 0.73788202  0.27211134  5.7304355  -2.87119216]
#  [ 0.48441664  0.146768    0.50497047  1.14624173]]
# The MAPE is of (4, 8) 8.958707496663106
# The concentration of NaCl is: 4
# The concentration of LaCl3 is: 7
# The concentration of CaCl2 is: 18.0
# Relaxation correction: [-0.14587749 -0.06674909 -0.02077909 -0.09097559]
# Hydrodynamic correction: [-0.32824041 -0.26041715 -0.15435683 -0.09506779]
# omega_bar: 273602494164.1693
# Alpha: [0.0, 167688396729.12244, 310844503308.16095, 365547959578.9586]
# Mew: [0.315 0.36  0.02  0.305]
# Transport number: [0.1730823  0.25309242 0.02368303 0.55014225]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.61409343 -1.72116214 -0.30185384 -0.34465318]
#  [ 1.26151999  1.36859654 -0.47948191 -0.50668901]
#  [ 0.74896839  0.26636724  5.77166683 -2.87754795]
#  [ 0.4916948   0.14473434  0.49922659  1.14270412]]
# The MAPE is of (4, 7) 8.784923875707104
# The concentration of NaCl is: 4
# The concentration of LaCl3 is: 6
# The concentration of CaCl2 is: 20.0
# Relaxation correction: [-0.14940567 -0.06928169 -0.02187079 -0.08948472]
# Hydrodynamic correction: [-0.3283636  -0.26051482 -0.15441472 -0.09510357]
# omega_bar: 276999012617.39215
# Alpha: [0.0, 165129989710.72302, 311100533868.85645, 365388071495.96533]
# Mew: [0.27 0.4  0.02 0.31]
# Transport number: [0.14653714 0.2777656  0.02339263 0.55230463]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.63846875 -1.98305522 -0.29756219 -0.34435097]
#  [ 1.2805709   1.2168612  -0.47241992 -0.50632423]
#  [ 0.76027898  0.25670094  5.81278917 -2.88375855]
#  [ 0.49912016  0.14047229  0.4937225   1.13928912]]
# The MAPE is of (4, 6) 8.426040156642454
# The concentration of NaCl is: 4
# The concentration of LaCl3 is: 5
# The concentration of CaCl2 is: 22.0
# Relaxation correction: [-0.15290856 -0.0717955  -0.02295305 -0.08800702]
# Hydrodynamic correction: [-0.32848679 -0.2606125  -0.15447262 -0.09513935]
# omega_bar: 280395531070.615
# Alpha: [0.0, 162600686498.94003, 311345728540.88776, 365233129333.956]
# Mew: [0.225 0.44  0.02  0.315]
# Transport number: [0.12063507 0.30184103 0.02310927 0.55441462]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.66335055 -2.30612837 -0.29346889 -0.34405842]
#  [ 1.30001767  1.07241843 -0.46569099 -0.50597119]
#  [ 0.77182458  0.24290936  5.85378872 -2.8898297 ]
#  [ 0.5066998   0.13383043  0.48844051  1.13599068]]
# The MAPE is of (4, 5) 7.884674514394245
# The concentration of NaCl is: 4
# The concentration of LaCl3 is: 4
# The concentration of CaCl2 is: 24.0
# Relaxation correction: [-0.15638657 -0.07429084 -0.02402605 -0.08654224]
# Hydrodynamic correction: [-0.32860998 -0.26071017 -0.15453052 -0.09517513]
# omega_bar: 283792049523.83777
# Alpha: [0.0, 160098841776.71463, 311580814718.8463, 365082902930.9846]
# Mew: [0.18 0.48 0.02 0.32]
# Transport number: [0.09535302 0.32534018 0.02283269 0.55647411]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.68876354 -2.72642573 -0.28955874 -0.34377513]
#  [ 1.31987959  0.9300722  -0.45926925 -0.50562946]
#  [ 0.78361667  0.22446503  5.89465405 -2.89576683]
#  [ 0.51444126  0.12447711  0.48336479  1.13280312]]
# The MAPE is of (4, 4) 7.158065693290834
# The concentration of NaCl is: 8
# The concentration of LaCl3 is: 16
# The concentration of CaCl2 is: -1.3333333333333333
# The concentration of NaCl is: 8
# The concentration of LaCl3 is: 14
# The concentration of CaCl2 is: 2.6666666666666665
# Relaxation correction: [-0.1227306  -0.05036911 -0.01380208 -0.10000729]
# Hydrodynamic correction: [-0.32722507 -0.25961216 -0.15387965 -0.09477282]
# omega_bar: 254467275854.17017
# Alpha: [0.0, 188230197788.77542, 296818820800.8823, 372366903690.0086]
# Mew: [0.63       0.05333333 0.04       0.27666667]
# Transport number: [0.3721952  0.0403147  0.05092786 0.53656224]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.47831652 -0.455633   -0.44391454 -0.3109356 ]
#  [ 1.15540142  4.76797687 -0.72801469 -0.45418505]
#  [ 0.68596546  0.1811693   3.71532233 -2.30838229]
#  [ 0.45033363  0.09220453  0.61402668  1.12932983]]
# The MAPE is of (8, 14) 5.446777147927716
# The concentration of NaCl is: 8
# The concentration of LaCl3 is: 12
# The concentration of CaCl2 is: 6.666666666666667
# Relaxation correction: [-0.13008925 -0.0556577  -0.01609705 -0.0968737 ]
# Hydrodynamic correction: [-0.32747146 -0.25980751 -0.15399545 -0.09484438]
# omega_bar: 261260312760.6158
# Alpha: [0.0, 182269375290.9291, 298106567154.1274, 371866154322.16003]
# Mew: [0.54       0.13333333 0.04       0.28666667]
# Transport number: [0.31072949 0.0981662  0.04960368 0.54150063]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.52211455 -0.79022543 -0.42459573 -0.31090651]
#  [ 1.18963246  2.84313411 -0.69407118 -0.45434988]
#  [ 0.70628853  0.25211586  3.76627577 -2.32649007]
#  [ 0.46367564  0.13099726  0.59711681  1.12161315]]
# The MAPE is of (8, 12) 7.962588888863204
# The concentration of NaCl is: 8
# The concentration of LaCl3 is: 10
# The concentration of CaCl2 is: 10.666666666666666
# Relaxation correction: [-0.1373373  -0.06086392 -0.01835025 -0.09379805]
# Hydrodynamic correction: [-0.32771784 -0.26000286 -0.15411125 -0.09491594]
# omega_bar: 268053349667.06152
# Alpha: [0.0, 176537353347.26016, 299250675931.592, 371395521964.34393]
# Mew: [0.45       0.21333333 0.04       0.29666667]
# Transport number: [0.25237913 0.15308554 0.04834662 0.54618872]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.56751182 -1.11447603 -0.40803378 -0.31088768]
#  [ 1.2251134   2.0934255  -0.66511318 -0.45451833]
#  [ 0.72735368  0.27872461  3.81880336 -2.34392419]
#  [ 0.47750483  0.14753187  0.58231644  1.11445057]]
# The MAPE is of (8, 10) 9.240989918861537
# The concentration of NaCl is: 8
# The concentration of LaCl3 is: 8
# The concentration of CaCl2 is: 14.666666666666666
# Relaxation correction: [-0.14447865 -0.06599075 -0.02056337 -0.09077809]
# Hydrodynamic correction: [-0.32796423 -0.26019821 -0.15422705 -0.0949875 ]
# omega_bar: 274846386573.50714
# Alpha: [0.0, 171000749074.97272, 300277063326.88495, 370952275278.8314]
# Mew: [0.36       0.29333333 0.04       0.30666667]
# Transport number: [0.19691311 0.20529013 0.04715169 0.55064507]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.61465977 -1.48985847 -0.39361417 -0.31087865]
#  [ 1.26196263  1.63163924 -0.64001156 -0.45469071]
#  [ 0.74923118  0.28155305  3.87226979 -2.36073148]
#  [ 0.49186732  0.15154157  0.56917511  1.10778754]]
# The MAPE is of (8, 8) 9.589565187744794
# The concentration of NaCl is: 8
# The concentration of LaCl3 is: 7
# The concentration of CaCl2 is: 16.666666666666668
# Relaxation correction: [-0.14801047 -0.06852528 -0.0216554  -0.08928833]
# Hydrodynamic correction: [-0.32808742 -0.26029589 -0.15428494 -0.09502329]
# omega_bar: 278242905026.73
# Alpha: [0.0, 168297170106.10666, 300752408227.28937, 370740158528.7974]
# Mew: [0.315      0.33333333 0.04       0.31166667]
# Transport number: [0.17019571 0.23043653 0.04657611 0.55279164]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.63894236 -1.71551491 -0.38706636 -0.31087765]
#  [ 1.28094106  1.44801861 -0.62864804 -0.4547784 ]
#  [ 0.76049874  0.27606823  3.89921934 -2.36891328]
#  [ 0.49926443  0.14974844  0.56312238  1.10462821]]
# The MAPE is of (8, 7) 9.46247337810141
# The concentration of NaCl is: 8
# The concentration of LaCl3 is: 6
# The concentration of CaCl2 is: 18.666666666666668
# Relaxation correction: [-0.15151698 -0.07104102 -0.02273799 -0.0878117 ]
# Hydrodynamic correction: [-0.32821061 -0.26039357 -0.15434284 -0.09505907]
# omega_bar: 281639423479.95276
# Alpha: [0.0, 165632812168.40143, 301205270070.5873, 370534008954.33777]
# Mew: [0.27       0.37333333 0.04       0.31666667]
# Transport number: [0.14412273 0.25497642 0.04601441 0.55488644]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.6637276  -1.98212269 -0.38090066 -0.3108789 ]
#  [ 1.30031235  1.28153447 -0.61796801 -0.4548671 ]
#  [ 0.77199954  0.26629364  3.92625992 -2.37695369]
#  [ 0.50681466  0.14552161  0.55737108  1.10157632]]
# The MAPE is of (8, 6) 9.147604845598556
# The concentration of NaCl is: 8
# The concentration of LaCl3 is: 5
# The concentration of CaCl2 is: 20.666666666666668
# Relaxation correction: [-0.1549986  -0.07353829 -0.02381133 -0.08634796]
# Hydrodynamic correction: [-0.3283338  -0.26049124 -0.15440074 -0.09509485]
# omega_bar: 285035941933.17566
# Alpha: [0.0, 163005041985.73526, 301637413274.52264, 370333569034.13226]
# Mew: [0.225      0.41333333 0.04       0.32166667]
# Transport number: [0.11867112 0.27893146 0.0454661  0.55693132]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.68903991 -2.31007815 -0.3750803  -0.31088233]
#  [ 1.32009559  1.125133   -0.60790449 -0.45495679]
#  [ 0.78374491  0.25209486  3.95336023 -2.38485724]
#  [ 0.51452545  0.13874243  0.55189383  1.09862679]]
# The MAPE is of (8, 5) 8.648546313051236
# The concentration of NaCl is: 8
# The concentration of LaCl3 is: 4
# The concentration of CaCl2 is: 22.666666666666668
# Relaxation correction: [-0.15845576 -0.0760174  -0.0248756  -0.08489688]
# Hydrodynamic correction: [-0.32845699 -0.26058892 -0.15445864 -0.09513063]
# omega_bar: 288432460386.39844
# Alpha: [0.0, 160411431939.82968, 302050406611.3975, 370138596132.50397]
# Mew: [0.18       0.45333333 0.04       0.32666667]
# Transport number: [0.09381894 0.30232232 0.0449307  0.55892804]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.71490523 -2.73581666 -0.36957331 -0.31088786]
#  [ 1.34031103  0.97269952 -0.59839938 -0.45504745]
#  [ 0.79574688  0.23297801  3.98049431 -2.39262825]
#  [ 0.52240469  0.12909417  0.54666676  1.09577487]]
# The MAPE is of (8, 4) 7.9633510280746425
# The concentration of NaCl is: 12
# The concentration of LaCl3 is: 16
# The concentration of CaCl2 is: -2.6666666666666665
# The concentration of NaCl is: 12
# The concentration of LaCl3 is: 14
# The concentration of CaCl2 is: 1.3333333333333333
# Relaxation correction: [-0.12500465 -0.05225455 -0.01473712 -0.09823034]
# Hydrodynamic correction: [-0.32707209 -0.2594909  -0.15380777 -0.09472832]
# omega_bar: 259107686716.73083
# Alpha: [0.0, 190129436230.03653, 286272564838.3666, 376452302920.04724]
# Mew: [0.63       0.02666667 0.06       0.28333333]
# Transport number: [0.36552948 0.01979635 0.07502367 0.5396505 ]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.50099827 -0.34028972 -0.5327315  -0.28837773]
#  [ 1.17312869  6.93916956 -0.89994585 -0.41970794]
#  [ 0.6964902   0.14437687  2.96062079 -2.01442507]
#  [ 0.45724307  0.07297196  0.64228995  1.10730243]]
# The MAPE is of (12, 14) 5.261075990173895
# The concentration of NaCl is: 12
# The concentration of LaCl3 is: 12
# The concentration of CaCl2 is: 5.333333333333333
# Relaxation correction: [-0.13231497 -0.0575055  -0.01701158 -0.09512847]
# Hydrodynamic correction: [-0.32731847 -0.25968625 -0.15392357 -0.09479988]
# omega_bar: 265900723623.1765
# Alpha: [0.0, 183715853316.09732, 288175979625.9643, 375896036897.5147]
# Mew: [0.54       0.10666667 0.06       0.29333333]
# Transport number: [0.30530674 0.07716243 0.07310702 0.54442381]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.54542196 -0.74140317 -0.50402819 -0.28869068]
#  [ 1.20784873  3.256903   -0.84655218 -0.4203672 ]
#  [ 0.71710359  0.2501751   2.99499361 -2.03267447]
#  [ 0.47077569  0.12935528  0.6230949   1.10008842]]
# The MAPE is of (12, 12) 8.088841668827659
# The concentration of NaCl is: 12
# The concentration of LaCl3 is: 10
# The concentration of CaCl2 is: 9.333333333333334
# Relaxation correction: [-0.13951661 -0.06267558 -0.01924517 -0.09208326]
# Hydrodynamic correction: [-0.32756485 -0.25988161 -0.15403937 -0.09487144]
# omega_bar: 272693760529.6221
# Alpha: [0.0, 177622541627.06454, 289835877350.79755, 375370736190.4332]
# Mew: [0.45       0.18666667 0.06       0.30333333]
# Transport number: [0.24808441 0.13167043 0.07128586 0.5489593 ]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.59150718 -1.08797111 -0.48040662 -0.28899719]
#  [ 1.24386735  2.28594177 -0.80295487 -0.42100739]
#  [ 0.73848796  0.28579425  3.03267111 -2.05033919]
#  [ 0.48481444  0.15075895  0.6069482   1.09337516]]
# The MAPE is of (12, 10) 9.535543827892374
# The concentration of NaCl is: 12
# The concentration of LaCl3 is: 8
# The concentration of CaCl2 is: 13.333333333333334
# Relaxation correction: [-0.14661335 -0.06776769 -0.02143951 -0.08909255]
# Hydrodynamic correction: [-0.32781124 -0.26007696 -0.15415516 -0.094943  ]
# omega_bar: 279486797436.0678
# Alpha: [0.0, 171790644365.90356, 291304053670.0399, 374873766710.14404]
# Mew: [0.36       0.26666667 0.06       0.31333333]
# Transport number: [0.19364369 0.18352876 0.06955323 0.55327432]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.63941216 -1.47672262 -0.46048717 -0.28929808]
#  [ 1.28130824  1.74406941 -0.76644388 -0.42163045]
#  [ 0.76071674  0.29149226  3.07236814 -2.06745598]
#  [ 0.49940754  0.15652798  0.59303721  1.08711529]]
# The MAPE is of (12, 8) 10.00598836979663
# The concentration of NaCl is: 12
# The concentration of LaCl3 is: 7
# The concentration of CaCl2 is: 15.333333333333334
# Relaxation correction: [-0.1501235  -0.07028538 -0.02252245 -0.08761698]
# Hydrodynamic correction: [-0.32793443 -0.26017463 -0.15421306 -0.09497878]
# omega_bar: 282883315889.29065
# Alpha: [0.0, 168958687228.63498, 291978140153.8828, 374635165384.3619]
# Mew: [0.315      0.30666667 0.06       0.31833333]
# Transport number: [0.16740382 0.20852394 0.06871812 0.55535411]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.66410158 -1.70780655 -0.4516221  -0.28944663]
#  [ 1.30060465  1.53723832 -0.7502721  -0.42193607]
#  [ 0.77217307  0.28637482  3.09271971 -2.07581937]
#  [ 0.50692858  0.15504761  0.58674729  1.08414214]]
# The MAPE is of (12, 7) 9.9311398561737
# The concentration of NaCl is: 12
# The concentration of LaCl3 is: 6
# The concentration of CaCl2 is: 17.333333333333332
# Relaxation correction: [-0.15360876 -0.07278458 -0.02359614 -0.08615428]
# Hydrodynamic correction: [-0.32805762 -0.26027231 -0.15427096 -0.09501456]
# omega_bar: 286279834342.5134
# Alpha: [0.0, 166176611581.14526, 292617217671.3233, 374402791272.8767]
# Mew: [0.27       0.34666667 0.06       0.32333333]
# Transport number: [0.14178659 0.23292603 0.06790282 0.55738456]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.68931401 -1.97955277 -0.44337046 -0.289594  ]
#  [ 1.32030981  1.35317909 -0.73526318 -0.42223798]
#  [ 0.78387209  0.27652014  3.11331204 -2.08405793]
#  [ 0.51460894  0.1508844   0.58083259  1.08126709]]
# The MAPE is of (12, 6) 9.6650414923254
# The concentration of NaCl is: 12
# The concentration of LaCl3 is: 5
# The concentration of CaCl2 is: 19.333333333333332
# Relaxation correction: [-0.15706952 -0.07526563 -0.02466076 -0.0847042 ]
# Hydrodynamic correction: [-0.32818081 -0.26036998 -0.15432886 -0.09505034]
# omega_bar: 289676352795.7363
# Alpha: [0.0, 163440472647.0334, 293224402403.3711, 374176391884.9787]
# Mew: [0.225      0.38666667 0.06       0.32833333]
# Transport number: [0.11677009 0.25675587 0.06710665 0.55936739]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.71507508 -2.31270461 -0.43566267 -0.28974026]
#  [ 1.34044378  1.18286757 -0.72128229 -0.42253635]
#  [ 0.79582569  0.26189318  3.13409146 -2.09217531]
#  [ 0.52245643  0.14396799  0.57525208  1.07848568]]
# The MAPE is of (12, 5) 9.212434858828779
# The concentration of NaCl is: 12
# The concentration of LaCl3 is: 4
# The concentration of CaCl2 is: 21.333333333333332
# Relaxation correction: [-0.1605062  -0.07772882 -0.02571648 -0.08326653]
# Hydrodynamic correction: [-0.328304   -0.26046766 -0.15438676 -0.09508612]
# omega_bar: 293072871248.9591
# Alpha: [0.0, 160746731037.30777, 293802412814.7071, 373955728523.5272]
# Mew: [0.18       0.42666667 0.06       0.33333333]
# Transport number: [0.09233345 0.28003337 0.06632893 0.56130426]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.74141203 -2.74412127 -0.4284399  -0.28988545]
#  [ 1.36102783  1.01894576 -0.70821568 -0.42283131]
#  [ 0.80804651  0.24205127  3.15501437 -2.10017496]
#  [ 0.53047935  0.13400568  0.56997103  1.07579372]]
# The MAPE is of (12, 4) 8.57230838836742
# The concentration of NaCl is: 15
# The concentration of LaCl3 is: 16
# The concentration of CaCl2 is: -3.6666666666666665
# The concentration of NaCl is: 15
# The concentration of LaCl3 is: 14
# The concentration of CaCl2 is: 0.3333333333333333
# The concentration of NaCl is: 15
# The concentration of LaCl3 is: 12
# The concentration of CaCl2 is: 4.333333333333333
# Relaxation correction: [-0.13397    -0.05887983 -0.01769083 -0.09383085]
# Hydrodynamic correction: [-0.32720373 -0.25959531 -0.15386966 -0.0947665 ]
# omega_bar: 269381031770.097
# Alpha: [0.0, 184929445716.02753, 281204906445.8864, 378367104574.05054]
# Mew: [0.54       0.08666667 0.075      0.29833333]
# Transport number: [0.30136229 0.06188448 0.09020313 0.5465501 ]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.56306452 -0.69531092 -0.56151987 -0.27628372]
#  [ 1.22163755  3.6845213  -0.96430613 -0.40144445]
#  [ 0.72529006  0.24557817  2.63958879 -1.87944326]
#  [ 0.47615007  0.12645036  0.63293217  1.08919544]]
# The MAPE is of (15, 12) 8.04020646087508
# The concentration of NaCl is: 15
# The concentration of LaCl3 is: 10
# The concentration of CaCl2 is: 8.333333333333334
# Relaxation correction: [-0.14113744 -0.0640233  -0.01991001 -0.09080803]
# Hydrodynamic correction: [-0.32745011 -0.25979066 -0.15398546 -0.09483806]
# omega_bar: 276174068676.54266
# Alpha: [0.0, 178517702477.6091, 283281042738.92377, 377815441323.5223]
# Mew: [0.45       0.16666667 0.075      0.30833333]
# Transport number: [0.24495808 0.11608137 0.08798441 0.55097614]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.60968439 -1.06421983 -0.53112827 -0.2767421 ]
#  [ 1.25807404  2.45958415 -0.90581275 -0.40229994]
#  [ 0.74692252  0.29077683  2.6693618  -1.896764  ]
#  [ 0.49035169  0.15295125  0.61548446  1.08272833]]
# The MAPE is of (15, 10) 9.63293003516317
# The concentration of NaCl is: 15
# The concentration of LaCl3 is: 8
# The concentration of CaCl2 is: 12.333333333333334
# Relaxation correction: [-0.14820128 -0.06908983 -0.02209055 -0.08783882]
# Hydrodynamic correction: [-0.32769649 -0.25998601 -0.15410125 -0.09490962]
# omega_bar: 282967105582.9883
# Alpha: [0.0, 172433824702.81726, 285093857012.71814, 377292199478.55066]
# Mew: [0.36       0.24666667 0.075      0.31833333]
# Transport number: [0.19126201 0.16767611 0.08587221 0.55518967]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.65817778 -1.46485629 -0.50620072 -0.27718821]
#  [ 1.2959748   1.83988194 -0.85828257 -0.40312955]
#  [ 0.76942432  0.29929096  2.70218503 -1.91358771]
#  [ 0.50512404  0.16041015  0.60087356  1.07668729]]
# The MAPE is of (15, 8) 10.204591229962135
# The concentration of NaCl is: 15
# The concentration of LaCl3 is: 7
# The concentration of CaCl2 is: 14.333333333333334
# Relaxation correction: [-0.15169546 -0.07159509 -0.0231668  -0.0863737 ]
# Hydrodynamic correction: [-0.32781969 -0.26008369 -0.15415915 -0.0949454 ]
# omega_bar: 286363624036.2111
# Alpha: [0.0, 169494440259.80475, 285919837855.78265, 377040521769.83325]
# Mew: [0.315      0.28666667 0.075      0.32333333]
# Transport number: [0.16536929 0.19255555 0.08485369 0.55722147]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.6831835  -1.70049904 -0.49529151 -0.277407  ]
#  [ 1.31551841  1.61191822 -0.83761375 -0.40353533]
#  [ 0.78102742  0.29454385  2.71934374 -1.9218222 ]
#  [ 0.51274143  0.15922635  0.59437728  1.07381443]]
# The MAPE is of (15, 7) 10.172328885896393
# The concentration of NaCl is: 15
# The concentration of LaCl3 is: 6
# The concentration of CaCl2 is: 16.333333333333332
# Relaxation correction: [-0.15516503 -0.0740821  -0.02423394 -0.08492124]
# Hydrodynamic correction: [-0.32794288 -0.26018136 -0.15421705 -0.09498118]
# omega_bar: 289760142489.43396
# Alpha: [0.0, 166614916518.8761, 286699623327.4803, 376795122703.55536]
# Mew: [0.27       0.32666667 0.075      0.32833333]
# Transport number: [0.14008359 0.21685172 0.08385905 0.55920564]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.70872811 -1.97644082 -0.48523195 -0.27762312]
#  [ 1.3354832   1.4123084  -0.81862804 -0.40393542]
#  [ 0.79288058  0.28465417  2.73686019 -1.92994292]
#  [ 0.52052298  0.15513467  0.58832468  1.07103411]]
# The MAPE is of (15, 6) 9.945618249988211
# The concentration of NaCl is: 15
# The concentration of LaCl3 is: 5
# The concentration of CaCl2 is: 18.333333333333332
# Relaxation correction: [-0.1586104  -0.07655119 -0.02529215 -0.08348123]
# Hydrodynamic correction: [-0.32806607 -0.26027904 -0.15427495 -0.09501696]
# omega_bar: 293156660942.65686
# Alpha: [0.0, 163789925095.98965, 287437736702.3439, 376555757227.3332]
# Mew: [0.225      0.36666667 0.075      0.33333333]
# Transport number: [0.11538382 0.24058489 0.08288746 0.56114383]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.7348382  -2.31373629 -0.47591395 -0.27783668]
#  [ 1.35588996  1.22997806 -0.80110584 -0.40433004]
#  [ 0.80499614  0.26969045  2.75465741 -1.93795302]
#  [ 0.5284768   0.14811578  0.58266043  1.06834223]]
# The MAPE is of (15, 5) 9.53022224651911
# The concentration of NaCl is: 15
# The concentration of LaCl3 is: 4
# The concentration of CaCl2 is: 20.333333333333332
# Relaxation correction: [-0.16203197 -0.07900264 -0.02634159 -0.08205342]
# Hydrodynamic correction: [-0.32818926 -0.26037671 -0.15433285 -0.09505275]
# omega_bar: 296553179395.8796
# Alpha: [0.0, 161014783994.82465, 288138060956.8192, 376322193221.0407]
# Mew: [0.18       0.40666667 0.075      0.33833333]
# Transport number: [0.09124983 0.26377442 0.08193812 0.56303762]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.76154209 -2.74959312 -0.46724809 -0.27804777]
#  [ 1.3767608   1.05633105 -0.78486608 -0.4047194 ]
#  [ 0.81738722  0.24926452  2.7726743  -1.94585553]
#  [ 0.53661149  0.13790333  0.57733879  1.06573493]]
# The MAPE is of (15, 4) 8.92592869743133
# The concentration of NaCl is: 20
# The concentration of LaCl3 is: 16
# The concentration of CaCl2 is: -5.333333333333333
# The concentration of NaCl is: 20
# The concentration of LaCl3 is: 14
# The concentration of CaCl2 is: -1.3333333333333333
# The concentration of NaCl is: 20
# The concentration of LaCl3 is: 12
# The concentration of CaCl2 is: 2.6666666666666665
# Relaxation correction: [-0.1367018  -0.06114894 -0.01881056 -0.09168919]
# Hydrodynamic correction: [-0.32701249 -0.25944374 -0.15377981 -0.09471087]
# omega_bar: 275181545348.29785
# Alpha: [0.0, 187272882411.60233, 270061259665.1941, 381788490641.30786]
# Mew: [0.54       0.05333333 0.1        0.30666667]
# Transport number: [0.29500991 0.03728002 0.11773566 0.54997441]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.59279257 -0.58860113 -0.6622077  -0.26030383]
#  [ 1.24487197  4.87068966 -1.18678511 -0.37714527]
#  [ 0.73908441  0.22631277  2.24227872 -1.69361332]
#  [ 0.48520601  0.11557571  0.64128095  1.07621678]]
# The MAPE is of (20, 12) 7.703969993834189
# The concentration of NaCl is: 20
# The concentration of LaCl3 is: 10
# The concentration of CaCl2 is: 6.666666666666667
# Relaxation correction: [-0.14381337 -0.06624896 -0.02100628 -0.08870283]
# Hydrodynamic correction: [-0.32725887 -0.25963909 -0.1538956  -0.09478243]
# omega_bar: 281974582254.74347
# Alpha: [0.0, 180201521217.44305, 272937856847.4078, 381208871367.2971]
# Mew: [0.45       0.13333333 0.1        0.31666667]
# Transport number: [0.23991904 0.09095477 0.1148993  0.5542269 ]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.64034051 -1.01481301 -0.61597659 -0.26092751]
#  [ 1.2820338   2.83161013 -1.09077585 -0.37822935]
#  [ 0.76114751  0.29780955  2.26069613 -1.71011412]
#  [ 0.49969034  0.15580069  0.62070516  1.07008223]]
# The MAPE is of (20, 10) 9.590446860314541
# The concentration of NaCl is: 20
# The concentration of LaCl3 is: 8
# The concentration of CaCl2 is: 10.666666666666666
# Relaxation correction: [-0.15082345 -0.07127369 -0.02316433 -0.0857687 ]
# Hydrodynamic correction: [-0.32750526 -0.25983444 -0.1540114  -0.09485399]
# omega_bar: 288767619161.1891
# Alpha: [0.0, 173621035414.9269, 275380515252.3503, 380657255734.6425]
# Mew: [0.36       0.21333333 0.1        0.32666667]
# Transport number: [0.1874201  0.1421042  0.11219638 0.55827932]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.68985552 -1.44046825 -0.58021323 -0.26153232]
#  [ 1.32073304  2.02814261 -1.01761418 -0.3792793 ]
#  [ 0.78412337  0.31296945  2.28482547 -1.72618562]
#  [ 0.5147739   0.16714653  0.60454666  1.06433607]]
# The MAPE is of (20, 8) 10.351459304465802
# The concentration of NaCl is: 20
# The concentration of LaCl3 is: 7
# The concentration of CaCl2 is: 12.666666666666666
# Relaxation correction: [-0.15429149 -0.07375864 -0.02422969 -0.08432061]
# Hydrodynamic correction: [-0.32762845 -0.25993211 -0.1540693  -0.09488977]
# omega_bar: 292164137614.4119
# Alpha: [0.0, 170475898184.59647, 276476109528.8478, 380391282903.5411]
# Mew: [0.315      0.25333333 0.1        0.33166667]
# Transport number: [0.16208611 0.16678697 0.11089205 0.56023486]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.71541058 -1.68495143 -0.56507636 -0.26182811]
#  [ 1.340706    1.75495119 -0.98695682 -0.37979229]
#  [ 0.79598137  0.30909596  2.29818651 -1.73406768]
#  [ 0.52255864  0.16662052  0.59761647  1.061598  ]]
# The MAPE is of (20, 7) 10.396769942268133
# The concentration of NaCl is: 20
# The concentration of LaCl3 is: 6
# The concentration of CaCl2 is: 14.666666666666666
# Relaxation correction: [-0.15773541 -0.07622573 -0.02528615 -0.08288488]
# Hydrodynamic correction: [-0.32775164 -0.26002979 -0.1541272  -0.09492555]
# omega_bar: 295560656067.63477
# Alpha: [0.0, 167412556429.81287, 277501781274.14825, 380131538845.7282]
# Mew: [0.27       0.29333333 0.1        0.33666667]
# Transport number: [0.13733439 0.19090244 0.10961771 0.56214546]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.74153229 -1.96871818 -0.55136622 -0.26211972]
#  [ 1.36112183  1.52336482 -0.95935309 -0.38029767]
#  [ 0.80810231  0.29921585  2.31214394 -1.74185091]
#  [ 0.53051599  0.16270884  0.59128136  1.05894475]]
# The MAPE is of (20, 6) 10.240937978026075
# The concentration of NaCl is: 20
# The concentration of LaCl3 is: 5
# The concentration of CaCl2 is: 16.666666666666668
# Relaxation correction: [-0.1611556  -0.07867525 -0.0263339  -0.08146127]
# Hydrodynamic correction: [-0.32787483 -0.26012746 -0.1541851  -0.09496133]
# omega_bar: 298957174520.8576
# Alpha: [0.0, 164422168255.38513, 278465598626.81323, 379877793293.16754]
# Mew: [0.225      0.33333333 0.1        0.34166667]
# Transport number: [0.11314509 0.21446995 0.10837232 0.56401265]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.76824895 -2.31349805 -0.53886419 -0.2624073 ]
#  [ 1.38200266  1.31710518 -0.93432064 -0.38079572]
#  [ 0.82049933  0.28365627  2.32656096 -1.7495379 ]
#  [ 0.53865458  0.1555211   0.58544944  1.0563727 ]]
# The MAPE is of (20, 5) 9.891825509756357
# The concentration of NaCl is: 20
# The concentration of LaCl3 is: 4
# The concentration of CaCl2 is: 18.666666666666668
# Relaxation correction: [-0.16455244 -0.0811075  -0.02737309 -0.08004958]
# Hydrodynamic correction: [-0.32799802 -0.26022514 -0.154243   -0.09499712]
# omega_bar: 302353692974.08044
# Alpha: [0.0, 161497253491.03183, 279374271616.1836, 379629827536.59705]
# Mew: [0.18       0.37333333 0.1        0.34666667]
# Transport number: [0.08949925 0.23750797 0.10715491 0.56583788]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.79559076 -2.75716851 -0.52739681 -0.26269099]
#  [ 1.40337207  1.12461512 -0.91147859 -0.38128669]
#  [ 0.83318642  0.26216473  2.34133385 -1.75713111]
#  [ 0.5469836   0.1448583   0.58004822  1.05387843]]
# The MAPE is of (20, 4) 9.350795146435157
# The concentration of NaCl is: 25
# The concentration of LaCl3 is: 16
# The concentration of CaCl2 is: -7.0
# The concentration of NaCl is: 25
# The concentration of LaCl3 is: 14
# The concentration of CaCl2 is: -3.0
# The concentration of NaCl is: 25
# The concentration of LaCl3 is: 12
# The concentration of CaCl2 is: 1.0
# Relaxation correction: [-0.13940122 -0.06339192 -0.01991528 -0.08957317]
# Hydrodynamic correction: [-0.32682125 -0.25929216 -0.15368996 -0.09465524]
# omega_bar: 280982058926.49866
# Alpha: [0.0, 190186527106.19025, 259077293338.89725, 384597001280.7193]
# Mew: [0.54  0.02  0.125 0.315]
# Transport number: [0.28891981 0.01369141 0.14413145 0.55325733]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.62294665 -0.39666892 -0.77996102 -0.24804572]
#  [ 1.26843937  8.31417166 -1.47497426 -0.3585696 ]
#  [ 0.75307645  0.16862014  1.97729123 -1.55976712]
#  [ 0.49439172  0.0852072   0.64608582  1.06694276]]
# The MAPE is of (25, 12) 7.029501017651915
# The concentration of NaCl is: 25
# The concentration of LaCl3 is: 10
# The concentration of CaCl2 is: 5.0
# Relaxation correction: [-0.14645825 -0.06844955 -0.0220882  -0.08662227]
# Hydrodynamic correction: [-0.32706764 -0.25948751 -0.15380575 -0.0947268 ]
# omega_bar: 287775095832.9443
# Alpha: [0.0, 182198857995.3898, 262991433260.22766, 384001726282.6323]
# Mew: [0.45  0.1   0.125 0.325]
# Transport number: [0.23508313 0.06684108 0.14072918 0.55734661]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.67147086 -0.94744219 -0.70743547 -0.24877285]
#  [ 1.30636422  3.37755001 -1.31033464 -0.35979187]
#  [ 0.77559255  0.30143534  1.98280601 -1.57541116]
#  [ 0.50917345  0.1566602   0.62008823  1.06108727]]
# The MAPE is of (25, 10) 9.314291388006186
# The concentration of NaCl is: 25
# The concentration of LaCl3 is: 8
# The concentration of CaCl2 is: 9.0
# Relaxation correction: [-0.15341582 -0.0734335  -0.02422438 -0.08372227]
# Hydrodynamic correction: [-0.32731402 -0.25968286 -0.15392155 -0.09479836]
# omega_bar: 294568132739.3899
# Alpha: [0.0, 174986256859.8049, 266180654284.71832, 383433680819.73254]
# Mew: [0.36  0.18  0.125 0.335]
# Transport number: [0.1837295  0.11753939 0.13748382 0.56124729]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.72206107 -1.40882061 -0.65595363 -0.24947754]
#  [ 1.34590379  2.26605694 -1.19624893 -0.3609759 ]
#  [ 0.79906732  0.32748831  1.99939255 -1.59067767]
#  [ 0.52458455  0.17417651  0.60162401  1.05558891]]
# The MAPE is of (25, 8) 10.296059240698238
# The concentration of NaCl is: 25
# The concentration of LaCl3 is: 7
# The concentration of CaCl2 is: 11.0
# Relaxation correction: [-0.15685833 -0.07589863 -0.02527913 -0.08229078]
# Hydrodynamic correction: [-0.32743721 -0.25978054 -0.15397945 -0.09483414]
# omega_bar: 297964651192.6128
# Alpha: [0.0, 171591196388.40176, 267580927290.05347, 383159251460.6761]
# Mew: [0.315 0.22  0.125 0.34 ]
# Transport number: [0.15893076 0.14202167 0.13591663 0.56313093]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.74819456 -1.66435744 -0.63511193 -0.24982198]
#  [ 1.36632883  1.92855413 -1.15077439 -0.36155442]
#  [ 0.81119373  0.3249792   2.0098855  -1.59817546]
#  [ 0.53254549  0.1746126   0.59410276  1.0529642 ]]
# The MAPE is of (25, 7) 10.428002845474294
# The concentration of NaCl is: 25
# The concentration of LaCl3 is: 6
# The concentration of CaCl2 is: 13.0
# Relaxation correction: [-0.16027718 -0.07834626 -0.02632521 -0.08087134]
# Hydrodynamic correction: [-0.3275604  -0.25987821 -0.15403735 -0.09486992]
# omega_bar: 301361169645.8356
# Alpha: [0.0, 168309826400.00223, 268877773819.70633, 382890912642.81995]
# Mew: [0.27  0.26  0.125 0.345]
# Transport number: [0.13469102 0.1659521  0.13438477 0.56497212]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.77492417 -1.95734615 -0.61665201 -0.2501614 ]
#  [ 1.38721977  1.65418381 -1.11085483 -0.36212437]
#  [ 0.82359675  0.31523678  2.02131819 -1.60558597]
#  [ 0.54068802  0.17098862  0.58740152  1.05041785]]
# The MAPE is of (25, 6) 10.34991935990109
# The concentration of NaCl is: 25
# The concentration of LaCl3 is: 5
# The concentration of CaCl2 is: 15.0
# Relaxation correction: [-0.16367275 -0.08077667 -0.02736277 -0.07946372]
# Hydrodynamic correction: [-0.3276836  -0.25997589 -0.15409525 -0.0949057 ]
# omega_bar: 304757688099.0585
# Alpha: [0.0, 165127186239.83066, 270085405210.12726, 382628449516.0208]
# Mew: [0.225 0.3   0.125 0.35 ]
# Transport number: [0.11099157 0.18934911 0.13288706 0.56677226]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.80228008 -2.31053477 -0.60013366 -0.25049598]
#  [ 1.40860022  1.41739619 -1.07542658 -0.36268601]
#  [ 0.83629038  0.29902935  2.03344637 -1.61291138]
#  [ 0.54902134  0.16363656  0.58136357  1.04794663]]
# The MAPE is of (25, 5) 10.072481647310783
# The concentration of NaCl is: 25
# The concentration of LaCl3 is: 4
# The concentration of CaCl2 is: 17.0
# Relaxation correction: [-0.16704542 -0.08319015 -0.02839197 -0.07806774]
# Hydrodynamic correction: [-0.32780679 -0.26007357 -0.15415315 -0.09494149]
# omega_bar: 308154206552.28125
# Alpha: [0.0, 162031173925.80405, 271215175356.10602, 382371657551.18774]
# Mew: [0.18  0.34  0.125 0.355]
# Transport number: [0.08781457 0.21223036 0.13142236 0.56853272]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.83029452 -2.76265306 -0.58522541 -0.25082588]
#  [ 1.43049534  1.20179189 -1.04369419 -0.36323964]
#  [ 0.84928959  0.27632838  2.04609558 -1.62015375]
#  [ 0.55755527  0.15247116  0.57587226  1.04554748]]
# The MAPE is of (25, 4) 9.59904264472065
# The concentration of NaCl is: 30
# The concentration of LaCl3 is: 16
# The concentration of CaCl2 is: -8.666666666666666
# The concentration of NaCl is: 30
# The concentration of LaCl3 is: 14
# The concentration of CaCl2 is: -4.666666666666667
# The concentration of NaCl is: 30
# The concentration of LaCl3 is: 12
# The concentration of CaCl2 is: -0.6666666666666666
# The concentration of NaCl is: 30
# The concentration of LaCl3 is: 10
# The concentration of CaCl2 is: 3.3333333333333335
# Relaxation correction: [-0.14907292 -0.07062577 -0.02315619 -0.08456568]
# Hydrodynamic correction: [-0.3268764  -0.25933594 -0.1537159  -0.09467117]
# omega_bar: 293575609411.1451
# Alpha: [0.0, 184647303719.82373, 253125385667.28357, 386366567379.98444]
# Mew: [0.45       0.06666667 0.15       0.33333333]
# Transport number: [0.23043832 0.04368028 0.16553835 0.56034304]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.70310344 -0.84864294 -0.81343945 -0.2389898 ]
#  [ 1.33108716  4.29662606 -1.59430636 -0.34499623]
#  [ 0.79027064  0.296602    1.77775291 -1.47240972]
#  [ 0.51880956  0.15287186  0.61701572  1.05421985]]
# The MAPE is of (30, 10) 8.81239523413311
# The concentration of NaCl is: 30
# The concentration of LaCl3 is: 8
# The concentration of CaCl2 is: 7.333333333333333
# Relaxation correction: [-0.15597919 -0.0755699  -0.0252711  -0.08169891]
# Hydrodynamic correction: [-0.32712278 -0.25953129 -0.1538317  -0.09474273]
# omega_bar: 300368646317.59076
# Alpha: [0.0, 176585735662.31903, 257264175116.6675, 385789492302.07306]
# Mew: [0.36       0.14666667 0.15       0.34333333]
# Transport number: [0.18018144 0.09392334 0.16179459 0.56410063]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.7548254  -1.3672365  -0.7373793  -0.23976043]
#  [ 1.37151126  2.58089082 -1.40891477 -0.34626543]
#  [ 0.81427055  0.34270012  1.78585655 -1.48691385]
#  [ 0.53456541  0.18136738  0.59481232  1.04894106]]
# The MAPE is of (30, 8) 10.058662252307446
# The concentration of NaCl is: 30
# The concentration of LaCl3 is: 7
# The concentration of CaCl2 is: 9.333333333333334
# Relaxation correction: [-0.15939674 -0.07801567 -0.02631553 -0.08028359]
# Hydrodynamic correction: [-0.32724598 -0.25962897 -0.1538896  -0.09477851]
# omega_bar: 303765164770.8136
# Alpha: [0.0, 172877058033.3982, 259026099201.7794, 385510244161.6651]
# Mew: [0.315      0.18666667 0.15       0.34833333]
# Transport number: [0.15589592 0.11820218 0.1599855  0.5659164 ]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.78156809 -1.63734812 -0.70850305 -0.24013714]
#  [ 1.39241244  2.14586605 -1.34022291 -0.34688581]
#  [ 0.82667965  0.34240859  1.79380977 -1.49404485]
#  [ 0.54271193  0.18327763  0.58645532  1.04641707]]
# The MAPE is of (30, 7) 10.288151298641596
# The concentration of NaCl is: 30
# The concentration of LaCl3 is: 6
# The concentration of CaCl2 is: 11.333333333333334
# Relaxation correction: [-0.16279109 -0.08044428 -0.02735149 -0.07888002]
# Hydrodynamic correction: [-0.32736917 -0.25972664 -0.1539475  -0.09481429]
# omega_bar: 307161683224.0364
# Alpha: [0.0, 169330729633.2171, 260634456156.88965, 385236905837.80756]
# Mew: [0.27       0.22666667 0.15       0.35333333]
# Transport number: [0.13214748 0.14194409 0.15821642 0.56769201]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.80893825 -1.9415962  -0.68367039 -0.24050837]
#  [ 1.41380401  1.81164585 -1.28194023 -0.34749712]
#  [ 0.83937989  0.33301767  1.8032478  -1.50109775]
#  [ 0.5510496   0.18010924  0.5792744   1.04396586]]
# The MAPE is of (30, 6) 10.295637131456832
# The concentration of NaCl is: 30
# The concentration of LaCl3 is: 5
# The concentration of CaCl2 is: 13.333333333333334
# Relaxation correction: [-0.16616258 -0.08285602 -0.02837912 -0.07748799]
# Hydrodynamic correction: [-0.32749236 -0.25982432 -0.1540054  -0.09485007]
# omega_bar: 310558201677.2593
# Alpha: [0.0, 165920514447.6036, 262114751776.71927, 384969277418.746]
# Mew: [0.225      0.26666667 0.15       0.35833333]
# Transport number: [0.10891851 0.16516667 0.15648604 0.56942879]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.83696811 -2.30445131 -0.66197299 -0.24087429]
#  [ 1.43571119  1.53464363 -1.23163272 -0.34809966]
#  [ 0.85238625  0.31609665  1.81371957 -1.5080744 ]
#  [ 0.55958822  0.17260115  0.5729899   1.04158451]]
# The MAPE is of (30, 5) 10.095738885273056
# The concentration of NaCl is: 30
# The concentration of LaCl3 is: 4
# The concentration of CaCl2 is: 15.333333333333334
# Relaxation correction: [-0.16951159 -0.08525116 -0.02939859 -0.07610732]
# Hydrodynamic correction: [-0.32761555 -0.25992199 -0.1540633  -0.09488586]
# omega_bar: 313954720130.48206
# Alpha: [0.0, 162626351247.26407, 263486315961.37546, 384707168230.3951]
# Mew: [0.18       0.30666667 0.15       0.36333333]
# Transport number: [0.08619214 0.18788679 0.15479309 0.57112798]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.86569212 -2.7658325  -0.64277184 -0.24123508]
#  [ 1.45816088  1.29001128 -1.18760449 -0.34869369]
#  [ 0.86571471  0.29199557  1.82492715 -1.51497659]
#  [ 0.5683383   0.16086345  0.5674089   1.03927028]]
# The MAPE is of (30, 4) 9.694420722242628
# The concentration of NaCl is: 50
# The concentration of LaCl3 is: 16
# The concentration of CaCl2 is: -15.333333333333334
# The concentration of NaCl is: 50
# The concentration of LaCl3 is: 14
# The concentration of CaCl2 is: -11.333333333333334
# The concentration of NaCl is: 50
# The concentration of LaCl3 is: 12
# The concentration of CaCl2 is: -7.333333333333333
# The concentration of NaCl is: 50
# The concentration of LaCl3 is: 10
# The concentration of CaCl2 is: -3.3333333333333335
# The concentration of NaCl is: 50
# The concentration of LaCl3 is: 8
# The concentration of CaCl2 is: 0.6666666666666666
# The concentration of NaCl is: 50
# The concentration of LaCl3 is: 7
# The concentration of CaCl2 is: 2.6666666666666665
# Relaxation correction: [-0.16928019 -0.08626571 -0.03033777 -0.07246973]
# Hydrodynamic correction: [-0.32648103 -0.25902267 -0.15353019 -0.09455599]
# omega_bar: 326967219083.6168
# Alpha: [0.0, 181580141718.36398, 224640486702.69534, 392357864182.30444]
# Mew: [0.315      0.05333333 0.25       0.38166667]
# Transport number: [0.14483332 0.03137554 0.24772118 0.57606996]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.92167745 -1.38112658 -1.12174292 -0.21407094]
#  [ 1.5019171   4.54972875 -2.97010827 -0.30762306]
#  [ 0.89169291  0.42873629  1.2358043  -1.23719573]
#  [ 0.58539288  0.22328017  0.53136345  1.03005548]]
# The MAPE is of (50, 7) 8.17691678271534
# The concentration of NaCl is: 50
# The concentration of LaCl3 is: 6
# The concentration of CaCl2 is: 4.666666666666667
# Relaxation correction: [-0.17258165 -0.08862238 -0.03133574 -0.07112585]
# Hydrodynamic correction: [-0.32660422 -0.25912035 -0.15358809 -0.09459177]
# omega_bar: 330363737536.8397
# Alpha: [0.0, 175670689426.9423, 228753332430.34155, 392082251738.6148]
# Mew: [0.27       0.09333333 0.25       0.38666667]
# Transport number: [0.12286652 0.05434269 0.24517432 0.57761648]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.9519798  -1.80356657 -1.01480447 -0.21449518]
#  [ 1.52560037  3.10462259 -2.51804622 -0.30829528]
#  [ 0.90575375  0.4331948   1.23507056 -1.24309444]
#  [ 0.59462377  0.2299125   0.51788073  1.02791776]]
# The MAPE is of (50, 6) 8.667012628977142
# The concentration of NaCl is: 50
# The concentration of LaCl3 is: 5
# The concentration of CaCl2 is: 6.666666666666667
# Relaxation correction: [-0.17586185 -0.09096343 -0.03232609 -0.06979249]
# Hydrodynamic correction: [-0.32672741 -0.25921802 -0.15364599 -0.09462755]
# omega_bar: 333760255990.0625
# Alpha: [0.0, 170560817232.85324, 232069516875.3414, 391811579278.4345]
# Mew: [0.225      0.13333333 0.25       0.39166667]
# Transport number: [0.1013468  0.07684238 0.2426793  0.57913152]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.98309996 -2.23587509 -0.94292029 -0.21491377]
#  [ 1.54992282  2.34776672 -2.23694599 -0.30895869]
#  [ 0.92019406  0.41215584  1.24265239 -1.24893962]
#  [ 0.60410378  0.22212095  0.51000877  1.02583403]]
# The MAPE is of (50, 5) 8.867832351955123
# The concentration of NaCl is: 50
# The concentration of LaCl3 is: 4
# The concentration of CaCl2 is: 8.666666666666666
# Relaxation correction: [-0.1791211  -0.09328908 -0.03330897 -0.06846948]
# Hydrodynamic correction: [-0.32685061 -0.2593157  -0.15370389 -0.09466333]
# omega_bar: 337156774443.28534
# Alpha: [0.0, 165955236962.0318, 234883622076.90878, 391545703072.44666]
# Mew: [0.18       0.17333333 0.25       0.39666667]
# Transport number: [0.08026067 0.09888875 0.24023454 0.58061604]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 2.01508365 -2.74986384 -0.88922661 -0.21532688]
#  [ 1.57492017  1.8377829  -2.03928754 -0.30961354]
#  [ 0.93503507  0.37813108  1.25338409 -1.25473238]
#  [ 0.61384684  0.20645467  0.50468388  1.02380238]]
# The MAPE is of (50, 4) 8.818102992260574
# The concentration of NaCl is: 75
# The concentration of LaCl3 is: 16
# The concentration of CaCl2 is: -23.666666666666668
# The concentration of NaCl is: 75
# The concentration of LaCl3 is: 14
# The concentration of CaCl2 is: -19.666666666666668
# The concentration of NaCl is: 75
# The concentration of LaCl3 is: 12
# The concentration of CaCl2 is: -15.666666666666666
# The concentration of NaCl is: 75
# The concentration of LaCl3 is: 10
# The concentration of CaCl2 is: -11.666666666666666
# The concentration of NaCl is: 75
# The concentration of LaCl3 is: 8
# The concentration of CaCl2 is: -7.666666666666667
# The concentration of NaCl is: 75
# The concentration of LaCl3 is: 7
# The concentration of CaCl2 is: -5.666666666666667
# The concentration of NaCl is: 75
# The concentration of LaCl3 is: 6
# The concentration of CaCl2 is: -3.6666666666666665
# The concentration of NaCl is: 75
# The concentration of LaCl3 is: 5
# The concentration of CaCl2 is: -1.6666666666666667
# The concentration of NaCl is: 75
# The concentration of LaCl3 is: 4
# The concentration of CaCl2 is: 0.3333333333333333

# %% [markdown]
# ### 150 mM Ionic Strength

# %%
# desired ionic strength in mM
ionic_strength_150 = 150

# cation concentration in mM
# na_150 = [8, 10, 12, 15, 20, 25]
# la_150 = [14, 12, 10, 8, 6, 5]
na_150 = [8, 12, 15, 20, 25, 30, 50, 75, 100]
la_150 = [24, 20, 18, 16, 14, 12, 10, 9, 8]

three_salts_conc(la_150, na_150, ionic_strength_150, "ionic_str_150")
# Out:
# The concentration of NaCl is: 8
# The concentration of LaCl3 is: 24
# The concentration of CaCl2 is: -0.6666666666666666
# The concentration of NaCl is: 8
# The concentration of LaCl3 is: 20
# The concentration of CaCl2 is: 7.333333333333333
# Relaxation correction: [-0.13825022 -0.05705681 -0.01567653 -0.11198297]
# Hydrodynamic correction: [-0.38330317 -0.30492643 -0.18068274 -0.11012006]
# omega_bar: 253638014247.945
# Alpha: [0.0, 185177783333.67725, 304812137764.90094, 368754461556.5953]
# Mew: [0.6        0.09777778 0.02666667 0.27555556]
# Transport number: [0.35563055 0.07415194 0.03406291 0.5361546 ]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.47761339 -0.61553375 -0.37304143 -0.33245131]
#  [ 1.15485188  3.39918756 -0.60021643 -0.48724275]
#  [ 0.68563919  0.21940933  4.68810217 -2.6193325 ]
#  [ 0.45011943  0.11287862  0.57156034  1.1502623 ]]
# The MAPE is of (8, 20) 7.151885971267952
# The concentration of NaCl is: 8
# The concentration of LaCl3 is: 18
# The concentration of CaCl2 is: 11.333333333333334
# Relaxation correction: [-0.14372893 -0.06102348 -0.01740254 -0.10965096]
# Hydrodynamic correction: [-0.38353278 -0.30510888 -0.18079087 -0.11018635]
# omega_bar: 258166705518.90875
# Alpha: [0.0, 181395272601.89877, 305399933438.0633, 368464122798.9741]
# Mew: [0.54       0.15111111 0.02666667 0.28222222]
# Transport number: [0.31445296 0.11258819 0.03346539 0.53949346]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.50670812 -0.81694078 -0.36363427 -0.33216628]
#  [ 1.17759132  2.62995237 -0.58431675 -0.48695898]
#  [ 0.69913967  0.25172335  4.73402391 -2.63030005]
#  [ 0.45898244  0.13117456  0.56132582  1.14482848]]
# The MAPE is of (8, 18) 8.769239956515628
# The concentration of NaCl is: 8
# The concentration of LaCl3 is: 16
# The concentration of CaCl2 is: 15.333333333333334
# Relaxation correction: [-0.1491487  -0.06494609 -0.01910613 -0.10735   ]
# Hydrodynamic correction: [-0.38376239 -0.30529134 -0.180899   -0.11025265]
# omega_bar: 262695396789.87253
# Alpha: [0.0, 177694607282.36597, 305946836476.489, 368186398818.3184]
# Mew: [0.48       0.20444444 0.02666667 0.28888889]
# Transport number: [0.27469511 0.14969922 0.03288847 0.5427172 ]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.53649546 -1.02146764 -0.35500815 -0.33189525]
#  [ 1.20087208  2.16251326 -0.56976908 -0.48669015]
#  [ 0.71296154  0.26918641  4.7802121  -2.64094565]
#  [ 0.46805644  0.14196579  0.55183054  1.13966319]]
# The MAPE is of (8, 16) 9.795669494972662
# The concentration of NaCl is: 8
# The concentration of LaCl3 is: 14
# The concentration of CaCl2 is: 19.333333333333332
# Relaxation correction: [-0.15451096 -0.06882576 -0.02078793 -0.10507925]
# Hydrodynamic correction: [-0.38399201 -0.3054738  -0.18100712 -0.11031895]
# omega_bar: 267224088060.83624
# Alpha: [0.0, 174068858834.9997, 306457439300.934, 367920464514.2693]
# Mew: [0.42       0.25777778 0.02666667 0.29555556]
# Transport number: [0.23628483 0.18555239 0.0323311  0.54583168]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.56701821 -1.24346353 -0.34705788 -0.33163754]
#  [ 1.22472761  1.8284331  -0.55638876 -0.48643562]
#  [ 0.72712464  0.27631788  4.82655065 -2.65128638]
#  [ 0.47735446  0.14737258  0.54298066  1.13474785]]
# The MAPE is of (8, 14) 10.33466127378539
# The concentration of NaCl is: 8
# The concentration of LaCl3 is: 12
# The concentration of CaCl2 is: 23.333333333333332
# Relaxation correction: [-0.15981711 -0.07266355 -0.02244853 -0.1028379 ]
# Hydrodynamic correction: [-0.38422162 -0.30565625 -0.18111525 -0.11038525]
# omega_bar: 271752779331.80005
# Alpha: [0.0, 170511871858.55453, 306935621185.56946, 367665566079.9155]
# Mew: [0.36       0.31111111 0.02666667 0.30222222]
# Transport number: [0.19915475 0.2202106  0.03179231 0.54884235]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.59832232 -1.49712107 -0.33969731 -0.33139252]
#  [ 1.24919384  1.56469609 -0.54402487 -0.48619476]
#  [ 0.74165031  0.27520529  4.87295036 -2.66133793]
#  [ 0.48689051  0.148336    0.53469883  1.13006551]]
# The MAPE is of (8, 12) 10.449003021119571
# The concentration of NaCl is: 8
# The concentration of LaCl3 is: 10
# The concentration of CaCl2 is: 27.333333333333332
# Relaxation correction: [-0.16506847 -0.07646048 -0.02408851 -0.1006252 ]
# Hydrodynamic correction: [-0.38445124 -0.30583871 -0.18122338 -0.11045155]
# omega_bar: 276281470602.7638
# Alpha: [0.0, 167018117764.59967, 307384688416.9951, 367421013423.2125]
# Mew: [0.3        0.36444444 0.02666667 0.30888889]
# Transport number: [0.1632419  0.2537326  0.03127118 0.55175432]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.63045731 -1.80195113 -0.33285507 -0.33115956]
#  [ 1.27430944  1.34071482 -0.53255266 -0.48596696]
#  [ 0.75656152  0.26675448  4.91934203 -2.67111476]
#  [ 0.49667966  0.14521668  0.52692062  1.12560071]]
# The MAPE is of (8, 10) 10.176660414127962
# The concentration of NaCl is: 8
# The concentration of LaCl3 is: 9
# The concentration of CaCl2 is: 29.333333333333332
# Relaxation correction: [-0.167674   -0.07834393 -0.02490094 -0.09952935]
# Hydrodynamic correction: [-0.38456604 -0.30592994 -0.18127744 -0.11048469]
# omega_bar: 278545816238.2457
# Alpha: [0.0, 165293368305.0591, 307599207482.3377, 367302416883.2905]
# Mew: [0.27       0.39111111 0.02666667 0.31222222]
# Transport number: [0.1457234  0.27008484 0.03101697 0.55317479]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.6468529  -1.98291627 -0.32960928 -0.33104741]
#  [ 1.28712367  1.2377165  -0.52711769 -0.48585777]
#  [ 0.76416938  0.25983253  4.94251749 -2.67590436]
#  [ 0.50167419  0.14212265  0.52320307  1.12344541]]
# The MAPE is of (8, 9) 9.902058845237136
# The concentration of NaCl is: 8
# The concentration of LaCl3 is: 8
# The concentration of CaCl2 is: 31.333333333333332
# Relaxation correction: [-0.17026631 -0.08021753 -0.02570842 -0.09844039]
# Hydrodynamic correction: [-0.38468085 -0.30602116 -0.1813315  -0.11051784]
# omega_bar: 280810161873.7276
# Alpha: [0.0, 163582581269.17328, 307807481499.3617, 367186173546.2124]
# Mew: [0.24       0.41777778 0.02666667 0.31555556]
# Transport number: [0.12848741 0.28617336 0.03076687 0.55457236]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.66347658 -2.19080024 -0.32647146 -0.33093805]
#  [ 1.30011616  1.13832444 -0.52186793 -0.48575161]
#  [ 0.77188306  0.25104154  4.96567166 -2.68063022]
#  [ 0.50673819  0.13795023  0.51959175  1.12133926]]
# The MAPE is of (8, 8) 9.536388366005562
# The concentration of NaCl is: 12
# The concentration of LaCl3 is: 24
# The concentration of CaCl2 is: -2.0
# The concentration of NaCl is: 12
# The concentration of LaCl3 is: 20
# The concentration of CaCl2 is: 6.0
# Relaxation correction: [-0.13991599 -0.05846201 -0.01637918 -0.11063159]
# Hydrodynamic correction: [-0.38316403 -0.30481593 -0.18061726 -0.11007978]
# omega_bar: 256731621489.6521
# Alpha: [0.0, 186215415848.98053, 297265975242.0918, 372196457219.7102]
# Mew: [0.6  0.08 0.04 0.28]
# Transport number: [0.35134522 0.0599387  0.05047868 0.53823741]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.49274687 -0.57459706 -0.43712054 -0.31092474]
#  [ 1.16667969  3.82145239 -0.71605767 -0.45423962]
#  [ 0.6926614   0.21272918  3.73207967 -2.31449619]
#  [ 0.45472948  0.10904599  0.60812055  1.12669236]]
# The MAPE is of (12, 20) 7.296517104537021
# The concentration of NaCl is: 12
# The concentration of LaCl3 is: 18
# The concentration of CaCl2 is: 10.0
# Relaxation correction: [-0.14536901 -0.06240858 -0.01809419 -0.10831661]
# Hydrodynamic correction: [-0.38339365 -0.30499839 -0.18072539 -0.11014608]
# omega_bar: 261260312760.61588
# Alpha: [0.0, 182269375290.92908, 298106567154.12744, 371866154322.1601]
# Mew: [0.54       0.13333333 0.04       0.28666667]
# Transport number: [0.31072949 0.0981662  0.04960368 0.54150063]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.52211455 -0.79022543 -0.42459573 -0.31090651]
#  [ 1.18963246  2.84313411 -0.69407118 -0.45434988]
#  [ 0.70628853  0.25211586  3.76627577 -2.32649007]
#  [ 0.46367564  0.13099726  0.59711681  1.12161315]]
# The MAPE is of (12, 18) 9.02629971012994
# The concentration of NaCl is: 12
# The concentration of LaCl3 is: 16
# The concentration of CaCl2 is: 14.0
# Relaxation correction: [-0.15076379 -0.06631165 -0.01978712 -0.1060322 ]
# Hydrodynamic correction: [-0.38362326 -0.30518085 -0.18083351 -0.11021237]
# omega_bar: 265789004031.5796
# Alpha: [0.0, 178424826374.03595, 298883511388.51373, 371549228898.51514]
# Mew: [0.48       0.18666667 0.04       0.29333333]
# Transport number: [0.27149784 0.13509101 0.0487585  0.54465265]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.55219269 -1.00324721 -0.41329049 -0.31089284]
#  [ 1.2131405   2.29554021 -0.67428987 -0.45446175]
#  [ 0.72024533  0.27301292  3.80116409 -2.33818467]
#  [ 0.47283823  0.14364991  0.58704652  1.11678004]]
# The MAPE is of (12, 16) 10.131899293851669
# The concentration of NaCl is: 12
# The concentration of LaCl3 is: 14
# The concentration of CaCl2 is: 18.0
# Relaxation correction: [-0.15610175 -0.07017232 -0.02145857 -0.10377756]
# Hydrodynamic correction: [-0.38385287 -0.3053633  -0.18094164 -0.11027867]
# omega_bar: 270317695302.54337
# Alpha: [0.0, 174671540031.08688, 299604811566.6008, 371244855210.6742]
# Mew: [0.42 0.24 0.04 0.3 ]
# Transport number: [0.23358071 0.1707786  0.04794164 0.54769905]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.58302532 -1.23131542 -0.40301368 -0.31088361]
#  [ 1.23723822  1.92024108 -0.65636235 -0.45457535]
#  [ 0.73455223  0.28188135  3.8365452  -2.34959411]
#  [ 0.48223065  0.15006454  0.57776967  1.11217654]]
# The MAPE is of (12, 14) 10.733050897845365
# The concentration of NaCl is: 12
# The concentration of LaCl3 is: 12
# The concentration of CaCl2 is: 22.0
# Relaxation correction: [-0.16138424 -0.07399161 -0.02310912 -0.10155188]
# Hydrodynamic correction: [-0.38408249 -0.30554576 -0.18104977 -0.11034497]
# omega_bar: 274846386573.50708
# Alpha: [0.0, 171000749074.9727, 300277063326.88495, 370952275278.83136]
# Mew: [0.36       0.29333333 0.04       0.30666667]
# Transport number: [0.19691311 0.20529013 0.04715169 0.55064507]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.61465977 -1.48985847 -0.39361417 -0.31087865]
#  [ 1.26196263  1.63163924 -0.64001156 -0.45469071]
#  [ 0.74923118  0.28155305  3.87226979 -2.36073148]
#  [ 0.49186732  0.15154157  0.56917511  1.10778754]]
# The MAPE is of (12, 12) 10.899784489140117
# The concentration of NaCl is: 12
# The concentration of LaCl3 is: 10
# The concentration of CaCl2 is: 26.0
# Relaxation correction: [-0.16661256 -0.07777054 -0.02473934 -0.09935443]
# Hydrodynamic correction: [-0.3843121  -0.30572822 -0.18115789 -0.11041127]
# omega_bar: 279375077844.47095
# Alpha: [0.0, 167404827532.69086, 300905768790.1845, 370670792020.3537]
# Mew: [0.3        0.34666667 0.04       0.31333333]
# Transport number: [0.16143428 0.23868279 0.04638736 0.55349557]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.64714708 -1.79903599 -0.38497059 -0.31087782]
#  [ 1.28735359  1.39100219 -0.6250156  -0.45480786]
#  [ 0.76430588  0.2732871   3.90822442 -2.3716089 ]
#  [ 0.5017638   0.14861241  0.56117322  1.10359923]]
# The MAPE is of (12, 10) 10.673981169665891
# The concentration of NaCl is: 12
# The concentration of LaCl3 is: 9
# The concentration of CaCl2 is: 28.0
# Relaxation correction: [-0.16920679 -0.07964516 -0.025547   -0.09826607]
# Hydrodynamic correction: [-0.38442691 -0.30581944 -0.18121196 -0.11044442]
# omega_bar: 281639423479.9528
# Alpha: [0.0, 165632812168.40146, 301205270070.5873, 370534008954.3377]
# Mew: [0.27       0.37333333 0.04       0.31666667]
# Transport number: [0.14412273 0.25497642 0.04601441 0.55488644]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.6637276  -1.98212269 -0.38090066 -0.3108789 ]
#  [ 1.30031235  1.28153447 -0.61796801 -0.4548671 ]
#  [ 0.77199954  0.26629364  3.92625992 -2.37695369]
#  [ 0.50681466  0.14552161  0.55737108  1.10157632]]
# The MAPE is of (12, 9) 10.421249359982298
# The concentration of NaCl is: 12
# The concentration of LaCl3 is: 8
# The concentration of CaCl2 is: 30.0
# Relaxation correction: [-0.17178795 -0.08151005 -0.02634977 -0.09718449]
# Hydrodynamic correction: [-0.38454172 -0.30591067 -0.18126602 -0.11047757]
# omega_bar: 283903769115.4347
# Alpha: [0.0, 163877053811.56088, 301495567076.97705, 370399763206.81665]
# Mew: [0.24 0.4  0.04 0.32]
# Transport number: [0.12708733 0.27101013 0.04564741 0.55625513]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.68054234 -2.19217215 -0.37698412 -0.31088094]
#  [ 1.31345418  1.17652893 -0.61119425 -0.45492678]
#  [ 0.77980188  0.25734096  3.94432185 -2.38223765]
#  [ 0.51193686  0.14130033  0.55369067  1.09959889]]
# The MAPE is of (12, 8) 10.076834676800337
# The concentration of NaCl is: 15
# The concentration of LaCl3 is: 24
# The concentration of CaCl2 is: -3.0
# The concentration of NaCl is: 15
# The concentration of LaCl3 is: 20
# The concentration of CaCl2 is: 5.0
# Relaxation correction: [-0.14115739 -0.05950948 -0.01690242 -0.1096244 ]
# Hydrodynamic correction: [-0.38305968 -0.30473306 -0.18056815 -0.11004957]
# omega_bar: 259051826920.93237
# Alpha: [0.0, 187053759252.97, 291991393580.27545, 374359205352.6723]
# Mew: [0.6        0.06666667 0.05       0.28333333]
# Transport number: [0.34819838 0.04950155 0.0625332  0.53976687]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.50416067 -0.5379439  -0.48047197 -0.29864655]
#  [ 1.17560032  4.24177518 -0.79817047 -0.43545378]
#  [ 0.69795761  0.20523413  3.29198309 -2.15060124]
#  [ 0.45820643  0.10489278  0.62433667  1.11440557]]
# The MAPE is of (15, 20) 7.303177260561519
# The concentration of NaCl is: 15
# The concentration of LaCl3 is: 18
# The concentration of CaCl2 is: 9.0
# Relaxation correction: [-0.14659138 -0.06344117 -0.01860931 -0.10732201]
# Hydrodynamic correction: [-0.3832893  -0.30491552 -0.18067627 -0.11011587]
# omega_bar: 263580518191.89618
# Alpha: [0.0, 182970507096.07812, 293025974563.1712, 374007959193.10187]
# Mew: [0.54 0.12 0.05 0.29]
# Transport number: [0.30799425 0.08757187 0.06145879 0.54297508]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.53373802 -0.76731986 -0.46521539 -0.29875815]
#  [ 1.19871696  3.03290689 -0.77062625 -0.43575283]
#  [ 0.71168203  0.25160843  3.32020453 -2.16275478]
#  [ 0.46721645  0.13042577  0.61269392  1.10950854]]
# The MAPE is of (15, 18) 9.13016270836046
# The concentration of NaCl is: 15
# The concentration of LaCl3 is: 16
# The concentration of CaCl2 is: 13.0
# Relaxation correction: [-0.15196766 -0.06732978 -0.02029435 -0.10504985]
# Hydrodynamic correction: [-0.38351891 -0.30509798 -0.1807844  -0.11018217]
# omega_bar: 268109209462.85995
# Alpha: [0.0, 179006962992.24777, 293976724487.83746, 373670354870.09875]
# Mew: [0.48       0.17333333 0.05       0.29666667]
# Transport number: [0.26914831 0.12435609 0.06042068 0.54607492]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.56403952 -0.98788657 -0.45162029 -0.29886996]
#  [ 1.22239957  2.40836792 -0.74618339 -0.43604754]
#  [ 0.72574248  0.27567454  3.34946456 -2.17462945]
#  [ 0.47644708  0.14477995  0.6021673   1.10484481]]
# The MAPE is of (15, 16) 10.301916300818107
# The concentration of NaCl is: 15
# The concentration of LaCl3 is: 14
# The concentration of CaCl2 is: 17.0
# Relaxation correction: [-0.1572876  -0.07117636 -0.02195815 -0.10280712]
# Hydrodynamic correction: [-0.38374852 -0.30528043 -0.18089253 -0.11024846]
# omega_bar: 272637900733.8237
# Alpha: [0.0, 175149481696.53238, 294855128622.30634, 373345579168.44183]
# Mew: [0.42       0.22666667 0.05       0.30333333]
# Transport number: [0.23159289 0.15991828 0.05941705 0.54907178]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.59511016 -1.22110004 -0.43939715 -0.29898209]
#  [ 1.24668332  1.99599225 -0.72429154 -0.43633831]
#  [ 0.74015981  0.28609442  3.37947674 -2.1862377 ]
#  [ 0.485912    0.15208479  0.59256829  1.10039905]]
# The MAPE is of (15, 14) 10.954128641615464
# The concentration of NaCl is: 15
# The concentration of LaCl3 is: 12
# The concentration of CaCl2 is: 21.0
# Relaxation correction: [-0.16255256 -0.07498196 -0.02360127 -0.10059305]
# Hydrodynamic correction: [-0.38397814 -0.30546289 -0.18100065 -0.11031476]
# omega_bar: 277166592004.7875
# Alpha: [0.0, 171386682524.14398, 295670457785.21533, 373032883541.3932]
# Mew: [0.36 0.28 0.05 0.31]
# Transport number: [0.19526472 0.19431836 0.05844622 0.5519707 ]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.62699836 -1.48364774 -0.42832354 -0.29909461]
#  [ 1.27160604  1.68588518 -0.70452928 -0.43662548]
#  [ 0.75495651  0.28645851  3.41003237 -2.19759108]
#  [ 0.49562598  0.15400778  0.58375179  1.09615725]]
# The MAPE is of (15, 12) 11.163421136295241
# The concentration of NaCl is: 15
# The concentration of LaCl3 is: 10
# The concentration of CaCl2 is: 25.0
# Relaxation correction: [-0.16776379 -0.07874754 -0.02522427 -0.09840689]
# Hydrodynamic correction: [-0.38420775 -0.30564535 -0.18110878 -0.11038106]
# omega_bar: 281695283275.7512
# Alpha: [0.0, 167708900993.7831, 296430310470.49054, 372731577752.45734]
# Mew: [0.3        0.33333333 0.05       0.31666667]
# Transport number: [0.16010461 0.22761237 0.05750661 0.55477641]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.65975631 -1.79629839 -0.41822514 -0.29920757]
#  [ 1.29720853  1.43123014 -0.68656748 -0.43690933]
#  [ 0.77015679  0.27836667  3.44097642 -2.20870033]
#  [ 0.5056049   0.1512457   0.57560383  1.09210651]]
# The MAPE is of (15, 10) 10.97509218943045
# The concentration of NaCl is: 15
# The concentration of LaCl3 is: 9
# The concentration of CaCl2 is: 27.0
# Relaxation correction: [-0.17034965 -0.08061562 -0.0260284  -0.09732406]
# Hydrodynamic correction: [-0.38432256 -0.30573657 -0.18116284 -0.11041421]
# omega_bar: 283959628911.2331
# Alpha: [0.0, 165899242612.03458, 296791447183.7613, 372584994895.706]
# Mew: [0.27 0.36 0.05 0.32]
# Transport number: [0.14294512 0.24386113 0.05704804 0.55614571]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.6764789  -1.98105314 -0.41349711 -0.29926422]
#  [ 1.31027833  1.3164069  -0.67817787 -0.43705008]
#  [ 0.77791637  0.27132294  3.45655636 -2.21416656]
#  [ 0.51069904  0.14816161  0.57175136  1.09014905]]
# The MAPE is of (15, 9) 10.739865595557308
# The concentration of NaCl is: 15
# The concentration of LaCl3 is: 8
# The concentration of CaCl2 is: 29.0
# Relaxation correction: [-0.17292254 -0.08247405 -0.02682769 -0.09624795]
# Hydrodynamic correction: [-0.38443737 -0.3058278  -0.18121691 -0.11044736]
# omega_bar: 286223974546.71497
# Alpha: [0.0, 164107798599.80872, 297140996729.00665, 372441024255.5785]
# Mew: [0.24       0.38666667 0.05       0.32333333]
# Transport number: [0.12605712 0.25985281 0.05659673 0.55749334]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.69344045 -2.19278981 -0.40896302 -0.29932098]
#  [ 1.3235349   1.20679696 -0.67014458 -0.4371901 ]
#  [ 0.78578684  0.26224614  3.47219186 -2.21957547]
#  [ 0.51586596  0.1439044   0.56803331  1.08823499]]
# The MAPE is of (15, 8) 10.41240000809689
# The concentration of NaCl is: 20
# The concentration of LaCl3 is: 24
# The concentration of CaCl2 is: -4.666666666666667
# The concentration of NaCl is: 20
# The concentration of LaCl3 is: 20
# The concentration of CaCl2 is: 3.3333333333333335
# Relaxation correction: [-0.14321152 -0.06124322 -0.0177675  -0.10795765]
# Hydrodynamic correction: [-0.38288576 -0.30459495 -0.18048629 -0.10999922]
# omega_bar: 262918835973.06628
# Alpha: [0.0, 188587203672.35318, 283659340439.2967, 377417365394.5673]
# Mew: [0.6        0.04444444 0.06666667 0.28888889]
# Transport number: [0.34307708 0.03251565 0.08215129 0.54225598]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.52330915 -0.45985505 -0.55046186 -0.28257953]
#  [ 1.19056611  5.31873713 -0.93762817 -0.41092616]
#  [ 0.70684285  0.18512345  2.80112525 -1.94742483]
#  [ 0.46403955  0.09409551  0.6411039   1.09952108]]
# The MAPE is of (20, 20) 7.1333147710119205
# The concentration of NaCl is: 20
# The concentration of LaCl3 is: 18
# The concentration of CaCl2 is: 7.333333333333333
# Relaxation correction: [-0.14861425 -0.06515047 -0.01946106 -0.10567591]
# Hydrodynamic correction: [-0.38311538 -0.3047774  -0.18059442 -0.11006552]
# omega_bar: 267447527244.0301
# Alpha: [0.0, 184240056549.63867, 285040036719.0379, 377041528712.38904]
# Mew: [0.54       0.09777778 0.06666667 0.29555556]
# Transport number: [0.30354098 0.07032314 0.08076022 0.54537566]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.55324558 -0.72212371 -0.52954303 -0.28283882]
#  [ 1.2139634   3.43083887 -0.89801312 -0.41143646]
#  [ 0.72073389  0.24855772  2.82165703 -1.9594252 ]
#  [ 0.47315896  0.12828886  0.628134    1.09485558]]
# The MAPE is of (20, 18) 9.154281041977466
# The concentration of NaCl is: 20
# The concentration of LaCl3 is: 16
# The concentration of CaCl2 is: 11.333333333333334
# Relaxation correction: [-0.15396011 -0.0690153  -0.02113318 -0.10342385]
# Hydrodynamic correction: [-0.38334499 -0.30495986 -0.18070254 -0.11013182]
# omega_bar: 271976218514.99387
# Alpha: [0.0, 180052255760.07288, 286294396403.59265, 376679465764.90063]
# Mew: [0.48       0.15111111 0.06666667 0.30222222]
# Transport number: [0.26532151 0.10687156 0.07941548 0.54839145]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.58392961 -0.95841163 -0.51135532 -0.28309367]
#  [ 1.23794499  2.62844378 -0.86377671 -0.41193622]
#  [ 0.73497184  0.27951846  2.84396719 -1.97117742]
#  [ 0.48250612  0.1463028   0.61669522  1.09040602]]
# The MAPE is of (20, 16) 10.450739954876216
# The concentration of NaCl is: 20
# The concentration of LaCl3 is: 14
# The concentration of CaCl2 is: 15.333333333333334
# Relaxation correction: [-0.15925044 -0.07283875 -0.02278442 -0.10120067]
# Hydrodynamic correction: [-0.38357461 -0.30514232 -0.18081067 -0.11019812]
# omega_bar: 276504909785.9576
# Alpha: [0.0, 176001670466.04825, 287442480924.7818, 376330394605.4227]
# Mew: [0.42       0.20444444 0.06666667 0.30888889]
# Transport number: [0.22835399 0.14222278 0.07811478 0.55130845]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.61540789 -1.20165868 -0.49533385 -0.28334441]
#  [ 1.26254733  2.13820175 -0.8337834  -0.41242612]
#  [ 0.74957832  0.29315176  2.8675428  -1.98269181]
#  [ 0.49209522  0.15542717  0.60647401  1.08615864]]
# The MAPE is of (20, 14) 11.1967703793165
# The concentration of NaCl is: 20
# The concentration of LaCl3 is: 12
# The concentration of CaCl2 is: 19.333333333333332
# Relaxation correction: [-0.16448655 -0.07662182 -0.02441535 -0.09900563]
# Hydrodynamic correction: [-0.38380422 -0.30532477 -0.1809188  -0.11026442]
# omega_bar: 281033601056.9213
# Alpha: [0.0, 172070722566.43024, 288499843431.3467, 375993592772.90466]
# Mew: [0.36       0.25777778 0.06666667 0.31555556]
# Transport number: [0.19257788 0.17643466 0.07685601 0.55413144]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.64773069 -1.47167855 -0.48106763 -0.28359133]
#  [ 1.28780971  1.78529701 -0.80721074 -0.41290675]
#  [ 0.76457668  0.29492112  2.89203045 -1.993978  ]
#  [ 0.50194158  0.1582383   0.59724288  1.08210083]]
# The MAPE is of (20, 12) 11.483047577205886
# The concentration of NaCl is: 20
# The concentration of LaCl3 is: 10
# The concentration of CaCl2 is: 23.333333333333332
# Relaxation correction: [-0.16966968 -0.08036546 -0.02602651 -0.09683802]
# Hydrodynamic correction: [-0.38403384 -0.30550723 -0.18102692 -0.11033071]
# omega_bar: 285562292327.8851
# Alpha: [0.0, 168245098478.36407, 289478810725.2, 375668391679.91626]
# Mew: [0.3        0.31111111 0.06666667 0.32222222]
# Transport number: [0.15793652 0.20956143 0.07563716 0.55686489]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.68095227 -1.79059718 -0.46824895 -0.28383467]
#  [ 1.31377456  1.50372801 -0.78344563 -0.41337866]
#  [ 0.7799921   0.28720281  2.91717946 -2.00504498]
#  [ 0.51206174  0.15581113  0.58883181  1.07822098]]
# The MAPE is of (20, 10) 11.36173768201843
# The concentration of NaCl is: 20
# The concentration of LaCl3 is: 9
# The concentration of CaCl2 is: 25.333333333333332
# Relaxation correction: [-0.17224176 -0.08222278 -0.02682483 -0.09576428]
# Hydrodynamic correction: [-0.38414864 -0.30559846 -0.18108099 -0.11036386]
# omega_bar: 287826637963.367
# Alpha: [0.0, 166367985753.28235, 289942081277.8707, 375509945971.05225]
# Mew: [0.27       0.33777778 0.06666667 0.32555556]
# Transport number: [0.14102462 0.2257339  0.07504212 0.55819936]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.69791828 -1.97830134 -0.46230651 -0.28395507]
#  [ 1.32703461  1.37883902 -0.77246519 -0.4136115 ]
#  [ 0.78786463  0.2800834   2.92994305 -2.01049892]
#  [ 0.51723003  0.15274799  0.58489187  1.07634441]]
# The MAPE is of (20, 9) 11.157590945717226
# The concentration of NaCl is: 20
# The concentration of LaCl3 is: 8
# The concentration of CaCl2 is: 27.333333333333332
# Relaxation correction: [-0.17480104 -0.08407059 -0.0276184  -0.09469715]
# Hydrodynamic correction: [-0.38426345 -0.30568969 -0.18113505 -0.11039701]
# omega_bar: 290090983598.84894
# Alpha: [0.0, 164512892507.30576, 290389333508.13605, 375354171631.18555]
# Mew: [0.24       0.36444444 0.06666667 0.32888889]
# Transport number: [0.12437674 0.24165389 0.07445637 0.559513  ]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.71513138 -2.19298717 -0.45664186 -0.28407465]
#  [ 1.34048778  1.2606754  -0.76201992 -0.41384233]
#  [ 0.79585182  0.27079394  2.94280778 -2.01590118]
#  [ 0.52247358  0.14843264  0.5811105   1.07450838]]
# The MAPE is of (20, 8) 10.860085591606362
# The concentration of NaCl is: 25
# The concentration of LaCl3 is: 24
# The concentration of CaCl2 is: -6.333333333333333
# The concentration of NaCl is: 25
# The concentration of LaCl3 is: 20
# The concentration of CaCl2 is: 1.6666666666666667
# Relaxation correction: [-0.14524741 -0.06296217 -0.01862401 -0.1063055 ]
# Hydrodynamic correction: [-0.38271185 -0.30445683 -0.18040444 -0.10994888]
# omega_bar: 266785845025.20013
# Alpha: [0.0, 190330907327.3134, 275667994206.7023, 379983351358.04517]
# Mew: [0.6        0.02222222 0.08333333 0.29444444]
# Transport number: [0.33810425 0.01602217 0.10120065 0.54467293]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.54262017 -0.34255822 -0.62266447 -0.27006209]
#  [ 1.20565894  7.72116199 -1.0908678  -0.39186943]
#  [ 0.71580351  0.14632459  2.47273705 -1.79809489]
#  [ 0.46992219  0.07390133  0.65132411  1.08878502]]
# The MAPE is of (25, 20) 6.7308948823524775
# The concentration of NaCl is: 25
# The concentration of LaCl3 is: 18
# The concentration of CaCl2 is: 5.666666666666667
# Relaxation correction: [-0.15061942 -0.06684542 -0.02030451 -0.10404401]
# Hydrodynamic correction: [-0.38294146 -0.30463929 -0.18051256 -0.11001517]
# omega_bar: 271314536296.16394
# Alpha: [0.0, 185660959539.08145, 277442920601.29785, 379591202699.63385]
# Mew: [0.54       0.07555556 0.08333333 0.30111111]
# Transport number: [0.29921465 0.0535661  0.09951144 0.54770781]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.57292806 -0.66483514 -0.59400929 -0.27041977]
#  [ 1.22934655  3.99180066 -1.03377368 -0.39251748]
#  [ 0.72986692  0.24122696  2.48656643 -1.80974768]
#  [ 0.47915476  0.1238945   0.63650421  1.0843036 ]]
# The MAPE is of (25, 18) 9.006927331623116
# The concentration of NaCl is: 25
# The concentration of LaCl3 is: 16
# The concentration of CaCl2 is: 9.666666666666666
# Relaxation correction: [-0.15593536 -0.07068689 -0.02196395 -0.10181165]
# Hydrodynamic correction: [-0.38317108 -0.30482174 -0.18062069 -0.11008147]
# omega_bar: 275843227567.1277
# Alpha: [0.0, 181207396372.79718, 279031942287.58185, 379212742240.55804]
# Mew: [0.48       0.12888889 0.08333333 0.30777778]
# Transport number: [0.26160201 0.08987726 0.0978777  0.55064303]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.60400779 -0.92288339 -0.56985036 -0.27077017]
#  [ 1.2536374   2.90307137 -0.98604579 -0.39315133]
#  [ 0.74428847  0.28222038  2.50330381 -1.82117763]
#  [ 0.48862245  0.14715819  0.62385878  1.08002378]]
# The MAPE is of (25, 16) 10.449931172427334
# The concentration of NaCl is: 25
# The concentration of LaCl3 is: 14
# The concentration of CaCl2 is: 13.666666666666666
# Relaxation correction: [-0.16119657 -0.0744876  -0.02360288 -0.09960766]
# Hydrodynamic correction: [-0.38340069 -0.3050042  -0.18072882 -0.11014777]
# omega_bar: 280371918838.09143
# Alpha: [0.0, 176933681688.35318, 280469601807.05615, 378847224513.10284]
# Mew: [0.42       0.18222222 0.08333333 0.31444444]
# Transport number: [0.22520443 0.1250154  0.09629674 0.55348343]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.63590777 -1.17865222 -0.54908288 -0.27111371]
#  [ 1.27856933  2.30555159 -0.94533098 -0.39377179]
#  [ 0.75909064  0.30016611  2.52201969 -1.83239355]
#  [ 0.49834002  0.15868417  0.61284852  1.07593312]]
# The MAPE is of (25, 14) 11.301695363840288
# The concentration of NaCl is: 25
# The concentration of LaCl3 is: 12
# The concentration of CaCl2 is: 17.666666666666668
# Relaxation correction: [-0.16640431 -0.07824852 -0.02522186 -0.09743131]
# Hydrodynamic correction: [-0.3836303  -0.30518666 -0.18083694 -0.11021407]
# omega_bar: 284900610109.0553
# Alpha: [0.0, 172812402401.6327, 281781357846.99347, 378493958643.6303]
# Mew: [0.36       0.23555556 0.08333333 0.32111111]
# Transport number: [0.18996399 0.15903645 0.09476604 0.55623353]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.66868023 -1.45741652 -0.53095526 -0.27145081]
#  [ 1.30418316  1.89822788 -0.9100378  -0.39437959]
#  [ 0.77429765  0.30375517  2.54211777 -1.84340365]
#  [ 0.50832336  0.16261939  0.60310963  1.0720201 ]]
# The MAPE is of (25, 12) 11.672717023236407
# The concentration of NaCl is: 25
# The concentration of LaCl3 is: 10
# The concentration of CaCl2 is: 21.666666666666668
# Relaxation correction: [-0.1715598  -0.08197058 -0.02682139 -0.0952819 ]
# Hydrodynamic correction: [-0.38385992 -0.30536911 -0.18094507 -0.11028037]
# omega_bar: 289429301380.01904
# Alpha: [0.0, 168822263088.6529, 282986584317.7195, 378152303385.50275]
# Mew: [0.3        0.28888889 0.08333333 0.32777778]
# Transport number: [0.15582636 0.19199284 0.09328323 0.55889757]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.70238162 -1.78333217 -0.51493442 -0.27178182]
#  [ 1.33052301  1.58414404 -0.87904389 -0.39497542]
#  [ 0.7899357   0.2965431   2.56319878 -1.85421567]
#  [ 0.51858968  0.16061526  0.59438576  1.06827416]]
# The MAPE is of (25, 10) 11.624002328625942
# The concentration of NaCl is: 25
# The concentration of LaCl3 is: 9
# The concentration of CaCl2 is: 23.666666666666668
# Relaxation correction: [-0.17411832 -0.08381732 -0.02761402 -0.09421709]
# Hydrodynamic correction: [-0.38397473 -0.30546034 -0.18099913 -0.11031351]
# omega_bar: 291693647015.50085
# Alpha: [0.0, 166870920271.47702, 283554106557.77484, 377985641815.39215]
# Mew: [0.27       0.31555556 0.08333333 0.33111111]
# Transport number: [0.13915504 0.20808729 0.0925591  0.56019857]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.71959959 -1.97423573 -0.50758773 -0.27194515]
#  [ 1.34397998  1.44745063 -0.86489449 -0.39526904]
#  [ 0.79792515  0.28936125  2.57401798 -1.85954968]
#  [ 0.52383472  0.15758796  0.59034398  1.06646075]]
# The MAPE is of (25, 9) 11.453194685768329
# The concentration of NaCl is: 25
# The concentration of LaCl3 is: 8
# The concentration of CaCl2 is: 25.666666666666668
# Relaxation correction: [-0.17666421 -0.08565468 -0.02840198 -0.09315877]
# Hydrodynamic correction: [-0.38408953 -0.30555157 -0.1810532  -0.11034666]
# omega_bar: 293957992650.9828
# Alpha: [0.0, 164946241855.87857, 284100408071.4695, 377821662686.0566]
# Mew: [0.24       0.34222222 0.08333333 0.33444444]
# Transport number: [0.12274057 0.22393379 0.09184612 0.56147953]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.73707312 -2.1920699  -0.50062946 -0.27210707]
#  [ 1.3576367   1.31941513 -0.85153064 -0.39555988]
#  [ 0.80603318  0.27985131  2.58498615 -1.86483685]
#  [ 0.52915761  0.15321725  0.58648984  1.0646855 ]]
# The MAPE is of (25, 8) 11.187645321320009
# The concentration of NaCl is: 30
# The concentration of LaCl3 is: 24
# The concentration of CaCl2 is: -8.0
# The concentration of NaCl is: 30
# The concentration of LaCl3 is: 20
# The concentration of CaCl2 is: 0.0
# The concentration of NaCl is: 30
# The concentration of LaCl3 is: 18
# The concentration of CaCl2 is: 4.0
# Relaxation correction: [-0.15260722 -0.06852629 -0.02113983 -0.10242603]
# Hydrodynamic correction: [-0.38276754 -0.30450117 -0.18043071 -0.10996483]
# omega_bar: 275181545348.29785
# Alpha: [0.0, 187272882411.60233, 270061259665.1941, 381788490641.30786]
# Mew: [0.54       0.05333333 0.1        0.30666667]
# Transport number: [0.29500991 0.03728002 0.11773566 0.54997441]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.59279257 -0.58860113 -0.6622077  -0.26030383]
#  [ 1.24487197  4.87068966 -1.18678511 -0.37714527]
#  [ 0.73908441  0.22631277  2.24227872 -1.69361332]
#  [ 0.48520601  0.11557571  0.64128095  1.07621678]]
# The MAPE is of (30, 18) 8.69365462075218
# The concentration of NaCl is: 30
# The concentration of LaCl3 is: 16
# The concentration of CaCl2 is: 8.0
# Relaxation correction: [-0.15789376 -0.0723448  -0.02278684 -0.100213  ]
# Hydrodynamic correction: [-0.38299716 -0.30468363 -0.18053883 -0.11003113]
# omega_bar: 279710236619.26166
# Alpha: [0.0, 182496526064.24628, 272034464117.30548, 381398855664.17755]
# Mew: [0.48       0.10666667 0.1        0.31333333]
# Transport number: [0.25798534 0.07335286 0.11582945 0.55283235]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.62428159 -0.87923186 -0.62997936 -0.26072179]
#  [ 1.26948271  3.25954811 -1.11969021 -0.37787192]
#  [ 0.75369588  0.28302788  2.25374043 -1.70466276]
#  [ 0.49479838  0.14694694  0.62696703  1.07208215]]
# The MAPE is of (30, 16) 10.312722368452992
# The concentration of NaCl is: 30
# The concentration of LaCl3 is: 14
# The concentration of CaCl2 is: 12.0
# Relaxation correction: [-0.16312632 -0.07612316 -0.02441371 -0.09802784]
# Hydrodynamic correction: [-0.38322677 -0.30486608 -0.18064696 -0.11009742]
# omega_bar: 284238927890.22534
# Alpha: [0.0, 177960463267.50793, 273793627679.1845, 381021996594.57745]
# Mew: [0.42 0.16 0.1  0.32]
# Transport number: [0.22214057 0.10827623 0.11398397 0.55559923]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.65661781 -1.15123323 -0.60311192 -0.26113114]
#  [ 1.29475559  2.50661016 -1.064343   -0.378583  ]
#  [ 0.76870047  0.30697525  2.26826539 -1.7155178 ]
#  [ 0.50464883  0.16175877  0.61492296  1.06812543]]
# The MAPE is of (30, 14) 11.2842136025608
# The concentration of NaCl is: 30
# The concentration of LaCl3 is: 12
# The concentration of CaCl2 is: 16.0
# Relaxation correction: [-0.16830615 -0.07986229 -0.02602095 -0.09586983]
# Hydrodynamic correction: [-0.38345639 -0.30504854 -0.18075509 -0.11016372]
# omega_bar: 288767619161.1891
# Alpha: [0.0, 173621035414.9269, 275380515252.3503, 380657255734.6425]
# Mew: [0.36       0.21333333 0.1        0.32666667]
# Transport number: [0.1874201  0.1421042  0.11219638 0.55827932]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.68985552 -1.44046825 -0.58021323 -0.26153232]
#  [ 1.32073304  2.02814261 -1.01761418 -0.3792793 ]
#  [ 0.78412337  0.31296945  2.28482547 -1.72618562]
#  [ 0.5147739   0.16714653  0.60454666  1.06433607]]
# The MAPE is of (30, 12) 11.74839181071146
# The concentration of NaCl is: 30
# The concentration of LaCl3 is: 10
# The concentration of CaCl2 is: 20.0
# Relaxation correction: [-0.17343443 -0.08356313 -0.02760907 -0.0937383 ]
# Hydrodynamic correction: [-0.383686   -0.305231   -0.18086321 -0.11023002]
# omega_bar: 293296310432.1529
# Alpha: [0.0, 169446164466.8309, 276825338996.1214, 380304021082.16394]
# Mew: [0.3        0.26666667 0.1        0.33333333]
# Transport number: [0.15377184 0.17488752 0.11046399 0.56087665]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.7240535  -1.77430909 -0.56035967 -0.26192577]
#  [ 1.347461    1.67408034 -0.97744255 -0.37996158]
#  [ 0.79999184  0.30644206  2.30278029 -1.73667294]
#  [ 0.52519149  0.16568129  0.59544365  1.06070434]]
# The MAPE is of (30, 10) 11.777984405206249
# The concentration of NaCl is: 30
# The concentration of LaCl3 is: 9
# The concentration of CaCl2 is: 22.0
# Relaxation correction: [-0.1759796  -0.08539945 -0.02839611 -0.09268226]
# Hydrodynamic correction: [-0.38380081 -0.30532222 -0.18091728 -0.11026317]
# omega_bar: 295560656067.63477
# Alpha: [0.0, 167412556429.81287, 277501781274.14825, 380131538845.7282]
# Mew: [0.27       0.29333333 0.1        0.33666667]
# Transport number: [0.13733439 0.19090244 0.10961771 0.56214546]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.74153229 -1.96871818 -0.55136622 -0.26211972]
#  [ 1.36112183  1.52336482 -0.95935309 -0.38029767]
#  [ 0.80810231  0.29921585  2.31214394 -1.74185091]
#  [ 0.53051599  0.16270884  0.59128136  1.05894475]]
# The MAPE is of (30, 9) 11.64275007050778
# The concentration of NaCl is: 30
# The concentration of LaCl3 is: 8
# The concentration of CaCl2 is: 24.0
# Relaxation correction: [-0.17851231 -0.08722653 -0.02917856 -0.0916326 ]
# Hydrodynamic correction: [-0.38391562 -0.30541345 -0.18097134 -0.11029632]
# omega_bar: 297825001703.11664
# Alpha: [0.0, 165411344460.07425, 278150760383.7698, 379961722373.4725]
# Mew: [0.24 0.32 0.1  0.34]
# Transport number: [0.12114688 0.20667384 0.10878429 0.56339498]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.75927547 -2.1899395  -0.54290879 -0.26231188]
#  [ 1.37498929  1.38381377 -0.94240437 -0.3806305 ]
#  [ 0.81633547  0.28947684  2.32171119 -1.74698611]
#  [ 0.53592102  0.15828643  0.58734232  1.05722124]]
# The MAPE is of (30, 8) 11.411091005768037
# The concentration of NaCl is: 50
# The concentration of LaCl3 is: 24
# The concentration of CaCl2 is: -14.666666666666666
# The concentration of NaCl is: 50
# The concentration of LaCl3 is: 20
# The concentration of CaCl2 is: -6.666666666666667
# The concentration of NaCl is: 50
# The concentration of LaCl3 is: 18
# The concentration of CaCl2 is: -2.6666666666666665
# The concentration of NaCl is: 50
# The concentration of LaCl3 is: 16
# The concentration of CaCl2 is: 1.3333333333333333
# Relaxation correction: [-0.16556492 -0.07884479 -0.02600284 -0.09394879]
# Hydrodynamic correction: [-0.38230149 -0.30413116 -0.18021141 -0.10982974]
# omega_bar: 295178272827.7971
# Alpha: [0.0, 189977519634.6224, 244384277269.8264, 387958484005.55786]
# Mew: [0.48       0.01777778 0.16666667 0.33555556]
# Transport number: [0.2444663  0.01158483 0.18293285 0.56101601]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.70749134 -0.4718929  -0.94761608 -0.23314688]
#  [ 1.33451659  8.97233002 -1.98068811 -0.33614622]
#  [ 0.7923067   0.19919251  1.67563723 -1.41113396]
#  [ 0.52014623  0.1007337   0.62819726  1.05221155]]
# The MAPE is of (50, 16) 8.413617031983753
# The concentration of NaCl is: 50
# The concentration of LaCl3 is: 14
# The concentration of CaCl2 is: 5.333333333333333
# Relaxation correction: [-0.17068742 -0.08253733 -0.02758364 -0.09183557]
# Hydrodynamic correction: [-0.3825311  -0.30431362 -0.18031954 -0.10989604]
# omega_bar: 299706964098.76086
# Alpha: [0.0, 183545701433.25964, 248228701616.09045, 387563264907.7626]
# Mew: [0.42       0.07111111 0.16666667 0.34222222]
# Transport number: [0.21067578 0.04563913 0.18016866 0.56351643]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.74172834 -0.95950721 -0.85892225 -0.23368985]
#  [ 1.36127505  4.11226475 -1.74173556 -0.33703174]
#  [ 0.80819329  0.32167423  1.66602059 -1.42059126]
#  [ 0.53057571  0.16642093  0.60467727  1.04868014]]
# The MAPE is of (50, 14) 10.13217208045983
# The concentration of NaCl is: 50
# The concentration of LaCl3 is: 12
# The concentration of CaCl2 is: 9.333333333333334
# Relaxation correction: [-0.17575993 -0.08619282 -0.02914607 -0.08974771]
# Hydrodynamic correction: [-0.38276072 -0.30449607 -0.18042767 -0.10996233]
# omega_bar: 304235655369.7246
# Alpha: [0.0, 177824146794.61713, 251379799978.80856, 387179172866.8865]
# Mew: [0.36       0.12444444 0.16666667 0.34888889]
# Transport number: [0.17789123 0.07867959 0.17748677 0.56594241]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.77699473 -1.33179016 -0.79698007 -0.23422193]
#  [ 1.38883805  2.85822342 -1.58028097 -0.33789958]
#  [ 0.82455753  0.35298793  1.66885618 -1.42991131]
#  [ 0.54131877  0.18608535  0.58880441  1.04528457]]
# The MAPE is of (50, 12) 11.089094861994594
# The concentration of NaCl is: 50
# The concentration of LaCl3 is: 10
# The concentration of CaCl2 is: 13.333333333333334
# Relaxation correction: [-0.18078353 -0.08981207 -0.03069058 -0.0876846 ]
# Hydrodynamic correction: [-0.38299033 -0.30467853 -0.18053579 -0.11002863]
# omega_bar: 308764346640.68835
# Alpha: [0.0, 172580854133.4914, 254067866975.06967, 386805707845.50916]
# Mew: [0.3        0.17777778 0.16666667 0.35555556]
# Transport number: [0.1460684  0.11075084 0.17488354 0.56829722]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.8133599  -1.71470694 -0.75000616 -0.23474361]
#  [ 1.41725982  2.18426502 -1.46112497 -0.33875048]
#  [ 0.84143162  0.35306868  1.67762385 -1.43909851]
#  [ 0.55239655  0.18915053  0.576994    1.04201759]]
# The MAPE is of (50, 10) 11.502251736387109
# The concentration of NaCl is: 50
# The concentration of LaCl3 is: 9
# The concentration of CaCl2 is: 15.333333333333334
# Relaxation correction: [-0.18327731 -0.09160836 -0.03145626 -0.08666214]
# Hydrodynamic correction: [-0.38310514 -0.30476976 -0.18058986 -0.11006178]
# omega_bar: 311028692276.1703
# Alpha: [0.0, 170096176664.52905, 255280110409.5186, 386622812638.3444]
# Mew: [0.27       0.20444444 0.16666667 0.35888889]
# Transport number: [0.13050449 0.12643623 0.17361036 0.56944892]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.8319779  -1.92817484 -0.7303046  -0.23500069]
#  [ 1.43181101  1.93653081 -1.4120392  -0.3391698 ]
#  [ 0.85007071  0.34604484  1.68331546 -1.44364358]
#  [ 0.55806807  0.18674331  0.57208022  1.04043018]]
# The MAPE is of (50, 9) 11.534682702827082
# The concentration of NaCl is: 50
# The concentration of LaCl3 is: 8
# The concentration of CaCl2 is: 17.333333333333332
# Relaxation correction: [-0.18575926 -0.09339589 -0.03221762 -0.08564565]
# Hydrodynamic correction: [-0.38321995 -0.30486099 -0.18064392 -0.11009493]
# omega_bar: 313293037911.6522
# Alpha: [0.0, 167687338803.7817, 256419682330.27344, 386442400405.5407]
# Mew: [0.24       0.23111111 0.16666667 0.36222222]
# Transport number: [0.11516557 0.14189489 0.17235558 0.57058396]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.85089949 -2.16662759 -0.7125319  -0.23525533]
#  [ 1.44659948  1.72263255 -1.36822471 -0.33958516]
#  [ 0.85885066  0.33528441  1.68960358 -1.44815699]
#  [ 0.56383208  0.18218199  0.5676598   1.03887243]]
# The MAPE is of (50, 8) 11.459625997366404
# The concentration of NaCl is: 75
# The concentration of LaCl3 is: 24
# The concentration of CaCl2 is: -23.0
# The concentration of NaCl is: 75
# The concentration of LaCl3 is: 20
# The concentration of CaCl2 is: -15.0
# The concentration of NaCl is: 75
# The concentration of LaCl3 is: 18
# The concentration of CaCl2 is: -11.0
# The concentration of NaCl is: 75
# The concentration of LaCl3 is: 16
# The concentration of CaCl2 is: -7.0
# The concentration of NaCl is: 75
# The concentration of LaCl3 is: 14
# The concentration of CaCl2 is: -3.0
# The concentration of NaCl is: 75
# The concentration of LaCl3 is: 12
# The concentration of CaCl2 is: 1.0
# Relaxation correction: [-0.18475129 -0.09384165 -0.03290226 -0.08235752]
# Hydrodynamic correction: [-0.38189113 -0.30380549 -0.18001839 -0.1097106 ]
# omega_bar: 323570700630.39404
# Alpha: [0.0, 189074381540.3241, 218946467701.66776, 392638566411.75543]
# Mew: [0.36       0.01333333 0.25       0.37666667]
# Transport number: [0.1672613  0.00792622 0.2503215  0.57449098]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.89215039 -0.77399009 -1.32428589 -0.21364089]
#  [ 1.47883976 10.4152877  -3.92480726 -0.30694178]
#  [ 0.87799182  0.31684648  1.26792882 -1.23124236]
#  [ 0.57639817  0.16076365  0.56307473  1.03224921]]
# The MAPE is of (75, 12) 8.175929533889285
# The concentration of NaCl is: 75
# The concentration of LaCl3 is: 10
# The concentration of CaCl2 is: 5.0
# Relaxation correction: [-0.18965255 -0.09736576 -0.03439641 -0.08037361]
# Hydrodynamic correction: [-0.38212075 -0.30398795 -0.18012652 -0.1097769 ]
# omega_bar: 328099391901.3578
# Alpha: [0.0, 179491279625.93594, 226130112501.93427, 392265435362.2251]
# Mew: [0.3        0.06666667 0.25       0.38333333]
# Transport number: [0.13746052 0.03908409 0.24686636 0.57658902]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.93169005 -1.52661828 -1.08024949 -0.21421299]
#  [ 1.50974261  3.92778517 -2.7900303  -0.30784812]
#  [ 0.89633894  0.4348789   1.23397495 -1.23916798]
#  [ 0.58844298  0.228035    0.52586903  1.02933678]]
# The MAPE is of (75, 10) 9.445296000403832
# The concentration of NaCl is: 75
# The concentration of LaCl3 is: 9
# The concentration of CaCl2 is: 7.0
# Relaxation correction: [-0.19208624 -0.09911532 -0.03513738 -0.07939005]
# Hydrodynamic correction: [-0.38223555 -0.30407918 -0.18018058 -0.10981005]
# omega_bar: 330363737536.8397
# Alpha: [0.0, 175670689426.9423, 228753332430.34155, 392082251738.6148]
# Mew: [0.27       0.09333333 0.25       0.38666667]
# Transport number: [0.12286652 0.05434269 0.24517432 0.57761648]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.9519798  -1.80356657 -1.01480447 -0.21449518]
#  [ 1.52560037  3.10462259 -2.51804622 -0.30829528]
#  [ 0.90575375  0.4331948   1.23507056 -1.24309444]
#  [ 0.59462377  0.2299125   0.51788073  1.02791776]]
# The MAPE is of (75, 9) 9.789307961459171
# The concentration of NaCl is: 75
# The concentration of LaCl3 is: 8
# The concentration of CaCl2 is: 9.0
# Relaxation correction: [-0.19450879 -0.10085666 -0.03587434 -0.07841202]
# Hydrodynamic correction: [-0.38235036 -0.3041704  -0.18023464 -0.1098432 ]
# omega_bar: 332628083172.32153
# Alpha: [0.0, 172197853265.2544, 231030095792.40674, 391901263538.42596]
# Mew: [0.24 0.12 0.25 0.39]
# Transport number: [0.10847121 0.06939354 0.24350531 0.57862994]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.97263295 -2.08606772 -0.9643384  -0.21477486]
#  [ 1.54174217  2.56158864 -2.31873656 -0.30873852]
#  [ 0.91533718  0.42089879  1.23963178 -1.2469971 ]
#  [ 0.60091525  0.22574595  0.51226066  1.02652273]]
# The MAPE is of (75, 8) 9.986032298283115
# The concentration of NaCl is: 100
# The concentration of LaCl3 is: 24
# The concentration of CaCl2 is: -31.333333333333332
# The concentration of NaCl is: 100
# The concentration of LaCl3 is: 20
# The concentration of CaCl2 is: -23.333333333333332
# The concentration of NaCl is: 100
# The concentration of LaCl3 is: 18
# The concentration of CaCl2 is: -19.333333333333332
# The concentration of NaCl is: 100
# The concentration of LaCl3 is: 16
# The concentration of CaCl2 is: -15.333333333333334
# The concentration of NaCl is: 100
# The concentration of LaCl3 is: 14
# The concentration of CaCl2 is: -11.333333333333334
# The concentration of NaCl is: 100
# The concentration of LaCl3 is: 12
# The concentration of CaCl2 is: -7.333333333333333
# The concentration of NaCl is: 100
# The concentration of LaCl3 is: 10
# The concentration of CaCl2 is: -3.3333333333333335
# The concentration of NaCl is: 100
# The concentration of LaCl3 is: 9
# The concentration of CaCl2 is: -1.3333333333333333
# The concentration of NaCl is: 100
# The concentration of LaCl3 is: 8
# The concentration of CaCl2 is: 0.6666666666666666

# %% [markdown]
# ### 200 mM Ionic Strength

# %%
# desired ionic strength in mM
ionic_strength_200 = 200

# cation concentration in mM
# na_200 = [10, 12, 15, 20, 25, 30]
# la_200 = [16, 14, 12, 10, 8, 6]

na_200 = [12, 20, 25, 30, 35, 40, 50, 70, 100]
la_200 = [32, 28, 24, 22, 20, 18, 16, 14, 12]

three_salts_conc(la_200, na_200, ionic_strength_200, "ionic_str_200")
# Out:
# The concentration of NaCl is: 12
# The concentration of LaCl3 is: 32
# The concentration of CaCl2 is: -1.3333333333333333
# The concentration of NaCl is: 12
# The concentration of LaCl3 is: 28
# The concentration of CaCl2 is: 6.666666666666667
# Relaxation correction: [-0.1456693  -0.05954095 -0.0161334  -0.12094849]
# Hydrodynamic correction: [-0.42656354 -0.34006395 -0.20145394 -0.12179248]
# omega_bar: 252147070422.88983
# Alpha: [0.0, 187375116922.66306, 302510733605.00964, 369845227275.9801]
# Mew: [0.63       0.06666667 0.03       0.27333333]
# Transport number: [0.37562006 0.05085709 0.03854736 0.53497549]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.4670554  -0.49693421 -0.39561194 -0.32643631]
#  [ 1.14660012  4.20837116 -0.63987413 -0.47793659]
#  [ 0.6807401   0.19175945  4.36671127 -2.52463189]
#  [ 0.44690319  0.09789399  0.58863095  1.14605952]]
# The MAPE is of (12, 28) 6.563720767286197
# The concentration of NaCl is: 12
# The concentration of LaCl3 is: 24
# The concentration of CaCl2 is: 14.666666666666666
# Relaxation correction: [-0.15447112 -0.06594996 -0.01892703 -0.11720804]
# Hydrodynamic correction: [-0.42699715 -0.34040903 -0.20165841 -0.12191722]
# omega_bar: 258940107329.3355
# Alpha: [0.0, 181607744310.216, 303506557737.4073, 369387050437.03345]
# Mew: [0.54       0.14666667 0.03       0.28333333]
# Transport number: [0.31351375 0.10895039 0.03753611 0.53999975]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.51055008 -0.81062717 -0.38002152 -0.32612643]
#  [ 1.18059407  2.67963128 -0.61325157 -0.47768796]
#  [ 0.70092241  0.25191731  4.43006263 -2.54181104]
#  [ 0.4601528   0.13118317  0.57265874  1.13796531]]
# The MAPE is of (12, 24) 9.576079411068623
# The concentration of NaCl is: 12
# The concentration of LaCl3 is: 22
# The concentration of CaCl2 is: 18.666666666666668
# Relaxation correction: [-0.15881613 -0.06911258 -0.0203025  -0.11536732]
# Hydrodynamic correction: [-0.42721395 -0.34058158 -0.20176064 -0.12197958]
# omega_bar: 262336625782.55838
# Alpha: [0.0, 178798685391.35922, 303964176830.7735, 369169005835.05585]
# Mew: [0.495      0.18666667 0.03       0.28833333]
# Transport number: [0.28366675 0.13686882 0.03705012 0.54241431]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.53287691 -0.96444865 -0.37299735 -0.32598093]
#  [ 1.19804394  2.29811446 -0.60129082 -0.47757278]
#  [ 0.71128246  0.26673744  4.4620886  -2.55012878]
#  [ 0.46695414  0.1401801   0.56535949  1.13414338]]
# The MAPE is of (12, 22) 10.487654680810815
# The concentration of NaCl is: 12
# The concentration of LaCl3 is: 20
# The concentration of CaCl2 is: 22.666666666666668
# Relaxation correction: [-0.16312478 -0.07224798 -0.02166413 -0.11354573]
# Hydrodynamic correction: [-0.42743075 -0.34075412 -0.20186287 -0.12204195]
# omega_bar: 265733144235.7812
# Alpha: [0.0, 176034891114.80185, 304398113444.09814, 368957844616.2178]
# Mew: [0.45       0.22666667 0.03       0.29333333]
# Transport number: [0.25458273 0.16407357 0.03657656 0.54476714]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.55561376 -1.12589109 -0.36641316 -0.32584143]
#  [ 1.21581429  2.01008323 -0.59009879 -0.47746348]
#  [ 0.72183277  0.2750948   4.49426571 -2.55827469]
#  [ 0.47388037  0.14583846  0.55845572  1.13046116]]
# The MAPE is of (12, 20) 11.08606310469123
# The concentration of NaCl is: 12
# The concentration of LaCl3 is: 18
# The concentration of CaCl2 is: 26.666666666666668
# Relaxation correction: [-0.16739777 -0.07535669 -0.02301222 -0.11174287]
# Hydrodynamic correction: [-0.42764755 -0.34092666 -0.20196511 -0.12210431]
# omega_bar: 269129662689.00397
# Alpha: [0.0, 173313391789.84277, 304810380696.53204, 368753236577.5838]
# Mew: [0.405      0.26666667 0.03       0.29833333]
# Transport number: [0.22623282 0.19059164 0.03611495 0.54706058]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.57877966 -1.30070493 -0.3602236  -0.32570774]
#  [ 1.23391996  1.77776781 -0.57959507 -0.47735988]
#  [ 0.73258217  0.27820778  4.5265463  -2.56625526]
#  [ 0.48093731  0.14871904  0.551909    1.12691149]]
# The MAPE is of (12, 18) 11.407938088910186
# The concentration of NaCl is: 12
# The concentration of LaCl3 is: 16
# The concentration of CaCl2 is: 30.666666666666668
# Relaxation correction: [-0.17163572 -0.07843921 -0.02434705 -0.10995838]
# Hydrodynamic correction: [-0.42786435 -0.34109921 -0.20206734 -0.12216668]
# omega_bar: 272526181142.22684
# Alpha: [0.0, 170631475433.66364, 305202751471.76874, 368554872601.86456]
# Mew: [0.36       0.30666667 0.03       0.30333333]
# Transport number: [0.19858957 0.21644872 0.03566485 0.54929686]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.60239466 -1.49540913 -0.35438968 -0.32557964]
#  [ 1.25237664  1.58089708 -0.5697106  -0.47726182]
#  [ 0.74353995  0.27677201  4.5588912  -2.57407665]
#  [ 0.48813105  0.14912864  0.54568616  1.12348768]]
# The MAPE is of (12, 16) 11.478578624895716
# The concentration of NaCl is: 12
# The concentration of LaCl3 is: 14
# The concentration of CaCl2 is: 34.666666666666664
# Relaxation correction: [-0.17583929 -0.08149601 -0.02566889 -0.10819189]
# Hydrodynamic correction: [-0.42808116 -0.34127175 -0.20216957 -0.12222905]
# omega_bar: 275922699595.4496
# Alpha: [0.0, 167986649526.7762, 305576795197.65247, 368362462989.9371]
# Mew: [0.315      0.34666667 0.03       0.30833333]
# Transport number: [0.17162687 0.24166922 0.03522582 0.55147809]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.62648001 -1.71858035 -0.34887768 -0.32545694]
#  [ 1.27120092  1.4072004  -0.56038575 -0.47716911]
#  [ 0.75471599  0.27114601  4.59126808 -2.58174461]
#  [ 0.49546807  0.14720743  0.53975834  1.12018346]]
# The MAPE is of (12, 14) 11.31496477007378
# The concentration of NaCl is: 12
# The concentration of LaCl3 is: 12
# The concentration of CaCl2 is: 38.666666666666664
# Relaxation correction: [-0.18000906 -0.08452757 -0.02697801 -0.10644304]
# Hydrodynamic correction: [-0.42829796 -0.34144429 -0.20227181 -0.12229141]
# omega_bar: 279319218048.6724
# Alpha: [0.0, 165376609550.31805, 305933907798.2273, 368175735954.0002]
# Mew: [0.27       0.38666667 0.03       0.31333333]
# Transport number: [0.1453199  0.26627636 0.03479748 0.55360626]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.65105818 -1.98278339 -0.34365822 -0.32533944]
#  [ 1.29041037  1.24840019 -0.55156867 -0.47708158]
#  [ 0.7661207   0.26142259  4.62365014 -2.58926461]
#  [ 0.50295522  0.14295989  0.53410032  1.11699298]]
# The MAPE is of (12, 12) 10.927118960845139
# The concentration of NaCl is: 20
# The concentration of LaCl3 is: 32
# The concentration of CaCl2 is: -4.0
# The concentration of NaCl is: 20
# The concentration of LaCl3 is: 28
# The concentration of CaCl2 is: 4.0
# Relaxation correction: [-0.14831851 -0.06180606 -0.01727311 -0.11873808]
# Hydrodynamic correction: [-0.42630587 -0.33985906 -0.20133253 -0.12171809]
# omega_bar: 256787481285.45053
# Alpha: [0.0, 189145347387.76035, 291438285118.81244, 374540217686.96216]
# Mew: [0.63 0.04 0.05 0.28]
# Transport number: [0.36883223 0.02996283 0.06308462 0.53812032]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.48963036 -0.40514348 -0.48883898 -0.2985908 ]
#  [ 1.16424393  5.58285167 -0.81332613 -0.43530249]
#  [ 0.69121528  0.16625566  3.27838157 -2.14441575]
#  [ 0.45378011  0.08433407  0.63065186  1.11694675]]
# The MAPE is of (20, 28) 6.513293637668661
# The concentration of NaCl is: 20
# The concentration of LaCl3 is: 24
# The concentration of CaCl2 is: 12.0
# Relaxation correction: [-0.15705565 -0.06816432 -0.02003892 -0.11504077]
# Hydrodynamic correction: [-0.42673948 -0.34020415 -0.201537   -0.12184282]
# omega_bar: 263580518191.89618
# Alpha: [0.0, 182970507096.07812, 293025974563.1712, 374007959193.10187]
# Mew: [0.54 0.12 0.05 0.29]
# Transport number: [0.30799425 0.08757187 0.06145879 0.54297508]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.53373802 -0.76731986 -0.46521539 -0.29875815]
#  [ 1.19871696  3.03290689 -0.77062625 -0.43575283]
#  [ 0.71168203  0.25160843  3.32020453 -2.16275478]
#  [ 0.46721645  0.13042577  0.61269392  1.10950854]]
# The MAPE is of (20, 24) 9.885247535950706
# The concentration of NaCl is: 20
# The concentration of LaCl3 is: 22
# The concentration of CaCl2 is: 16.0
# Relaxation correction: [-0.16136933 -0.07130236 -0.02140095 -0.11322093]
# Hydrodynamic correction: [-0.42695628 -0.34037669 -0.20163923 -0.12190518]
# omega_bar: 266977036645.11896
# Alpha: [0.0, 179987416369.84088, 293746225215.0966, 373753522659.0143]
# Mew: [0.495 0.16  0.05  0.295]
# Transport number: [0.27873625 0.11527703 0.06067691 0.54530982]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.55639385 -0.93222121 -0.45488046 -0.29884198]
#  [ 1.21642398  2.53760446 -0.752036   -0.43597425]
#  [ 0.72219475  0.27114637  3.34206941 -2.17168623]
#  [ 0.47411801  0.14195073  0.60470548  1.10598973]]
# The MAPE is of (20, 22) 10.904769384957405
# The concentration of NaCl is: 20
# The concentration of LaCl3 is: 20
# The concentration of CaCl2 is: 20.0
# Relaxation correction: [-0.16564731 -0.0744137  -0.02274945 -0.1114198 ]
# Hydrodynamic correction: [-0.42717308 -0.34054923 -0.20174146 -0.12196755]
# omega_bar: 270373555098.34186
# Alpha: [0.0, 177065721498.01685, 294424345742.97107, 373506411662.903]
# Mew: [0.45 0.2  0.05 0.3 ]
# Transport number: [0.25021334 0.1422861  0.05991466 0.5475859 ]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.57947576 -1.10188487 -0.44535244 -0.29892598]
#  [ 1.23446401  2.18489808 -0.73494744 -0.43619339]
#  [ 0.73290517  0.28230182  3.36439116 -2.18046614]
#  [ 0.48114936  0.14917829  0.59726176  1.10259559]]
# The MAPE is of (20, 20) 11.590280485795041
# The concentration of NaCl is: 20
# The concentration of LaCl3 is: 18
# The concentration of CaCl2 is: 24.0
# Relaxation correction: [-0.16989024 -0.07749884 -0.02408469 -0.10963698]
# Hydrodynamic correction: [-0.42738988 -0.34072177 -0.2018437  -0.12202992]
# omega_bar: 273770073551.56464
# Alpha: [0.0, 174200308850.50555, 295064552199.85284, 373266300668.01886]
# Mew: [0.405 0.24  0.05  0.305]
# Transport number: [0.22239817 0.168625   0.05917134 0.5498055 ]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.6030036  -1.28329854 -0.4365285  -0.29901018]
#  [ 1.25285256  1.91128913 -0.71916553 -0.43641043]
#  [ 0.74382251  0.28704151  3.38707153 -2.18909951]
#  [ 0.48831655  0.15303096  0.59029571  1.09932001]]
# The MAPE is of (20, 18) 11.98600674927769
# The concentration of NaCl is: 20
# The concentration of LaCl3 is: 16
# The concentration of CaCl2 is: 28.0
# Relaxation correction: [-0.17409875 -0.08055826 -0.02540697 -0.10787211]
# Hydrodynamic correction: [-0.42760669 -0.34089432 -0.20194593 -0.12209228]
# omega_bar: 277166592004.7875
# Alpha: [0.0, 171386682524.14398, 295670457785.21533, 373032883541.3932]
# Mew: [0.36 0.28 0.05 0.31]
# Transport number: [0.19526472 0.19431836 0.05844622 0.5519707 ]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.62699836 -1.48364774 -0.42832354 -0.29909461]
#  [ 1.27160604  1.68588518 -0.70452928 -0.43662548]
#  [ 0.75495651  0.28645851  3.41003237 -2.19759108]
#  [ 0.49562598  0.15400778  0.58375179  1.09615725]]
# The MAPE is of (20, 16) 12.121677168550113
# The concentration of NaCl is: 20
# The concentration of LaCl3 is: 14
# The concentration of CaCl2 is: 32.0
# Relaxation correction: [-0.17827346 -0.08359244 -0.02671653 -0.10612486]
# Hydrodynamic correction: [-0.42782349 -0.34106686 -0.20204816 -0.12215465]
# omega_bar: 280563110458.01025
# Alpha: [0.0, 168620851669.53488, 296245184034.76025, 372805872119.51953]
# Mew: [0.315 0.32  0.05  0.315]
# Transport number: [0.16878822 0.21938963 0.05773867 0.55408347]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.65148227 -1.71193509 -0.42066642 -0.29917929]
#  [ 1.29074183  1.49127769 -0.69090441 -0.43683866]
#  [ 0.76631749  0.2811417   3.43321093 -2.20594534]
#  [ 0.50308441  0.15236066  0.57758346  1.09310195]]
# The MAPE is of (20, 14) 12.017108861586967
# The concentration of NaCl is: 20
# The concentration of LaCl3 is: 12
# The concentration of CaCl2 is: 36.0
# Relaxation correction: [-0.18241494 -0.08660182 -0.02801363 -0.10439486]
# Hydrodynamic correction: [-0.42804029 -0.3412394  -0.2021504  -0.12221701]
# omega_bar: 283959628911.23315
# Alpha: [0.0, 165899242612.03458, 296791447183.7612, 372584994895.70593]
# Mew: [0.27 0.36 0.05 0.32]
# Transport number: [0.14294512 0.24386113 0.05704804 0.55614571]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.6764789  -1.98105314 -0.41349711 -0.29926422]
#  [ 1.31027833  1.3164069  -0.67817787 -0.43705008]
#  [ 0.77791637  0.27132294  3.45655636 -2.21416656]
#  [ 0.51069904  0.14816161  0.57175136  1.09014905]]
# The MAPE is of (20, 12) 11.684290220208151
# The concentration of NaCl is: 25
# The concentration of LaCl3 is: 32
# The concentration of CaCl2 is: -5.666666666666667
# The concentration of NaCl is: 25
# The concentration of LaCl3 is: 28
# The concentration of CaCl2 is: 2.3333333333333335
# Relaxation correction: [-0.14995871 -0.06320911 -0.01797806 -0.11736914]
# Hydrodynamic correction: [-0.42614483 -0.339731   -0.20125665 -0.12167159]
# omega_bar: 259687738074.5509
# Alpha: [0.0, 190387472463.07965, 285006299827.68604, 376896601035.41895]
# Mew: [0.63       0.02333333 0.0625     0.28416667]
# Transport number: [0.36471302 0.01728312 0.07797509 0.54002877]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.50384885 -0.32067983 -0.54372984 -0.28608179]
#  [ 1.17535662  7.44680137 -0.92216992 -0.41620604]
#  [ 0.69781292  0.13723869  2.89395465 -1.98591462]
#  [ 0.45811144  0.06929797  0.64467425  1.10520586]]
# The MAPE is of (25, 28) 6.253785940556062
# The concentration of NaCl is: 25
# The concentration of LaCl3 is: 24
# The concentration of CaCl2 is: 10.333333333333334
# Relaxation correction: [-0.15865614 -0.06953622 -0.02072683 -0.11369825]
# Hydrodynamic correction: [-0.42657843 -0.34007609 -0.20146112 -0.12179632]
# omega_bar: 266480774980.99652
# Alpha: [0.0, 183909736012.6966, 286991988842.19324, 376335237797.7898]
# Mew: [0.54       0.10333333 0.0625     0.29416667]
# Transport number: [0.30464218 0.07458839 0.07598738 0.54478205]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.54835257 -0.7343782  -0.51360783 -0.28642543]
#  [ 1.21013919  3.31951493 -0.86572658 -0.41690898]
#  [ 0.71846345  0.24963847  2.92661941 -2.0041132 ]
#  [ 0.47166842  0.12899245  0.62513177  1.09804216]]
# The MAPE is of (25, 24) 9.918893710272968
# The concentration of NaCl is: 25
# The concentration of LaCl3 is: 22
# The concentration of CaCl2 is: 14.333333333333334
# Relaxation correction: [-0.16295058 -0.07265917 -0.02208062 -0.11189122]
# Hydrodynamic correction: [-0.42679524 -0.34024863 -0.20156335 -0.12185868]
# omega_bar: 269877293434.21936
# Alpha: [0.0, 180800762940.86307, 287883812114.21735, 376066348758.68665]
# Mew: [0.495      0.14333333 0.0625     0.29916667]
# Transport number: [0.27574079 0.10215921 0.07503105 0.54706895]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.57122095 -0.90830092 -0.50071183 -0.28659424]
#  [ 1.22801233  2.71993396 -0.84171704 -0.41725246]
#  [ 0.72907479  0.27320868  2.94439731 -2.01299467]
#  [ 0.47863473  0.14265029  0.61662495  1.09464903]]
# The MAPE is of (25, 22) 11.0175289932182
# The concentration of NaCl is: 25
# The concentration of LaCl3 is: 20
# The concentration of CaCl2 is: 18.333333333333332
# Relaxation correction: [-0.16720971 -0.07575573 -0.02342107 -0.11010263]
# Hydrodynamic correction: [-0.42701204 -0.34042118 -0.20166558 -0.12192105]
# omega_bar: 273273811887.4422
# Alpha: [0.0, 177766527790.82132, 288718962128.41797, 375804865378.1013]
# Mew: [0.45       0.18333333 0.0625     0.30416667]
# Transport number: [0.24755782 0.12904468 0.07409849 0.54929901]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.59452577 -1.08426596 -0.48896136 -0.28676122]
#  [ 1.24622658  2.31290181 -0.81992451 -0.41759098]
#  [ 0.73988864  0.28664939  2.9628581  -2.02173713]
#  [ 0.48573398  0.15114113  0.60878951  1.09137358]]
# The MAPE is of (25, 20) 11.76535697201471
# The concentration of NaCl is: 25
# The concentration of LaCl3 is: 18
# The concentration of CaCl2 is: 22.333333333333332
# Relaxation correction: [-0.17143417 -0.07882639 -0.02474845 -0.10833209]
# Hydrodynamic correction: [-0.42722884 -0.34059372 -0.20176782 -0.12198342]
# omega_bar: 276670330340.66504
# Alpha: [0.0, 174799864744.25452, 289503735352.55786, 375550470628.10583]
# Mew: [0.405      0.22333333 0.0625     0.30916667]
# Transport number: [0.22006683 0.15527003 0.07318882 0.55147431]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.61828744 -1.2705221  -0.47819107 -0.28692646]
#  [ 1.26479789  2.0064851  -0.80002215 -0.41792478]
#  [ 0.75091449  0.29268226  2.98185384 -2.03034494]
#  [ 0.4929724   0.15575354  0.60153035  1.08821017]]
# The MAPE is of (25, 18) 12.213074799394333
# The concentration of NaCl is: 25
# The concentration of LaCl3 is: 16
# The concentration of CaCl2 is: 26.333333333333332
# Relaxation correction: [-0.17562458 -0.08187162 -0.02606303 -0.10657927]
# Hydrodynamic correction: [-0.42744564 -0.34076626 -0.20187005 -0.12204578]
# omega_bar: 280066848793.8879
# Alpha: [0.0, 171894628458.80167, 290243421288.0319, 375302865749.3243]
# Mew: [0.36       0.26333333 0.0625     0.31416667]
# Transport number: [0.19324264 0.18085929 0.07230122 0.55359685]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.64252757 -1.47487261 -0.46826779 -0.28709007]
#  [ 1.28374314  1.75928909 -0.78174755 -0.4182541 ]
#  [ 0.76216234  0.29277116  3.00127007 -2.03882222]
#  [ 0.50035658  0.15716651  0.59477097  1.08515351]]
# The MAPE is of (25, 16) 12.393973358292872
# The concentration of NaCl is: 25
# The concentration of LaCl3 is: 14
# The concentration of CaCl2 is: 30.333333333333332
# Relaxation correction: [-0.17978154 -0.08489189 -0.02736506 -0.10484381]
# Hydrodynamic correction: [-0.42766245 -0.34093881 -0.20197228 -0.12210815]
# omega_bar: 283463367247.11066
# Alpha: [0.0, 169045484788.59543, 290942510251.7402, 375061768935.2916]
# Mew: [0.315      0.30333333 0.0625     0.31916667]
# Transport number: [0.16706127 0.20583531 0.0714349  0.55566852]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.66726903 -1.70668426 -0.45908279 -0.28725213]
#  [ 1.30308022  1.54918495 -0.76488714 -0.41857912]
#  [ 0.77364283  0.28770909  3.02101705 -2.04717289]
#  [ 0.50789347  0.15573145  0.58844891  1.08219863]]
# The MAPE is of (25, 14) 12.330059752016341
# The concentration of NaCl is: 25
# The concentration of LaCl3 is: 12
# The concentration of CaCl2 is: 34.333333333333336
# Relaxation correction: [-0.18390563 -0.08788764 -0.0286548  -0.10312538]
# Hydrodynamic correction: [-0.42787925 -0.34111135 -0.20207451 -0.12217051]
# omega_bar: 286859885700.3335
# Alpha: [0.0, 166247753239.46054, 291604849408.40466, 374826914139.0835]
# Mew: [0.27       0.34333333 0.0625     0.32416667]
# Transport number: [0.14149989 0.23021989 0.07058908 0.55769114]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.69253611 -1.97910759 -0.45054626 -0.28741273]
#  [ 1.3228281   1.36268997 -0.74926497 -0.41890004]
#  [ 0.78536721  0.27784689  3.04102354 -2.0554007 ]
#  [ 0.51559048  0.15157859  0.58251258  1.07934086]]
# The MAPE is of (25, 12) 12.034790860655656
# The concentration of NaCl is: 30
# The concentration of LaCl3 is: 32
# The concentration of CaCl2 is: -7.333333333333333
# The concentration of NaCl is: 30
# The concentration of LaCl3 is: 28
# The concentration of CaCl2 is: 0.6666666666666666
# The concentration of NaCl is: 30
# The concentration of LaCl3 is: 24
# The concentration of CaCl2 is: 8.666666666666666
# Relaxation correction: [-0.16024543 -0.07089899 -0.02140943 -0.11236483]
# Hydrodynamic correction: [-0.42641739 -0.33994803 -0.20138524 -0.12174982]
# omega_bar: 269381031770.097
# Alpha: [0.0, 184929445716.02753, 281204906445.8864, 378367104574.05054]
# Mew: [0.54       0.08666667 0.075      0.29833333]
# Transport number: [0.30136229 0.06188448 0.09020313 0.5465501 ]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.56306452 -0.69531092 -0.56151987 -0.27628372]
#  [ 1.22163755  3.6845213  -0.96430613 -0.40144445]
#  [ 0.72529006  0.24557817  2.63958879 -1.87944326]
#  [ 0.47615007  0.12645036  0.63293217  1.08919544]]
# The MAPE is of (30, 24) 9.843027532895903
# The concentration of NaCl is: 30
# The concentration of LaCl3 is: 22
# The concentration of CaCl2 is: 12.666666666666666
# Relaxation correction: [-0.16452087 -0.07400705 -0.02275513 -0.11057041]
# Hydrodynamic correction: [-0.42663419 -0.34012058 -0.20148747 -0.12181218]
# omega_bar: 272777550223.31976
# Alpha: [0.0, 181677754490.92004, 282280305325.07446, 378087568970.2134]
# Mew: [0.495      0.12666667 0.075      0.30333333]
# Transport number: [0.27280902 0.08932035 0.08907995 0.54879068]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.58615092 -0.88070697 -0.54551637 -0.27651452]
#  [ 1.23968109  2.93701351 -0.93343221 -0.40187557]
#  [ 0.73600256  0.27446346  2.65399008 -1.88816766]
#  [ 0.48318279  0.14289059  0.62378932  1.08590605]]
# The MAPE is of (30, 22) 11.031502443249247
# The concentration of NaCl is: 30
# The concentration of LaCl3 is: 20
# The concentration of CaCl2 is: 16.666666666666668
# Relaxation correction: [-0.1687614  -0.07708903 -0.02408765 -0.10879417]
# Hydrodynamic correction: [-0.426851   -0.34029312 -0.2015897  -0.12187455]
# omega_bar: 276174068676.54266
# Alpha: [0.0, 178517702477.6091, 283281042738.92377, 377815441323.5223]
# Mew: [0.45       0.16666667 0.075      0.30833333]
# Transport number: [0.24495808 0.11608137 0.08798441 0.55097614]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.60968439 -1.06421983 -0.53112827 -0.2767421 ]
#  [ 1.25807404  2.45958415 -0.90581275 -0.40229994]
#  [ 0.74692252  0.29077683  2.6693618  -1.896764  ]
#  [ 0.49035169  0.15295125  0.61548446  1.08272833]]
# The MAPE is of (30, 20) 11.848329466784188
# The concentration of NaCl is: 30
# The concentration of LaCl3 is: 18
# The concentration of CaCl2 is: 20.666666666666668
# Relaxation correction: [-0.17296762 -0.0801454  -0.02540728 -0.10703574]
# Hydrodynamic correction: [-0.4270678  -0.34046566 -0.20169193 -0.12193692]
# omega_bar: 279570587129.7655
# Alpha: [0.0, 175439199777.51495, 284216363643.4522, 377550414738.596]
# Mew: [0.405      0.20666667 0.075      0.31333333]
# Transport number: [0.21778387 0.14219216 0.08691548 0.5531085 ]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.63368593 -1.25604503 -0.51809173 -0.27696662]
#  [ 1.27683282  2.11287985 -0.88090389 -0.40271783]
#  [ 0.75805967  0.29839068  2.68548216 -1.90523613]
#  [ 0.49766319  0.1584801   0.60788125  1.07965705]]
# The MAPE is of (30, 18) 12.35270444668305
# The concentration of NaCl is: 30
# The concentration of LaCl3 is: 16
# The concentration of CaCl2 is: 24.666666666666668
# Relaxation correction: [-0.17714016 -0.08317663 -0.02671427 -0.10529479]
# Hydrodynamic correction: [-0.4272846  -0.34063821 -0.20179417 -0.12199928]
# omega_bar: 282967105582.9883
# Alpha: [0.0, 172433824702.81726, 285093857012.71814, 377292199478.55066]
# Mew: [0.36       0.24666667 0.075      0.31833333]
# Transport number: [0.19126201 0.16767611 0.08587221 0.55518967]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.65817778 -1.46485629 -0.50620072 -0.27718821]
#  [ 1.2959748   1.83988194 -0.85828257 -0.40312955]
#  [ 0.76942432  0.29929096  2.70218503 -1.91358771]
#  [ 0.50512404  0.16041015  0.60087356  1.07668729]]
# The MAPE is of (30, 16) 12.582331657961578
# The concentration of NaCl is: 30
# The concentration of LaCl3 is: 14
# The concentration of CaCl2 is: 28.666666666666668
# Relaxation correction: [-0.1812796  -0.08618317 -0.02800888 -0.10357096]
# Hydrodynamic correction: [-0.4275014  -0.34081075 -0.2018964  -0.12206165]
# omega_bar: 286363624036.2111
# Alpha: [0.0, 169494440259.80475, 285919837855.78265, 377040521769.83325]
# Mew: [0.315      0.28666667 0.075      0.32333333]
# Transport number: [0.16536929 0.19255555 0.08485369 0.55722147]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.6831835  -1.70049904 -0.49529151 -0.277407  ]
#  [ 1.31551841  1.61191822 -0.83761375 -0.40353533]
#  [ 0.78102742  0.29454385  2.71934374 -1.9218222 ]
#  [ 0.51274143  0.15922635  0.59437728  1.07381443]]
# The MAPE is of (30, 14) 12.561830152119416
# The concentration of NaCl is: 30
# The concentration of LaCl3 is: 12
# The concentration of CaCl2 is: 32.666666666666664
# Relaxation correction: [-0.18538651 -0.08916546 -0.02929135 -0.10186394]
# Hydrodynamic correction: [-0.42771821 -0.34098329 -0.20199863 -0.12212401]
# omega_bar: 289760142489.43396
# Alpha: [0.0, 166614916518.8761, 286699623327.4803, 376795122703.55536]
# Mew: [0.27       0.32666667 0.075      0.32833333]
# Transport number: [0.14008359 0.21685172 0.08385905 0.55920564]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.70872811 -1.97644082 -0.48523195 -0.27762312]
#  [ 1.3354832   1.4123084  -0.81862804 -0.40393542]
#  [ 0.79288058  0.28465417  2.73686019 -1.92994292]
#  [ 0.52052298  0.15513467  0.58832468  1.07103411]]
# The MAPE is of (30, 12) 12.306358112453891
# The concentration of NaCl is: 35
# The concentration of LaCl3 is: 32
# The concentration of CaCl2 is: -9.0
# The concentration of NaCl is: 35
# The concentration of LaCl3 is: 28
# The concentration of CaCl2 is: -1.0
# The concentration of NaCl is: 35
# The concentration of LaCl3 is: 24
# The concentration of CaCl2 is: 7.0
# Relaxation correction: [-0.16182367 -0.07225278 -0.02208684 -0.11104035]
# Hydrodynamic correction: [-0.42625635 -0.33981998 -0.20130935 -0.12170332]
# omega_bar: 272281288559.1974
# Alpha: [0.0, 186044142152.89847, 275583116776.5855, 380169723907.69916]
# Mew: [0.54   0.07   0.0875 0.3025]
# Transport number: [0.29815227 0.04945121 0.10411603 0.54828049]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.57787684 -0.64793823 -0.61057712 -0.2677073 ]
#  [ 1.23321435  4.17196645 -1.07003811 -0.38839205]
#  [ 0.73216324  0.23839896  2.41870493 -1.77809968]
#  [ 0.48066229  0.12227796  0.63794259  1.08209292]]
# The MAPE is of (35, 24) 9.662629960861134
# The concentration of NaCl is: 35
# The concentration of LaCl3 is: 22
# The concentration of CaCl2 is: 11.0
# Relaxation correction: [-0.16608037 -0.07534615 -0.02342454 -0.10925836]
# Hydrodynamic correction: [-0.42647315 -0.33999252 -0.20141159 -0.12176569]
# omega_bar: 275677807012.4202
# Alpha: [0.0, 182628544720.05783, 276859592403.8983, 379882236283.216]
# Mew: [0.495  0.11   0.0875 0.3075]
# Transport number: [0.26993895 0.07675162 0.10283326 0.55047617]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.60118686 -0.8485123  -0.59072233 -0.26798507]
#  [ 1.25143266  3.20160265 -1.0302732  -0.38888853]
#  [ 0.74297951  0.27455383  2.43003329 -1.78662264]
#  [ 0.48776312  0.14248403  0.627999    1.07889376]]
# The MAPE is of (35, 22) 10.954185900061045
# The concentration of NaCl is: 35
# The concentration of LaCl3 is: 20
# The concentration of CaCl2 is: 15.0
# Relaxation correction: [-0.17030252 -0.07841374 -0.02474926 -0.1074943 ]
# Hydrodynamic correction: [-0.42668995 -0.34016506 -0.20151382 -0.12182805]
# omega_bar: 279074325465.643
# Alpha: [0.0, 179326411547.82025, 278038578107.7583, 379602109780.1984]
# Mew: [0.45   0.15   0.0875 0.3125]
# Transport number: [0.24241238 0.10338751 0.10158171 0.55261841]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.62495487 -1.04127829 -0.57314958 -0.26825864]
#  [ 1.27000892  2.63005404 -0.99530254 -0.389377  ]
#  [ 0.75400829  0.29455862  2.44271915 -1.79502702]
#  [ 0.49500348  0.15453838  0.61911926  1.07580097]]
# The MAPE is of (35, 20) 11.847619681060145
# The concentration of NaCl is: 35
# The concentration of LaCl3 is: 18
# The concentration of CaCl2 is: 19.0
# Relaxation correction: [-0.17449075 -0.081456   -0.02606125 -0.10574781]
# Hydrodynamic correction: [-0.42690676 -0.34033761 -0.20161605 -0.12189042]
# omega_bar: 282470843918.8659
# Alpha: [0.0, 176123392949.86118, 279133600265.4428, 379329048325.10077]
# Mew: [0.405  0.19   0.0875 0.3175]
# Transport number: [0.21554778 0.12938283 0.10036026 0.55470913]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.64920247 -1.23960919 -0.55743656 -0.26852819]
#  [ 1.28896001  2.23290825 -0.96421691 -0.3898578 ]
#  [ 0.76525962  0.30413372  2.4564272  -1.80331624]
#  [ 0.50238993  0.16118883  0.61110437  1.07280966]]
# The MAPE is of (35, 18) 12.413688830072251
# The concentration of NaCl is: 35
# The concentration of LaCl3 is: 16
# The concentration of CaCl2 is: 23.0
# Relaxation correction: [-0.17864563 -0.0844734  -0.02736077 -0.10401856]
# Hydrodynamic correction: [-0.42712356 -0.34051015 -0.20171829 -0.12195278]
# omega_bar: 285867362372.08875
# Alpha: [0.0, 173007871553.61713, 280155463939.1994, 379062771953.95593]
# Mew: [0.36   0.23   0.0875 0.3225]
# Transport number: [0.18932156 0.15476044 0.09916783 0.55675017]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.67395255 -1.45344907 -0.54326512 -0.26879388]
#  [ 1.30830382  1.92895308 -0.93633452 -0.39033123]
#  [ 0.7767441   0.30602296  2.47091578 -1.81149357]
#  [ 0.50992944  0.16373782  0.60380544  1.06991525]]
# The MAPE is of (35, 16) 12.695676616325786
# The concentration of NaCl is: 35
# The concentration of LaCl3 is: 14
# The concentration of CaCl2 is: 27.0
# Relaxation correction: [-0.18276776 -0.08746638 -0.02864807 -0.10230621]
# Hydrodynamic correction: [-0.42734036 -0.34068269 -0.20182052 -0.12201515]
# omega_bar: 289263880825.3115
# Alpha: [0.0, 169970258473.3158, 281112955204.96875, 378803015716.70844]
# Mew: [0.315  0.27   0.0875 0.3275]
# Transport number: [0.16371124 0.17954208 0.09800341 0.55874327]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.6992294  -1.69328993 -0.53039003 -0.26905589]
#  [ 1.32805934  1.68020799 -0.91113213 -0.39079759]
#  [ 0.78847301  0.30166561  2.48600654 -1.81956213]
#  [ 0.51762943  0.16285322  0.59710828  1.06711341]]
# The MAPE is of (35, 14) 12.721358038839286
# The concentration of NaCl is: 35
# The concentration of LaCl3 is: 12
# The concentration of CaCl2 is: 31.0
# Relaxation correction: [-0.18685769 -0.09043538 -0.02992337 -0.10061044]
# Hydrodynamic correction: [-0.42755716 -0.34085524 -0.20192275 -0.12207751]
# omega_bar: 292660399278.53436
# Alpha: [0.0, 167002506042.20786, 282013326891.9556, 378549528672.04987]
# Mew: [0.27   0.31   0.0875 0.3325]
# Transport number: [0.13869537 0.2037485  0.09686601 0.56069012]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.72505882 -1.97299842 -0.51861849 -0.26931435]
#  [ 1.34824673  1.46569459 -0.88820017 -0.39125714]
#  [ 0.80045833  0.29176829  2.50156525 -1.8275249 ]
#  [ 0.52549774  0.15884068  0.59092357  1.06440005]]
# The MAPE is of (35, 12) 12.507880766747075
# The concentration of NaCl is: 40
# The concentration of LaCl3 is: 32
# The concentration of CaCl2 is: -10.666666666666666
# The concentration of NaCl is: 40
# The concentration of LaCl3 is: 28
# The concentration of CaCl2 is: -2.6666666666666665
# The concentration of NaCl is: 40
# The concentration of LaCl3 is: 24
# The concentration of CaCl2 is: 5.333333333333333
# Relaxation correction: [-0.16339104 -0.07359772 -0.02275911 -0.10972469]
# Hydrodynamic correction: [-0.42609531 -0.33969192 -0.20123347 -0.12165682]
# omega_bar: 275181545348.29785
# Alpha: [0.0, 187272882411.60233, 270061259665.1941, 381788490641.30786]
# Mew: [0.54       0.05333333 0.1        0.30666667]
# Transport number: [0.29500991 0.03728002 0.11773566 0.54997441]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.59279257 -0.58860113 -0.6622077  -0.26030383]
#  [ 1.24487197  4.87068966 -1.18678511 -0.37714527]
#  [ 0.73908441  0.22631277  2.24227872 -1.69361332]
#  [ 0.48520601  0.11557571  0.64128095  1.07621678]]
# The MAPE is of (40, 24) 9.378103062413198
# The concentration of NaCl is: 40
# The concentration of LaCl3 is: 22
# The concentration of CaCl2 is: 9.333333333333334
# Relaxation correction: [-0.16762923 -0.07667659 -0.02408896 -0.10795495]
# Hydrodynamic correction: [-0.42631211 -0.33986446 -0.20133571 -0.12171919]
# omega_bar: 278578063801.5206
# Alpha: [0.0, 183666044523.2655, 271563197769.58813, 381495039910.45245]
# Mew: [0.495      0.09333333 0.1        0.31166667]
# Transport number: [0.26712863 0.0644446  0.11630019 0.55212658]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.61633194 -0.81037175 -0.63746507 -0.26061813]
#  [ 1.26326953  3.53412032 -1.1352074  -0.37769175]
#  [ 0.7500071   0.27292862  2.2505354  -1.70191892]
#  [ 0.49237671  0.14114415  0.63030276  1.0730987 ]]
# The MAPE is of (40, 22) 10.790068461888525
# The concentration of NaCl is: 40
# The concentration of LaCl3 is: 20
# The concentration of CaCl2 is: 13.333333333333334
# Relaxation correction: [-0.17183325 -0.07972997 -0.02540598 -0.10620289]
# Hydrodynamic correction: [-0.42652891 -0.34003701 -0.20143794 -0.12178155]
# omega_bar: 281974582254.74347
# Alpha: [0.0, 180201521217.44305, 272937856847.4078, 381208871367.2971]
# Mew: [0.45       0.13333333 0.1        0.31666667]
# Transport number: [0.23991904 0.09095477 0.1148993  0.5542269 ]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.64034051 -1.01481301 -0.61597659 -0.26092751]
#  [ 1.2820338   2.83161013 -1.09077585 -0.37822935]
#  [ 0.76114751  0.29780955  2.26069613 -1.71011412]
#  [ 0.49969034  0.15580069  0.62070516  1.07008223]]
# The MAPE is of (40, 20) 11.76911448151337
# The concentration of NaCl is: 40
# The concentration of LaCl3 is: 18
# The concentration of CaCl2 is: 17.333333333333332
# Relaxation correction: [-0.17600369 -0.08275831 -0.02671045 -0.10446817]
# Hydrodynamic correction: [-0.42674571 -0.34020955 -0.20154017 -0.12184392]
# omega_bar: 285371100707.96625
# Alpha: [0.0, 176858584164.50958, 274205161372.4913, 380929699952.53265]
# Mew: [0.405      0.17333333 0.1        0.32166667]
# Transport number: [0.21335714 0.11683388 0.11353175 0.55627723]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.66484051 -1.22088622 -0.5970574  -0.26123218]
#  [ 1.30118216  2.36981755 -1.05194731 -0.37875843]
#  [ 0.77251595  0.30986103  2.27224458 -1.71820204]
#  [ 0.50715368  0.163848    0.61219064  1.06716279]]
# The MAPE is of (40, 18) 12.402496701664706
# The concentration of NaCl is: 40
# The concentration of LaCl3 is: 16
# The concentration of CaCl2 is: 21.333333333333332
# Relaxation correction: [-0.18014114 -0.08576206 -0.0280026  -0.10275046]
# Hydrodynamic correction: [-0.42696252 -0.34038209 -0.20164241 -0.12190628]
# omega_bar: 288767619161.1891
# Alpha: [0.0, 173621035414.9269, 275380515252.3503, 380657255734.6425]
# Mew: [0.36       0.21333333 0.1        0.32666667]
# Transport number: [0.1874201  0.1421042  0.11219638 0.55827932]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.68985552 -1.44046825 -0.58021323 -0.26153232]
#  [ 1.32073304  2.02814261 -1.01761418 -0.3792793 ]
#  [ 0.78412337  0.31296945  2.28482547 -1.72618562]
#  [ 0.5147739   0.16714653  0.60454666  1.06433607]]
# The MAPE is of (40, 16) 12.7407297018503
# The concentration of NaCl is: 40
# The concentration of LaCl3 is: 14
# The concentration of CaCl2 is: 25.333333333333332
# Relaxation correction: [-0.18424617 -0.08874165 -0.02928268 -0.10104942]
# Hydrodynamic correction: [-0.42717932 -0.34055464 -0.20174464 -0.12196865]
# omega_bar: 292164137614.4119
# Alpha: [0.0, 170475898184.59647, 276476109528.8478, 380391282903.5411]
# Mew: [0.315      0.25333333 0.1        0.33166667]
# Transport number: [0.16208611 0.16678697 0.11089205 0.56023486]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.71541058 -1.68495143 -0.56507636 -0.26182811]
#  [ 1.340706    1.75495119 -0.98695682 -0.37979229]
#  [ 0.79598137  0.30909596  2.29818651 -1.73406768]
#  [ 0.52255864  0.16662052  0.59761647  1.061598  ]]
# The MAPE is of (40, 14) 12.815461873891557
# The concentration of NaCl is: 40
# The concentration of LaCl3 is: 12
# The concentration of CaCl2 is: 29.333333333333332
# Relaxation correction: [-0.18831933 -0.09169751 -0.03055093 -0.09936475]
# Hydrodynamic correction: [-0.42739612 -0.34072718 -0.20184687 -0.12203102]
# omega_bar: 295560656067.63477
# Alpha: [0.0, 167412556429.81287, 277501781274.14825, 380131538845.7282]
# Mew: [0.27       0.29333333 0.1        0.33666667]
# Transport number: [0.13733439 0.19090244 0.10961771 0.56214546]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.74153229 -1.96871818 -0.55136622 -0.26211972]
#  [ 1.36112183  1.52336482 -0.95935309 -0.38029767]
#  [ 0.80810231  0.29921585  2.31214394 -1.74185091]
#  [ 0.53051599  0.16270884  0.59128136  1.05894475]]
# The MAPE is of (40, 12) 12.646192994097467
# The concentration of NaCl is: 50
# The concentration of LaCl3 is: 32
# The concentration of CaCl2 is: -14.0
# The concentration of NaCl is: 50
# The concentration of LaCl3 is: 28
# The concentration of CaCl2 is: -6.0
# The concentration of NaCl is: 50
# The concentration of LaCl3 is: 24
# The concentration of CaCl2 is: 2.0
# Relaxation correction: [-0.16649378 -0.07626156 -0.02408863 -0.10711928]
# Hydrodynamic correction: [-0.42577322 -0.33943581 -0.20108171 -0.12156382]
# omega_bar: 280982058926.49866
# Alpha: [0.0, 190186527106.19025, 259077293338.89725, 384597001280.7193]
# Mew: [0.54  0.02  0.125 0.315]
# Transport number: [0.28891981 0.01369141 0.14413145 0.55325733]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.62294665 -0.39666892 -0.77996102 -0.24804572]
#  [ 1.26843937  8.31417166 -1.47497426 -0.3585696 ]
#  [ 0.75307645  0.16862014  1.97729123 -1.55976712]
#  [ 0.49439172  0.0852072   0.64608582  1.06694276]]
# The MAPE is of (50, 24) 8.465098867715364
# The concentration of NaCl is: 50
# The concentration of LaCl3 is: 22
# The concentration of CaCl2 is: 6.0
# Relaxation correction: [-0.17069565 -0.079312   -0.02540309 -0.10537353]
# Hydrodynamic correction: [-0.42599002 -0.33960835 -0.20118394 -0.12162619]
# omega_bar: 284378577379.72144
# Alpha: [0.0, 186074177147.7594, 261146225959.10074, 384295830039.7726]
# Mew: [0.495 0.06  0.125 0.32 ]
# Transport number: [0.26167997 0.04058365 0.14241    0.55532639]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.64696248 -0.70668493 -0.74017848 -0.2484122 ]
#  [ 1.28720931  4.57588732 -1.38412436 -0.35918569]
#  [ 0.76422022  0.2602972   1.97805565 -1.56763761]
#  [ 0.50170757  0.13349578  0.63180891  1.06396837]]
# The MAPE is of (50, 22) 10.205828385732236
# The concentration of NaCl is: 50
# The concentration of LaCl3 is: 20
# The concentration of CaCl2 is: 10.0
# Relaxation correction: [-0.17486407 -0.0823375  -0.02670506 -0.10364498]
# Hydrodynamic correction: [-0.42620683 -0.33978089 -0.20128618 -0.12168855]
# omega_bar: 287775095832.9443
# Alpha: [0.0, 182198857995.3898, 262991433260.22766, 384001726282.6323]
# Mew: [0.45  0.1   0.125 0.325]
# Transport number: [0.23508313 0.06684108 0.14072918 0.55734661]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.67147086 -0.94744219 -0.70743547 -0.24877285]
#  [ 1.30636422  3.37755001 -1.31033464 -0.35979187]
#  [ 0.77559255  0.30143534  1.98280601 -1.57541116]
#  [ 0.50917345  0.1566602   0.62008823  1.06108727]]
# The MAPE is of (50, 20) 11.39268763121357
# The concentration of NaCl is: 50
# The concentration of LaCl3 is: 18
# The concentration of CaCl2 is: 14.0
# Relaxation correction: [-0.1789996  -0.08533851 -0.0279948  -0.10193331]
# Hydrodynamic correction: [-0.42642363 -0.33995344 -0.20138841 -0.12175092]
# omega_bar: 291171614286.1671
# Alpha: [0.0, 178513935968.2584, 264658778831.28534, 383714426569.68414]
# Mew: [0.405 0.14  0.125 0.33 ]
# Transport number: [0.2091068  0.09248593 0.13908757 0.5593197 ]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.69649538 -1.17472788 -0.67977827 -0.24912789]
#  [ 1.32592252  2.71388087 -1.24874141 -0.36038849]
#  [ 0.78720438  0.32091847  1.99019111 -1.58309036]
#  [ 0.51679657  0.16880806  0.61018214  1.05829539]]
# The MAPE is of (50, 18) 12.181302135857885
# The concentration of NaCl is: 50
# The concentration of LaCl3 is: 16
# The concentration of CaCl2 is: 18.0
# Relaxation correction: [-0.18310282 -0.08831546 -0.02927253 -0.10023819]
# Hydrodynamic correction: [-0.42664043 -0.34012598 -0.20149064 -0.12181328]
# omega_bar: 294568132739.3899
# Alpha: [0.0, 174986256859.8049, 266180654284.71832, 383433680819.73254]
# Mew: [0.36  0.18  0.125 0.335]
# Transport number: [0.1837295  0.11753939 0.13748382 0.56124729]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.72206107 -1.40882061 -0.65595363 -0.24947754]
#  [ 1.34590379  2.26605694 -1.19624893 -0.3609759 ]
#  [ 0.79906732  0.32748831  1.99939255 -1.59067767]
#  [ 0.52458455  0.17417651  0.60162401  1.05558891]]
# The MAPE is of (50, 16) 12.645378819312523
# The concentration of NaCl is: 50
# The concentration of LaCl3 is: 14
# The concentration of CaCl2 is: 22.0
# Relaxation correction: [-0.18717426 -0.09126877 -0.03053849 -0.09855933]
# Hydrodynamic correction: [-0.42685723 -0.34029852 -0.20159288 -0.12187565]
# omega_bar: 297964651192.6128
# Alpha: [0.0, 171591196388.40176, 267580927290.05347, 383159251460.6761]
# Mew: [0.315 0.22  0.125 0.34 ]
# Transport number: [0.15893076 0.14202167 0.13591663 0.56313093]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.74819456 -1.66435744 -0.63511193 -0.24982198]
#  [ 1.36632883  1.92855413 -1.15077439 -0.36155442]
#  [ 0.81119373  0.3249792   2.0098855  -1.59817546]
#  [ 0.53254549  0.1746126   0.59410276  1.0529642 ]]
# The MAPE is of (50, 14) 12.827614669014181
# The concentration of NaCl is: 50
# The concentration of LaCl3 is: 12
# The concentration of CaCl2 is: 26.0
# Relaxation correction: [-0.19121447 -0.09419884 -0.0317929  -0.09689642]
# Hydrodynamic correction: [-0.42707404 -0.34047107 -0.20169511 -0.12193802]
# omega_bar: 301361169645.8356
# Alpha: [0.0, 168309826400.00223, 268877773819.70633, 382890912642.81995]
# Mew: [0.27  0.26  0.125 0.345]
# Transport number: [0.13469102 0.1659521  0.13438477 0.56497212]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.77492417 -1.95734615 -0.61665201 -0.2501614 ]
#  [ 1.38721977  1.65418381 -1.11085483 -0.36212437]
#  [ 0.82359675  0.31523678  2.02131819 -1.60558597]
#  [ 0.54068802  0.17098862  0.58740152  1.05041785]]
# The MAPE is of (50, 12) 12.753751177861698
# The concentration of NaCl is: 70
# The concentration of LaCl3 is: 32
# The concentration of CaCl2 is: -20.666666666666668
# The concentration of NaCl is: 70
# The concentration of LaCl3 is: 28
# The concentration of CaCl2 is: -12.666666666666666
# The concentration of NaCl is: 70
# The concentration of LaCl3 is: 24
# The concentration of CaCl2 is: -4.666666666666667
# The concentration of NaCl is: 70
# The concentration of LaCl3 is: 22
# The concentration of CaCl2 is: -0.6666666666666666
# The concentration of NaCl is: 70
# The concentration of LaCl3 is: 20
# The concentration of CaCl2 is: 3.3333333333333335
# Relaxation correction: [-0.18080717 -0.08745604 -0.02924783 -0.09862551]
# Hydrodynamic correction: [-0.42556266 -0.33926867 -0.20098265 -0.12150255]
# omega_bar: 299376122989.34595
# Alpha: [0.0, 187812406586.75552, 242962114370.9035, 388409589464.1183]
# Mew: [0.45       0.03333333 0.175      0.34166667]
# Transport number: [0.2259735  0.02141698 0.18938615 0.56322336]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.7352676  -0.67914527 -0.94847624 -0.23086479]
#  [ 1.35622556  6.38083908 -2.00667578 -0.33274069]
#  [ 0.80519539  0.26613439  1.62101339 -1.39045514]
#  [ 0.5286076   0.13565039  0.6147107   1.04871267]]
# The MAPE is of (70, 20) 9.752411596700234
# The concentration of NaCl is: 70
# The concentration of LaCl3 is: 18
# The concentration of CaCl2 is: 7.333333333333333
# Relaxation correction: [-0.18487537 -0.09040439 -0.03050932 -0.09695808]
# Hydrodynamic correction: [-0.42577946 -0.33944121 -0.20108489 -0.12156492]
# omega_bar: 302772641442.5687
# Alpha: [0.0, 182944060098.51358, 245909481453.5557, 388115920063.5603]
# Mew: [0.405      0.07333333 0.175      0.34666667]
# Transport number: [0.20109467 0.0465888  0.18726161 0.56505493]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.76142515 -1.02058387 -0.88038855 -0.23127541]
#  [ 1.37666941  4.01932211 -1.81743189 -0.33340761]
#  [ 0.81733296  0.33431212  1.61481019 -1.39739511]
#  [ 0.53657587  0.17331219  0.597819    1.04613628]]
# The MAPE is of (70, 18) 10.997120638268491
# The concentration of NaCl is: 70
# The concentration of LaCl3 is: 16
# The concentration of CaCl2 is: 11.333333333333334
# Relaxation correction: [-0.18891252 -0.09332967 -0.03175938 -0.09530638]
# Hydrodynamic correction: [-0.42599626 -0.33961376 -0.20118712 -0.12162729]
# omega_bar: 306169159895.7916
# Alpha: [0.0, 178508785539.97507, 248432599001.0187, 387828358740.9103]
# Mew: [0.36       0.11333333 0.175      0.35166667]
# Transport number: [0.17676782 0.07120212 0.18518421 0.56684585]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.78818109 -1.31094852 -0.8290265  -0.23167993]
#  [ 1.39758093  3.02689511 -1.67857096 -0.33406466]
#  [ 0.8297482   0.35805188  1.61598155 -1.404261  ]
#  [ 0.54472642  0.18834391  0.5854715   1.04363349]]
# The MAPE is of (70, 16) 11.791049286440979
# The concentration of NaCl is: 70
# The concentration of LaCl3 is: 14
# The concentration of CaCl2 is: 15.333333333333334
# Relaxation correction: [-0.19291912 -0.09623228 -0.03299824 -0.09367012]
# Hydrodynamic correction: [-0.42621306 -0.3397863  -0.20128935 -0.12168965]
# omega_bar: 309565678349.0144
# Alpha: [0.0, 174388113107.15903, 250649223005.51428, 387546701529.8961]
# Mew: [0.315      0.15333333 0.175      0.35666667]
# Transport number: [0.1529748  0.09527533 0.18315239 0.56859748]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.81556563 -1.60178165 -0.78815023 -0.23207852]
#  [ 1.41898374  2.42969586 -1.57064554 -0.33471214]
#  [ 0.84245511  0.36162387  1.6212208  -1.41105457]
#  [ 0.55306847  0.19268321  0.57584859  1.04120134]]
# The MAPE is of (70, 14) 12.23757667501359
# The concentration of NaCl is: 70
# The concentration of LaCl3 is: 12
# The concentration of CaCl2 is: 19.333333333333332
# Relaxation correction: [-0.19689568 -0.0991126  -0.03422609 -0.09204902]
# Hydrodynamic correction: [-0.42642987 -0.33995884 -0.20139159 -0.12175202]
# omega_bar: 312962196802.2372
# Alpha: [0.0, 170509146538.35507, 252631535819.4367, 387270753784.93066]
# Mew: [0.27       0.19333333 0.175      0.36166667]
# Transport number: [0.12969823 0.11882602 0.18116467 0.57031109]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.84361102 -1.92044254 -0.75442797 -0.23247139]
#  [ 1.44090305  2.00660139 -1.48342666 -0.33535035]
#  [ 0.85546868  0.35296651  1.62890608 -1.41777751]
#  [ 0.56161182  0.19025091  0.56801698  1.03883707]]
# The MAPE is of (70, 12) 12.388419557949426
# The concentration of NaCl is: 100
# The concentration of LaCl3 is: 32
# The concentration of CaCl2 is: -30.666666666666668
# The concentration of NaCl is: 100
# The concentration of LaCl3 is: 28
# The concentration of CaCl2 is: -22.666666666666668
# The concentration of NaCl is: 100
# The concentration of LaCl3 is: 24
# The concentration of CaCl2 is: -14.666666666666666
# The concentration of NaCl is: 100
# The concentration of LaCl3 is: 22
# The concentration of CaCl2 is: -10.666666666666666
# The concentration of NaCl is: 100
# The concentration of LaCl3 is: 20
# The concentration of CaCl2 is: -6.666666666666667
# The concentration of NaCl is: 100
# The concentration of LaCl3 is: 18
# The concentration of CaCl2 is: -2.6666666666666665
# The concentration of NaCl is: 100
# The concentration of LaCl3 is: 16
# The concentration of CaCl2 is: 1.3333333333333333
# Relaxation correction: [-0.1973577  -0.1006315  -0.03536475 -0.08812829]
# Hydrodynamic correction: [-0.42503001 -0.33884542 -0.20073183 -0.12134829]
# omega_bar: 323570700630.39404
# Alpha: [0.0, 189074381540.3241, 218946467701.66776, 392638566411.75543]
# Mew: [0.36       0.01333333 0.25       0.37666667]
# Transport number: [0.1672613  0.00792622 0.2503215  0.57449098]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.89215039 -0.77399009 -1.32428589 -0.21364089]
#  [ 1.47883976 10.4152877  -3.92480726 -0.30694178]
#  [ 0.87799182  0.31684648  1.26792882 -1.23124236]
#  [ 0.57639817  0.16076365  0.56307473  1.03224921]]
# The MAPE is of (100, 16) 8.773200328017936
# The concentration of NaCl is: 100
# The concentration of LaCl3 is: 14
# The concentration of CaCl2 is: 5.333333333333333
# Relaxation correction: [-0.20127242 -0.10346237 -0.03656556 -0.08655194]
# Hydrodynamic correction: [-0.42524681 -0.33901796 -0.20083407 -0.12141066]
# omega_bar: 326967219083.6168
# Alpha: [0.0, 181580141718.36398, 224640486702.69534, 392357864182.30444]
# Mew: [0.315      0.05333333 0.25       0.38166667]
# Transport number: [0.14483332 0.03137554 0.24772118 0.57606996]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.92167745 -1.38112658 -1.12174292 -0.21407094]
#  [ 1.5019171   4.54972875 -2.97010827 -0.30762306]
#  [ 0.89169291  0.42873629  1.2358043  -1.23719573]
#  [ 0.58539288  0.22328017  0.53136345  1.03005548]]
# The MAPE is of (100, 14) 9.929800311826012
# The concentration of NaCl is: 100
# The concentration of LaCl3 is: 12
# The concentration of CaCl2 is: 9.333333333333334
# Relaxation correction: [-0.20515872 -0.10627223 -0.0377561  -0.08498969]
# Hydrodynamic correction: [-0.42546361 -0.33919051 -0.2009363  -0.12147302]
# omega_bar: 330363737536.8397
# Alpha: [0.0, 175670689426.9423, 228753332430.34155, 392082251738.6148]
# Mew: [0.27       0.09333333 0.25       0.38666667]
# Transport number: [0.12286652 0.05434269 0.24517432 0.57761648]
# Omega: [1.50335711e+11 1.92351992e+11 3.23986816e+11 4.93509152e+11]
# ksi: [[ 1.9519798  -1.80356657 -1.01480447 -0.21449518]
#  [ 1.52560037  3.10462259 -2.51804622 -0.30829528]
#  [ 0.90575375  0.4331948   1.23507056 -1.24309444]
#  [ 0.59462377  0.2299125   0.51788073  1.02791776]]
# The MAPE is of (100, 12) 10.578283039476526
