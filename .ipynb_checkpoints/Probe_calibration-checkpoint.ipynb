# %%
# importing packages
import numpy as np
from matplotlib import pyplot as plt
import math
import scipy.stats as stats
import pandas as pd

# %% [markdown]
# ## Error Propagation

# %%
voltage = 25.08 # mV
curr = 0.072 # mA
R = voltage/curr # Ohm

# define function to calculate cell constant
calc_cell_constant = lambda k: k*R

# conductivity measurement and uncertainty
k = 1413
k_std = 6.8

# calculate cell constant
c1 = calc_cell_constant(k)

# estimate gradient with forward finite difference
dc1dk = (calc_cell_constant(k + 1E-6) - c1)/(1E-6)

# calculate uncertainty
sigma_c1 = abs(dc1dk)*k_std

# report answer
print("Calculated cell constant: ",round(c1*10**(-6),3),"+/-",round(sigma_c1*10**(-6),3),"cm^(-1)")
# Out:
# Calculated cell constant:  0.492 +/- 0.002 cm^(-1)

# %% [markdown]
# ## Regression Analysis

# %%
# extracting data
data = pd.read_csv(".\Data\Probe_calibration.csv")
current = data["I"]
voltage = data["V"]
cond = data["Cond"]

# number of data points
n_data = len(cond)

# %%
# input variables
current_divide_voltage = [current[i]/voltage[i] for i in range(n_data)]

# Matrix of input variables
X = np.zeros((n_data, 1))
X[:, 0] = current_divide_voltage

# %%
# X transpose multiply X
A = np.matmul(np.transpose(X), X)

# A inverse
XXinv = np.linalg.inv(A)
print(XXinv)
# Out:
# [[1469.67848702]]

# %%
# X transpose multiply KCl_cond
B = np.matmul(np.transpose(X), cond)

# fitted parameters
beta_hat = np.matmul(XXinv, B)
print(f"Beta hat is:{beta_hat}")
# Out:
# Beta hat is:[496745.24060041]

# %%
# cell constants
cell_constant = beta_hat*10**(-6) #cm^-1
print(f"The cell constant is: {cell_constant}")
# Out:
# The cell constant is: [0.49674524]

# %%
# evaluating model predictions
cond_pred = np.matmul(beta_hat, np.transpose(X))

# conductance in mS
current_divide_voltage_plot = [current_divide_voltage[i] * 1000 for i in range(n_data)]

# making plots comparison of data and prediction
fig = plt.figure(figsize=(4,4))
plt.plot(current_divide_voltage_plot, cond, "b.", markersize=10, label="Data")
plt.plot(current_divide_voltage_plot, cond_pred, "r-", label="Model")
plt.xlabel("Conductance (mS)", fontsize=16,fontweight='bold')
plt.ylabel("Conductivity ($\mathbf{\mu}$S/cm)", fontsize=16,fontweight='bold')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.tick_params(direction="in",top=True, right=True)
plt.legend()
plt.show()

# %%
# calculating residuals
e = [cond_pred[i] - cond[i] for i in range(n_data)]

# error percent
percent_error = [(e[i]/cond[i])*100 for i in range(n_data)]
print(f"Error percent is {percent_error}")

# assessing model fit
fig = plt.figure(figsize=(4,4))
plt.plot(current_divide_voltage, e, "b.")
plt.xlabel("Current/Voltage (S)", fontsize=14,fontweight='bold')
plt.ylabel("Residuals", fontsize=14,fontweight='bold')
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.tick_params(direction="in",top=True, right=True)
plt.show()
# Out:
# Error percent is [-5.15422908305469, 0.9244792410344264, -0.011022423428056986]

# %%
# sum of squared errors
sse = sum(e[i]**2 for i in range(n_data))

# variance of residuals
se = sse/(n_data - 1)
standard_dev = math.sqrt(se)
print(f"Variance of measurements is: {se}")
print(f"Standard deviation of measurements is: {standard_dev}")

# covariance matrix of fitted parameters
Sigma_beta = se*XXinv
print(f"Covariance of fitted parameters: {Sigma_beta}")
# Out:
# Variance of measurements is: 95.69983879203038
# Standard deviation of measurements is: 9.782629441618974
# Covariance of fitted parameters: [[140647.99428364]]

# %%
# variance of fitted parameters
var_list = [Sigma_beta[i, i] for i in range(len(Sigma_beta))]

# standard deviation of fitted parameters
sd_list = [np.sqrt(var_list[i]) for i in range(len(var_list))]
print(f"Standard deviation :{sd_list}")

# correlation matrix of fitted parameters
corr = np.zeros((len(var_list), len(var_list)))
for i in range(len(var_list)):
    for j in range(len(var_list)):
        corr[i, j] = Sigma_beta[i, j]/(sd_list[i]*sd_list[j])
print(f"Corr: {corr}")
# Out:
# Standard deviation :[375.0306577916594]
# Corr: [[1.]]

# %% [markdown]
# R Squared

# %%
# mean conductivity
cond_mean = np.mean(cond)

# deviation from mean conductivity
dv = [cond[i] - cond_mean for i in range(n_data)]

# total sum of squares
tss = sum(dv[i]**2 for i in range(n_data))

# r squared evaluation
r_squared = 1 - (sse/tss)
print(f"r squared value: {r_squared}")
# Out:
# r squared value: 0.9999980666435334
